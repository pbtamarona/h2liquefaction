# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import compressor

# %%
P_suction= 3.45000000000000 #bar
P_final  = 12.0660000000000 #bar

n_comp   = 1

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 3.497391304347826

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'
    
fluid   = "REFPROP::NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]"

T_in    = 292 #K
P_in    = 3.45000000000000  #bar
P_out   = R*P_in #bar

m       = round(144022.730723676/3600,4) #kg/s

MRC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
MRC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]
# Mass flow [kg/s] : 40.0063
#
# Inlet Condition
# P [bar]     =  3.45
# T [Kelvin]  =  292
# H [kJ/kg]   =  640.066
# S [kJ/kg.K] =  3.786
#
#
# Isentropic Outlet Condition
# P [bar]     =  12.066
# T [Kelvin]  =  350.49
# H [kJ/kg]   =  736.037
# S [kJ/kg.K] =  3.786
#
#
# Δh_is [kJ/kg]  =  95.971
# Power_is [kW]  = 3839.454

# %%
#design constraint
u2_max  = 500 #m/s

MRC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  1
# Max. number of stage =  3

# %%
MRC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  4634.919
# Max. RPM =  18183.08

# %%
MRC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
MRC1.stagesCalculation(8500,2,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:55.8
# Compression ratio:1.92
# Power [kW]:2232.24
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 29520.39,
#  'Rotor outlet pressure [bar]': 5.71,
#  'Rotor outlet temperature [℃]': 44.82,
#  'Diffuser outlet pressure [bar]': 6.61,
#  'Diffuser outlet temperature [℃]': 52.54,
#  'Polytropic efficiency': 0.86,
#  'Isentropic efficiency': 0.86}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.593,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 42.88,
#  'Rotor outlet diameter [cm]': 72.3,
#  'Diffuser outlet diameter [cm]': 116.56,
#  'Blade height at rotor inlet  [cm]': 8.79,
#  'Blade height at rotor outlet  [cm]': 3.98}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 87.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 87.1,
#                       'Absolute tangential rotor outlet': 173.4,
#                       'Absolute meridional rotor outlet': 59.2,
#                       'Absolute rotor outlet': 183.2,
#                       'Absolute diffuser outlet': 87.1,
#                       'Relative tangential rotor inlet': 190.9,
#                       'Relative rotor inlet': 209.8,
#                       'Relative tangential rotor outlet': 148.4,
#                       'Relative rotor outlet': 159.8,
#                       'Blade speed rotor inlet': 190.9,
#                       'Blade speed rotor outlet': 321.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.734,
#                   'Ma at rotor outlet': 0.541,
#                   'Ma at difusser inlet': 0.62,
#                   'Ma at difusser outlet': 0.292},
#  'Non-dimensional': {'Specific speed': 0.786,
#                      'Flow coefficient': 0.271,
#                      "Flow coefficient'": 0.035,
#                      'Work coefficient': 0.539,
#                      'Isentropic work coefficient': 0.463,
#                      'Rotor meridional velocity ratio': 0.68,
#                      'Degree of reaction': 0.767},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.14,
#                      'Relative rotor inlet': 65.47,
#                      'Relative rotor outlet': 68.23}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.767
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.14
# Non-optimal rotor outlet relative flow angle (0°-60°):  68.23
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.31
# Stage 2
# Delta enthalpy [kJ/kg]:59.37
# Compression ratio:1.83
# Power [kW]:2375.23
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 17006.21,
#  'Rotor outlet pressure [bar]': 10.09,
#  'Rotor outlet temperature [℃]': 76.44,
#  'Diffuser outlet pressure [bar]': 12.07,
#  'Diffuser outlet temperature [℃]': 86.74,
#  'Polytropic efficiency': 0.83,
#  'Isentropic efficiency': 0.82}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.559,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 39.15,
#  'Rotor outlet diameter [cm]': 70.02,
#  'Diffuser outlet diameter [cm]': 111.29,
#  'Blade height at rotor inlet  [cm]': 7.32,
#  'Blade height at rotor outlet  [cm]': 2.56}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 64.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 64.6,
#                       'Absolute tangential rotor outlet': 187.8,
#                       'Absolute meridional rotor outlet': 58.4,
#                       'Absolute rotor outlet': 196.7,
#                       'Absolute diffuser outlet': 64.6,
#                       'Relative tangential rotor inlet': 174.2,
#                       'Relative rotor inlet': 185.8,
#                       'Relative tangential rotor outlet': 123.9,
#                       'Relative rotor outlet': 137.0,
#                       'Blade speed rotor inlet': 174.2,
#                       'Blade speed rotor outlet': 311.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.623,
#                   'Ma at rotor outlet': 0.448,
#                   'Ma at difusser inlet': 0.643,
#                   'Ma at difusser outlet': 0.209},
#  'Non-dimensional': {'Specific speed': 0.597,
#                      'Flow coefficient': 0.207,
#                      "Flow coefficient'": 0.022,
#                      'Work coefficient': 0.603,
#                      'Isentropic work coefficient': 0.494,
#                      'Rotor meridional velocity ratio': 0.905,
#                      'Degree of reaction': 0.705},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.71,
#                      'Relative rotor inlet': 69.67,
#                      'Relative rotor outlet': 64.74}}
# Warnings:
# Non-optimal work coefficient (0.5-0.6):  0.603
# Non-optimal degree of reaction (0.6-0.7):  0.705
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.71
# Non-optimal rotor outlet relative flow angle (0°-60°):  64.74
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.36

# %%
MRC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]',
#  'Mass flow [kg/s]': 40.0063,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 8500,
#  'Number of stages': 2,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 3.45,
#  'Inlet temperature [C]': 18.85,
#  'Inlet volumetric [m3/h]': 29520.39,
#  'Delta enthalpy [kJ/kg]': 115.17,
#  'Compression ratio': 3.5,
#  'Compressor power [kW]': 4607.47,
#  'Comp. Isentropic eff. [%]': 83.33,
#  'Comp. Polytropic eff. [%]': 84.86}
