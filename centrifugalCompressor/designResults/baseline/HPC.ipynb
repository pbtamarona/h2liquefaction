# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import compressor

# %%
P_suction= 7.40146000000000 #bar
P_final  = 29.8000000000000 #bar

n_comp   = 3

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 1.5908636398536855

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First high-pressure compressor
T_in    = 293.802876417080 #K
P_in    = 7.40146000000000  #bar
P_out   = R*P_in #bar

m       = round(51498.8305826687/3600,4) #kg/s

HPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  7.401
# T [Kelvin]  =  293.8
# H [kJ/kg]   =  3872.318
# S [kJ/kg.K] =  44.958
#
#
# Isentropic Outlet Condition
# P [bar]     =  11.775
# T [Kelvin]  =  335.75
# H [kJ/kg]   =  4477.477
# S [kJ/kg.K] =  44.958
#
#
# Δh_is [kJ/kg]  =  605.159
# Power_is [kW]  = 8656.919

# %%
#design constraint
u2_max  = 500  #m/s

HPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  5
# Max. number of stage =  7

# %%
HPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  4577.47
# Max. RPM =  12775.993

# %%
HPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC1.stagesCalculation(8000,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:118.8
# Compression ratio:1.09
# Power [kW]:1699.43
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 84684.72,
#  'Rotor outlet pressure [bar]': 7.87,
#  'Rotor outlet temperature [℃]': 26.83,
#  'Diffuser outlet pressure [bar]': 8.03,
#  'Diffuser outlet temperature [℃]': 28.93,
#  'Polytropic efficiency [%]': 85.05,
#  'Isentropic efficiency [%]': 84.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.58,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 63.88,
#  'Rotor outlet diameter [cm]': 110.05,
#  'Diffuser outlet diameter [cm]': 176.48,
#  'Blade height at rotor inlet  [cm]': 12.68,
#  'Blade height at rotor outlet  [cm]': 7.7}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 115.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 115.3,
#                       'Absolute tangential rotor outlet': 257.7,
#                       'Absolute meridional rotor outlet': 84.8,
#                       'Absolute rotor outlet': 271.3,
#                       'Absolute diffuser outlet': 115.3,
#                       'Relative tangential rotor inlet': 267.6,
#                       'Relative rotor inlet': 291.4,
#                       'Relative tangential rotor outlet': 203.3,
#                       'Relative rotor outlet': 220.3,
#                       'Blade speed rotor inlet': 267.6,
#                       'Blade speed rotor outlet': 461.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.222,
#                   'Ma at rotor outlet': 0.166,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.087},
#  'Non-dimensional': {'Specific speed': 0.718,
#                      'Flow coefficient': 0.25,
#                      "Flow coefficient'": 0.046,
#                      'Work coefficient': 0.559,
#                      'Isentropic work coefficient': 0.475,
#                      'Rotor meridional velocity ratio': 0.736,
#                      'Degree of reaction': 0.746},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.78,
#                      'Relative rotor inlet': 66.69,
#                      'Relative rotor outlet': 67.35}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.746
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.78
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.35
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:119.71
# Compression ratio:1.08
# Power [kW]:1712.53
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 80248.12,
#  'Rotor outlet pressure [bar]': 8.52,
#  'Rotor outlet temperature [℃]': 35.06,
#  'Diffuser outlet pressure [bar]': 8.7,
#  'Diffuser outlet temperature [℃]': 37.25,
#  'Polytropic efficiency [%]': 84.76,
#  'Isentropic efficiency [%]': 84.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 63.29,
#  'Rotor outlet diameter [cm]': 109.69,
#  'Diffuser outlet diameter [cm]': 175.66,
#  'Blade height at rotor inlet  [cm]': 12.45,
#  'Blade height at rotor outlet  [cm]': 7.36}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 112.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 112.1,
#                       'Absolute tangential rotor outlet': 259.5,
#                       'Absolute meridional rotor outlet': 84.6,
#                       'Absolute rotor outlet': 272.9,
#                       'Absolute diffuser outlet': 112.1,
#                       'Relative tangential rotor inlet': 265.1,
#                       'Relative rotor inlet': 287.8,
#                       'Relative tangential rotor outlet': 200.0,
#                       'Relative rotor outlet': 217.2,
#                       'Blade speed rotor inlet': 265.1,
#                       'Blade speed rotor outlet': 459.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.216,
#                   'Ma at rotor outlet': 0.162,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.083},
#  'Non-dimensional': {'Specific speed': 0.699,
#                      'Flow coefficient': 0.244,
#                      "Flow coefficient'": 0.044,
#                      'Work coefficient': 0.565,
#                      'Isentropic work coefficient': 0.478,
#                      'Rotor meridional velocity ratio': 0.755,
#                      'Degree of reaction': 0.74},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.94,
#                      'Relative rotor inlet': 67.08,
#                      'Relative rotor outlet': 67.08}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.74
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.94
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.08
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:120.64
# Compression ratio:1.08
# Power [kW]:1725.72
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 76144.16,
#  'Rotor outlet pressure [bar]': 9.21,
#  'Rotor outlet temperature [℃]': 43.35,
#  'Diffuser outlet pressure [bar]': 9.41,
#  'Diffuser outlet temperature [℃]': 45.61,
#  'Polytropic efficiency [%]': 84.45,
#  'Isentropic efficiency [%]': 84.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 62.74,
#  'Rotor outlet diameter [cm]': 109.36,
#  'Diffuser outlet diameter [cm]': 174.88,
#  'Blade height at rotor inlet  [cm]': 12.23,
#  'Blade height at rotor outlet  [cm]': 7.03}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 109.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 109.0,
#                       'Absolute tangential rotor outlet': 261.2,
#                       'Absolute meridional rotor outlet': 84.4,
#                       'Absolute rotor outlet': 274.5,
#                       'Absolute diffuser outlet': 109.0,
#                       'Relative tangential rotor inlet': 262.8,
#                       'Relative rotor inlet': 284.5,
#                       'Relative tangential rotor outlet': 196.9,
#                       'Relative rotor outlet': 214.2,
#                       'Blade speed rotor inlet': 262.8,
#                       'Blade speed rotor outlet': 458.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.211,
#                   'Ma at rotor outlet': 0.157,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.08},
#  'Non-dimensional': {'Specific speed': 0.681,
#                      'Flow coefficient': 0.238,
#                      "Flow coefficient'": 0.042,
#                      'Work coefficient': 0.57,
#                      'Isentropic work coefficient': 0.481,
#                      'Rotor meridional velocity ratio': 0.775,
#                      'Degree of reaction': 0.735},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.09,
#                      'Relative rotor inlet': 67.48,
#                      'Relative rotor outlet': 66.8}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.735
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.09
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.8
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:121.56
# Compression ratio:1.08
# Power [kW]:1739.01
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 72341.38,
#  'Rotor outlet pressure [bar]': 9.94,
#  'Rotor outlet temperature [℃]': 51.68,
#  'Diffuser outlet pressure [bar]': 10.16,
#  'Diffuser outlet temperature [℃]': 54.03,
#  'Polytropic efficiency [%]': 84.12,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 62.23,
#  'Rotor outlet diameter [cm]': 109.04,
#  'Diffuser outlet diameter [cm]': 174.16,
#  'Blade height at rotor inlet  [cm]': 12.03,
#  'Blade height at rotor outlet  [cm]': 6.72}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 105.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 105.9,
#                       'Absolute tangential rotor outlet': 262.9,
#                       'Absolute meridional rotor outlet': 84.3,
#                       'Absolute rotor outlet': 276.0,
#                       'Absolute diffuser outlet': 105.9,
#                       'Relative tangential rotor inlet': 260.7,
#                       'Relative rotor inlet': 281.4,
#                       'Relative tangential rotor outlet': 193.9,
#                       'Relative rotor outlet': 211.4,
#                       'Blade speed rotor inlet': 260.7,
#                       'Blade speed rotor outlet': 456.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.206,
#                   'Ma at rotor outlet': 0.153,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.077},
#  'Non-dimensional': {'Specific speed': 0.664,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.04,
#                      'Work coefficient': 0.576,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.795,
#                      'Degree of reaction': 0.729},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.23,
#                      'Relative rotor inlet': 67.89,
#                      'Relative rotor outlet': 66.51}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.729
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.23
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.51
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:122.5
# Compression ratio:1.08
# Power [kW]:1752.4
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 68811.88,
#  'Rotor outlet pressure [bar]': 10.71,
#  'Rotor outlet temperature [℃]': 60.07,
#  'Diffuser outlet pressure [bar]': 10.94,
#  'Diffuser outlet temperature [℃]': 62.5,
#  'Polytropic efficiency [%]': 83.78,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 61.74,
#  'Rotor outlet diameter [cm]': 108.75,
#  'Diffuser outlet diameter [cm]': 173.47,
#  'Blade height at rotor inlet  [cm]': 11.84,
#  'Blade height at rotor outlet  [cm]': 6.42}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 103.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 103.0,
#                       'Absolute tangential rotor outlet': 264.5,
#                       'Absolute meridional rotor outlet': 84.1,
#                       'Absolute rotor outlet': 277.6,
#                       'Absolute diffuser outlet': 103.0,
#                       'Relative tangential rotor inlet': 258.6,
#                       'Relative rotor inlet': 278.4,
#                       'Relative tangential rotor outlet': 191.0,
#                       'Relative rotor outlet': 208.7,
#                       'Blade speed rotor inlet': 258.6,
#                       'Blade speed rotor outlet': 455.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.201,
#                   'Ma at rotor outlet': 0.149,
#                   'Ma at difusser inlet': 0.199,
#                   'Ma at difusser outlet': 0.073},
#  'Non-dimensional': {'Specific speed': 0.647,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.039,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.817,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.29,
#                      'Relative rotor outlet': 66.22}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.22
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 6
# Delta enthalpy [kJ/kg]:123.59
# Compression ratio:1.08
# Power [kW]:1768.04
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 65530.86,
#  'Rotor outlet pressure [bar]': 11.52,
#  'Rotor outlet temperature [℃]': 68.51,
#  'Diffuser outlet pressure [bar]': 11.77,
#  'Diffuser outlet temperature [℃]': 71.03,
#  'Polytropic efficiency [%]': 83.43,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 61.29,
#  'Rotor outlet diameter [cm]': 108.47,
#  'Diffuser outlet diameter [cm]': 172.83,
#  'Blade height at rotor inlet  [cm]': 11.66,
#  'Blade height at rotor outlet  [cm]': 6.14}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 100.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 100.1,
#                       'Absolute tangential rotor outlet': 266.5,
#                       'Absolute meridional rotor outlet': 84.2,
#                       'Absolute rotor outlet': 279.5,
#                       'Absolute diffuser outlet': 100.1,
#                       'Relative tangential rotor inlet': 256.7,
#                       'Relative rotor inlet': 275.6,
#                       'Relative tangential rotor outlet': 187.9,
#                       'Relative rotor outlet': 205.9,
#                       'Blade speed rotor inlet': 256.7,
#                       'Blade speed rotor outlet': 454.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.197,
#                   'Ma at rotor outlet': 0.146,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.632,
#                      'Flow coefficient': 0.22,
#                      "Flow coefficient'": 0.037,
#                      'Work coefficient': 0.587,
#                      'Isentropic work coefficient': 0.489,
#                      'Rotor meridional velocity ratio': 0.841,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.47,
#                      'Relative rotor inlet': 68.7,
#                      'Relative rotor outlet': 65.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.47
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 8000,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 7.4,
#  'Inlet temperature [C]': 20.65,
#  'Inlet volumetric [m3/h]': 84684.72,
#  'Delta enthalpy [kJ/kg]': 726.81,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10397.12,
#  'Comp. Isentropic eff. [%]': 83.26,
#  'Comp. Polytropic eff. [%]': 84.32}

# %%
#Second high-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 11.7747135958315 #bar
P_out   = R*P_in #bar

HPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  11.775
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3936.454
# S [kJ/kg.K] =  43.249
#
#
# Isentropic Outlet Condition
# P [bar]     =  18.732
# T [Kelvin]  =  340.69
# H [kJ/kg]   =  4552.422
# S [kJ/kg.K] =  43.249
#
#
# Δh_is [kJ/kg]  =  615.968
# Power_is [kW]  = 8811.543

# %%
#design constraint
u2_max  = 500  #m/s

HPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  5
# Max. number of stage =  7

# %%
HPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  5798.115
# Max. RPM =  16189.759

# %%
HPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC2.stagesCalculation(9900,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:121.21
# Compression ratio:1.09
# Power [kW]:1733.87
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 54156.0,
#  'Rotor outlet pressure [bar]': 12.51,
#  'Rotor outlet temperature [℃]': 31.24,
#  'Diffuser outlet pressure [bar]': 12.78,
#  'Diffuser outlet temperature [℃]': 33.41,
#  'Polytropic efficiency [%]': 84.8,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 51.66,
#  'Rotor outlet diameter [cm]': 89.46,
#  'Diffuser outlet diameter [cm]': 143.29,
#  'Blade height at rotor inlet  [cm]': 10.17,
#  'Blade height at rotor outlet  [cm]': 6.03}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 113.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 113.5,
#                       'Absolute tangential rotor outlet': 261.4,
#                       'Absolute meridional rotor outlet': 85.3,
#                       'Absolute rotor outlet': 274.9,
#                       'Absolute diffuser outlet': 113.5,
#                       'Relative tangential rotor inlet': 267.8,
#                       'Relative rotor inlet': 290.8,
#                       'Relative tangential rotor outlet': 202.4,
#                       'Relative rotor outlet': 219.6,
#                       'Blade speed rotor inlet': 267.8,
#                       'Blade speed rotor outlet': 463.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.22,
#                   'Ma at rotor outlet': 0.164,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.701,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.036,
#                      'Work coefficient': 0.564,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.752,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.92,
#                      'Relative rotor inlet': 67.03,
#                      'Relative rotor outlet': 67.15}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.92
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.15
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:122.15
# Compression ratio:1.08
# Power [kW]:1747.35
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 51328.54,
#  'Rotor outlet pressure [bar]': 13.55,
#  'Rotor outlet temperature [℃]': 39.61,
#  'Diffuser outlet pressure [bar]': 13.84,
#  'Diffuser outlet temperature [℃]': 41.88,
#  'Polytropic efficiency [%]': 84.48,
#  'Isentropic efficiency [%]': 84.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 51.2,
#  'Rotor outlet diameter [cm]': 89.18,
#  'Diffuser outlet diameter [cm]': 142.64,
#  'Blade height at rotor inlet  [cm]': 9.99,
#  'Blade height at rotor outlet  [cm]': 5.75}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 110.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 110.2,
#                       'Absolute tangential rotor outlet': 263.1,
#                       'Absolute meridional rotor outlet': 85.1,
#                       'Absolute rotor outlet': 276.5,
#                       'Absolute diffuser outlet': 110.2,
#                       'Relative tangential rotor inlet': 265.4,
#                       'Relative rotor inlet': 287.4,
#                       'Relative tangential rotor outlet': 199.2,
#                       'Relative rotor outlet': 216.6,
#                       'Blade speed rotor inlet': 265.4,
#                       'Blade speed rotor outlet': 462.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.214,
#                   'Ma at rotor outlet': 0.16,
#                   'Ma at difusser inlet': 0.204,
#                   'Ma at difusser outlet': 0.081},
#  'Non-dimensional': {'Specific speed': 0.683,
#                      'Flow coefficient': 0.238,
#                      "Flow coefficient'": 0.035,
#                      'Work coefficient': 0.569,
#                      'Isentropic work coefficient': 0.48,
#                      'Rotor meridional velocity ratio': 0.772,
#                      'Degree of reaction': 0.736},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.08,
#                      'Relative rotor inlet': 67.44,
#                      'Relative rotor outlet': 66.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.736
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.08
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:123.24
# Compression ratio:1.08
# Power [kW]:1763.03
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 48713.61,
#  'Rotor outlet pressure [bar]': 14.65,
#  'Rotor outlet temperature [℃]': 48.04,
#  'Diffuser outlet pressure [bar]': 14.97,
#  'Diffuser outlet temperature [℃]': 50.39,
#  'Polytropic efficiency [%]': 84.15,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 50.77,
#  'Rotor outlet diameter [cm]': 88.92,
#  'Diffuser outlet diameter [cm]': 142.03,
#  'Blade height at rotor inlet  [cm]': 9.82,
#  'Blade height at rotor outlet  [cm]': 5.49}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 107.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 107.1,
#                       'Absolute tangential rotor outlet': 265.1,
#                       'Absolute meridional rotor outlet': 85.0,
#                       'Absolute rotor outlet': 278.5,
#                       'Absolute diffuser outlet': 107.1,
#                       'Relative tangential rotor inlet': 263.2,
#                       'Relative rotor inlet': 284.1,
#                       'Relative tangential rotor outlet': 195.8,
#                       'Relative rotor outlet': 213.5,
#                       'Blade speed rotor inlet': 263.2,
#                       'Blade speed rotor outlet': 460.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.209,
#                   'Ma at rotor outlet': 0.155,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.078},
#  'Non-dimensional': {'Specific speed': 0.665,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.033,
#                      'Work coefficient': 0.575,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.794,
#                      'Degree of reaction': 0.73},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.22,
#                      'Relative rotor inlet': 67.85,
#                      'Relative rotor outlet': 66.52}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.73
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.22
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.52
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:124.21
# Compression ratio:1.08
# Power [kW]:1776.79
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 46292.51,
#  'Rotor outlet pressure [bar]': 15.81,
#  'Rotor outlet temperature [℃]': 56.53,
#  'Diffuser outlet pressure [bar]': 16.16,
#  'Diffuser outlet temperature [℃]': 58.96,
#  'Polytropic efficiency [%]': 83.8,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 50.36,
#  'Rotor outlet diameter [cm]': 88.67,
#  'Diffuser outlet diameter [cm]': 141.46,
#  'Blade height at rotor inlet  [cm]': 9.66,
#  'Blade height at rotor outlet  [cm]': 5.25}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 104.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 104.1,
#                       'Absolute tangential rotor outlet': 266.8,
#                       'Absolute meridional rotor outlet': 84.9,
#                       'Absolute rotor outlet': 280.0,
#                       'Absolute diffuser outlet': 104.1,
#                       'Relative tangential rotor inlet': 261.1,
#                       'Relative rotor inlet': 281.0,
#                       'Relative tangential rotor outlet': 192.8,
#                       'Relative rotor outlet': 210.7,
#                       'Blade speed rotor inlet': 261.1,
#                       'Blade speed rotor outlet': 459.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.204,
#                   'Ma at rotor outlet': 0.151,
#                   'Ma at difusser inlet': 0.201,
#                   'Ma at difusser outlet': 0.074},
#  'Non-dimensional': {'Specific speed': 0.648,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.032,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.816,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.26,
#                      'Relative rotor outlet': 66.23}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.23
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:125.33
# Compression ratio:1.08
# Power [kW]:1792.8
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 44045.75,
#  'Rotor outlet pressure [bar]': 17.04,
#  'Rotor outlet temperature [℃]': 65.07,
#  'Diffuser outlet pressure [bar]': 17.41,
#  'Diffuser outlet temperature [℃]': 67.6,
#  'Polytropic efficiency [%]': 83.44,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 49.98,
#  'Rotor outlet diameter [cm]': 88.44,
#  'Diffuser outlet diameter [cm]': 140.93,
#  'Blade height at rotor inlet  [cm]': 9.51,
#  'Blade height at rotor outlet  [cm]': 5.01}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 101.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 101.1,
#                       'Absolute tangential rotor outlet': 268.8,
#                       'Absolute meridional rotor outlet': 84.9,
#                       'Absolute rotor outlet': 281.9,
#                       'Absolute diffuser outlet': 101.1,
#                       'Relative tangential rotor inlet': 259.1,
#                       'Relative rotor inlet': 278.1,
#                       'Relative tangential rotor outlet': 189.6,
#                       'Relative rotor outlet': 207.8,
#                       'Blade speed rotor inlet': 259.1,
#                       'Blade speed rotor outlet': 458.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.199,
#                   'Ma at rotor outlet': 0.147,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.632,
#                      'Flow coefficient': 0.221,
#                      "Flow coefficient'": 0.03,
#                      'Work coefficient': 0.586,
#                      'Isentropic work coefficient': 0.488,
#                      'Rotor meridional velocity ratio': 0.84,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.46,
#                      'Relative rotor inlet': 68.68,
#                      'Relative rotor outlet': 65.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.46
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:126.46
# Compression ratio:1.08
# Power [kW]:1809.04
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 41958.75,
#  'Rotor outlet pressure [bar]': 18.33,
#  'Rotor outlet temperature [℃]': 73.68,
#  'Diffuser outlet pressure [bar]': 18.73,
#  'Diffuser outlet temperature [℃]': 76.3,
#  'Polytropic efficiency [%]': 83.07,
#  'Isentropic efficiency [%]': 82.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.563,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 49.63,
#  'Rotor outlet diameter [cm]': 88.23,
#  'Diffuser outlet diameter [cm]': 140.43,
#  'Blade height at rotor inlet  [cm]': 9.38,
#  'Blade height at rotor outlet  [cm]': 4.79}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 98.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 98.3,
#                       'Absolute tangential rotor outlet': 270.8,
#                       'Absolute meridional rotor outlet': 85.0,
#                       'Absolute rotor outlet': 283.8,
#                       'Absolute diffuser outlet': 98.3,
#                       'Relative tangential rotor inlet': 257.3,
#                       'Relative rotor inlet': 275.4,
#                       'Relative tangential rotor outlet': 186.5,
#                       'Relative rotor outlet': 205.0,
#                       'Blade speed rotor inlet': 257.3,
#                       'Blade speed rotor outlet': 457.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.194,
#                   'Ma at rotor outlet': 0.143,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.068},
#  'Non-dimensional': {'Specific speed': 0.617,
#                      'Flow coefficient': 0.215,
#                      "Flow coefficient'": 0.029,
#                      'Work coefficient': 0.592,
#                      'Isentropic work coefficient': 0.491,
#                      'Rotor meridional velocity ratio': 0.865,
#                      'Degree of reaction': 0.714},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.57,
#                      'Relative rotor inlet': 69.09,
#                      'Relative rotor outlet': 65.5}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.714
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.57
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.5
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 9900,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 11.77,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 54156.0,
#  'Delta enthalpy [kJ/kg]': 742.59,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10622.89,
#  'Comp. Isentropic eff. [%]': 82.95,
#  'Comp. Polytropic eff. [%]': 84.02}

# %%
#Third high-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 18.7319637292991 #bar
P_out   = R*P_in #bar

HPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  18.732
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3939.509
# S [kJ/kg.K] =  41.327
#
#
# Isentropic Outlet Condition
# P [bar]     =  29.8
# T [Kelvin]  =  340.7
# H [kJ/kg]   =  4558.549
# S [kJ/kg.K] =  41.327
#
#
# Δh_is [kJ/kg]  =  619.04
# Power_is [kW]  = 8855.487

# %%
#design constraint
u2_max  = 500  #m/s

HPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  6
# Max. number of stage =  8

# %%
HPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  6640.659
# Max. RPM =  17840.513

# %%
HPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC3.stagesCalculation(12500,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:121.81
# Compression ratio:1.09
# Power [kW]:1742.52
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 34180.74,
#  'Rotor outlet pressure [bar]': 19.91,
#  'Rotor outlet temperature [℃]': 31.25,
#  'Diffuser outlet pressure [bar]': 20.33,
#  'Diffuser outlet temperature [℃]': 33.43,
#  'Polytropic efficiency [%]': 84.79,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 41.01,
#  'Rotor outlet diameter [cm]': 71.03,
#  'Diffuser outlet diameter [cm]': 113.75,
#  'Blade height at rotor inlet  [cm]': 8.07,
#  'Blade height at rotor outlet  [cm]': 4.78}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 113.7,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 113.7,
#                       'Absolute tangential rotor outlet': 262.0,
#                       'Absolute meridional rotor outlet': 85.5,
#                       'Absolute rotor outlet': 275.6,
#                       'Absolute diffuser outlet': 113.7,
#                       'Relative tangential rotor inlet': 268.4,
#                       'Relative rotor inlet': 291.5,
#                       'Relative tangential rotor outlet': 202.8,
#                       'Relative rotor outlet': 220.1,
#                       'Blade speed rotor inlet': 268.4,
#                       'Blade speed rotor outlet': 464.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.219,
#                   'Ma at rotor outlet': 0.164,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.701,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.029,
#                      'Work coefficient': 0.564,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.752,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.93,
#                      'Relative rotor inlet': 67.04,
#                      'Relative rotor outlet': 67.14}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.93
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.14
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:122.9
# Compression ratio:1.08
# Power [kW]:1758.16
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 32404.2,
#  'Rotor outlet pressure [bar]': 21.56,
#  'Rotor outlet temperature [℃]': 39.64,
#  'Diffuser outlet pressure [bar]': 22.03,
#  'Diffuser outlet temperature [℃]': 41.91,
#  'Polytropic efficiency [%]': 84.47,
#  'Isentropic efficiency [%]': 84.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 40.64,
#  'Rotor outlet diameter [cm]': 70.8,
#  'Diffuser outlet diameter [cm]': 113.24,
#  'Blade height at rotor inlet  [cm]': 7.93,
#  'Blade height at rotor outlet  [cm]': 4.56}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 110.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 110.5,
#                       'Absolute tangential rotor outlet': 264.1,
#                       'Absolute meridional rotor outlet': 85.4,
#                       'Absolute rotor outlet': 277.6,
#                       'Absolute diffuser outlet': 110.5,
#                       'Relative tangential rotor inlet': 266.0,
#                       'Relative rotor inlet': 288.0,
#                       'Relative tangential rotor outlet': 199.3,
#                       'Relative rotor outlet': 216.8,
#                       'Blade speed rotor inlet': 266.0,
#                       'Blade speed rotor outlet': 463.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.213,
#                   'Ma at rotor outlet': 0.159,
#                   'Ma at difusser inlet': 0.204,
#                   'Ma at difusser outlet': 0.081},
#  'Non-dimensional': {'Specific speed': 0.682,
#                      'Flow coefficient': 0.238,
#                      "Flow coefficient'": 0.027,
#                      'Work coefficient': 0.57,
#                      'Isentropic work coefficient': 0.48,
#                      'Rotor meridional velocity ratio': 0.773,
#                      'Degree of reaction': 0.735},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.08,
#                      'Relative rotor inlet': 67.45,
#                      'Relative rotor outlet': 66.81}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.735
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.08
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.81
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:123.86
# Compression ratio:1.08
# Power [kW]:1771.88
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 30762.72,
#  'Rotor outlet pressure [bar]': 23.31,
#  'Rotor outlet temperature [℃]': 48.08,
#  'Diffuser outlet pressure [bar]': 23.82,
#  'Diffuser outlet temperature [℃]': 50.43,
#  'Polytropic efficiency [%]': 84.15,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 40.3,
#  'Rotor outlet diameter [cm]': 70.6,
#  'Diffuser outlet diameter [cm]': 112.76,
#  'Blade height at rotor inlet  [cm]': 7.8,
#  'Blade height at rotor outlet  [cm]': 4.36}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 107.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 107.3,
#                       'Absolute tangential rotor outlet': 265.8,
#                       'Absolute meridional rotor outlet': 85.2,
#                       'Absolute rotor outlet': 279.2,
#                       'Absolute diffuser outlet': 107.3,
#                       'Relative tangential rotor inlet': 263.8,
#                       'Relative rotor inlet': 284.8,
#                       'Relative tangential rotor outlet': 196.2,
#                       'Relative rotor outlet': 214.0,
#                       'Blade speed rotor inlet': 263.8,
#                       'Blade speed rotor outlet': 462.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.208,
#                   'Ma at rotor outlet': 0.155,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.077},
#  'Non-dimensional': {'Specific speed': 0.665,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.026,
#                      'Work coefficient': 0.575,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.794,
#                      'Degree of reaction': 0.73},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.22,
#                      'Relative rotor inlet': 67.86,
#                      'Relative rotor outlet': 66.52}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.73
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.22
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.52
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:124.83
# Compression ratio:1.08
# Power [kW]:1785.7
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 29242.46,
#  'Rotor outlet pressure [bar]': 25.16,
#  'Rotor outlet temperature [℃]': 56.57,
#  'Diffuser outlet pressure [bar]': 25.71,
#  'Diffuser outlet temperature [℃]': 59.01,
#  'Polytropic efficiency [%]': 83.8,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 39.98,
#  'Rotor outlet diameter [cm]': 70.4,
#  'Diffuser outlet diameter [cm]': 112.31,
#  'Blade height at rotor inlet  [cm]': 7.67,
#  'Blade height at rotor outlet  [cm]': 4.16}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 104.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 104.3,
#                       'Absolute tangential rotor outlet': 267.5,
#                       'Absolute meridional rotor outlet': 85.1,
#                       'Absolute rotor outlet': 280.7,
#                       'Absolute diffuser outlet': 104.3,
#                       'Relative tangential rotor inlet': 261.7,
#                       'Relative rotor inlet': 281.7,
#                       'Relative tangential rotor outlet': 193.3,
#                       'Relative rotor outlet': 211.2,
#                       'Blade speed rotor inlet': 261.7,
#                       'Blade speed rotor outlet': 460.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.203,
#                   'Ma at rotor outlet': 0.151,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.074},
#  'Non-dimensional': {'Specific speed': 0.648,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.025,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.816,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.27,
#                      'Relative rotor outlet': 66.23}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.23
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:125.95
# Compression ratio:1.08
# Power [kW]:1801.79
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 27832.1,
#  'Rotor outlet pressure [bar]': 27.11,
#  'Rotor outlet temperature [℃]': 65.12,
#  'Diffuser outlet pressure [bar]': 27.7,
#  'Diffuser outlet temperature [℃]': 67.65,
#  'Polytropic efficiency [%]': 83.44,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 39.69,
#  'Rotor outlet diameter [cm]': 70.22,
#  'Diffuser outlet diameter [cm]': 111.89,
#  'Blade height at rotor inlet  [cm]': 7.55,
#  'Blade height at rotor outlet  [cm]': 3.98}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 101.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 101.4,
#                       'Absolute tangential rotor outlet': 269.5,
#                       'Absolute meridional rotor outlet': 85.2,
#                       'Absolute rotor outlet': 282.6,
#                       'Absolute diffuser outlet': 101.4,
#                       'Relative tangential rotor inlet': 259.7,
#                       'Relative rotor inlet': 278.8,
#                       'Relative tangential rotor outlet': 190.1,
#                       'Relative rotor outlet': 208.3,
#                       'Blade speed rotor inlet': 259.7,
#                       'Blade speed rotor outlet': 459.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.198,
#                   'Ma at rotor outlet': 0.147,
#                   'Ma at difusser inlet': 0.199,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.632,
#                      'Flow coefficient': 0.221,
#                      "Flow coefficient'": 0.024,
#                      'Work coefficient': 0.586,
#                      'Isentropic work coefficient': 0.488,
#                      'Rotor meridional velocity ratio': 0.84,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.46,
#                      'Relative rotor inlet': 68.68,
#                      'Relative rotor outlet': 65.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.46
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:127.09
# Compression ratio:1.08
# Power [kW]:1818.1
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 26522.42,
#  'Rotor outlet pressure [bar]': 29.16,
#  'Rotor outlet temperature [℃]': 73.73,
#  'Diffuser outlet pressure [bar]': 29.8,
#  'Diffuser outlet temperature [℃]': 76.35,
#  'Polytropic efficiency [%]': 83.07,
#  'Isentropic efficiency [%]': 82.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.563,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 39.41,
#  'Rotor outlet diameter [cm]': 70.05,
#  'Diffuser outlet diameter [cm]': 111.5,
#  'Blade height at rotor inlet  [cm]': 7.44,
#  'Blade height at rotor outlet  [cm]': 3.8}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 98.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 98.6,
#                       'Absolute tangential rotor outlet': 271.5,
#                       'Absolute meridional rotor outlet': 85.2,
#                       'Absolute rotor outlet': 284.5,
#                       'Absolute diffuser outlet': 98.6,
#                       'Relative tangential rotor inlet': 257.9,
#                       'Relative rotor inlet': 276.1,
#                       'Relative tangential rotor outlet': 187.0,
#                       'Relative rotor outlet': 205.5,
#                       'Blade speed rotor inlet': 257.9,
#                       'Blade speed rotor outlet': 458.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.194,
#                   'Ma at rotor outlet': 0.143,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.068},
#  'Non-dimensional': {'Specific speed': 0.617,
#                      'Flow coefficient': 0.215,
#                      "Flow coefficient'": 0.023,
#                      'Work coefficient': 0.592,
#                      'Isentropic work coefficient': 0.491,
#                      'Rotor meridional velocity ratio': 0.865,
#                      'Degree of reaction': 0.714},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.57,
#                      'Relative rotor inlet': 69.09,
#                      'Relative rotor outlet': 65.5}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.714
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.57
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.5
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 12500,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 18.73,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 34180.74,
#  'Delta enthalpy [kJ/kg]': 746.45,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10678.15,
#  'Comp. Isentropic eff. [%]': 82.93,
#  'Comp. Polytropic eff. [%]': 84.0}
