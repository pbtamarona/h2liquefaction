# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import compressor

# %%
P_suction = 1.05913000000000 #bar
P_final   = 7.40146000000000 #bar

n_comp    = 3

R         = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 1.911859803123236

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First low-pressure compressor
T_in    = 297.099998889065 #K
P_in    = 1.05913000000000 #bar
P_out   = R*P_in #bar

m       = round(2315.23292650504/3600,4) #kg/s

LPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  1.059
# T [Kelvin]  =  297.1
# H [kJ/kg]   =  3916.802
# S [kJ/kg.K] =  53.143
#
#
# Isentropic Outlet Condition
# P [bar]     =  2.025
# T [Kelvin]  =  357.8
# H [kJ/kg]   =  4790.406
# S [kJ/kg.K] =  53.143
#
#
# Δh_is [kJ/kg]  =  873.605
# Power_is [kW]  = 561.815

# %%
#design constraint
u2_max  = 500  #m/s

LPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  8772.21
# Max. RPM =  21023.463

# %%
LPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC1.stagesCalculation(15800,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:127.87
# Compression ratio:1.09
# Power [kW]:82.23
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 26802.43,
#  'Rotor outlet pressure [bar]': 1.13,
#  'Rotor outlet temperature [℃]': 30.7,
#  'Diffuser outlet pressure [bar]': 1.16,
#  'Diffuser outlet temperature [℃]': 32.88,
#  'Polytropic efficiency [%]': 85.49,
#  'Isentropic efficiency [%]': 85.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.587,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 34.21,
#  'Rotor outlet diameter [cm]': 58.32,
#  'Diffuser outlet diameter [cm]': 93.76,
#  'Blade height at rotor inlet  [cm]': 6.9,
#  'Blade height at rotor outlet  [cm]': 4.38}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 125.7,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 125.7,
#                       'Absolute tangential rotor outlet': 265.0,
# ...

# %%
LPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 15800,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 1.06,
#  'Inlet temperature [C]': 23.95,
#  'Inlet volumetric [m3/h]': 26802.43,
#  'Delta enthalpy [kJ/kg]': 1052.17,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 676.65,
#  'Comp. Isentropic eff. [%]': 83.03,
#  'Comp. Polytropic eff. [%]': 84.5}

# %%
#Second low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 2.02490807328191 #bar
P_out   = R*P_in #bar

LPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  2.025
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3932.236
# S [kJ/kg.K] =  50.519
#
#
# Isentropic Outlet Condition
# P [bar]     =  3.871
# T [Kelvin]  =  359.05
# H [kJ/kg]   =  4809.571
# S [kJ/kg.K] =  50.519
#
#
# Δh_is [kJ/kg]  =  877.335
# Power_is [kW]  = 564.214

# %%
#design constraint
u2_max  = 500  #m/s

LPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  12141.402
# Max. RPM =  29102.574

# %%
LPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC2.stagesCalculation(21000,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:129.02
# Compression ratio:1.09
# Power [kW]:82.97
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 14076.53,
#  'Rotor outlet pressure [bar]': 2.16,
#  'Rotor outlet temperature [℃]': 31.73,
#  'Diffuser outlet pressure [bar]': 2.21,
#  'Diffuser outlet temperature [℃]': 34.0,
#  'Polytropic efficiency [%]': 85.11,
#  'Isentropic efficiency [%]': 85.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.581,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 25.42,
#  'Rotor outlet diameter [cm]': 43.74,
#  'Diffuser outlet diameter [cm]': 70.17,
#  'Blade height at rotor inlet  [cm]': 5.06,
#  'Blade height at rotor outlet  [cm]': 3.08}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 120.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 120.9,
#                       'Absolute tangential rotor outlet': 268.2,
# ...

# %%
LPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 21000,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 2.02,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 14076.53,
#  'Delta enthalpy [kJ/kg]': 1064.07,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 684.3,
#  'Comp. Isentropic eff. [%]': 82.45,
#  'Comp. Polytropic eff. [%]': 83.97}

# %%
#Third low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 3.87134035032741 #bar
P_out   = R*P_in #bar

LPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  3.871
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3933.029
# S [kJ/kg.K] =  47.844
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.401
# T [Kelvin]  =  359.06
# H [kJ/kg]   =  4811.631
# S [kJ/kg.K] =  47.844
#
#
# Δh_is [kJ/kg]  =  878.601
# Power_is [kW]  = 565.029

# %%
#design constraint
u2_max  = 500  #m/s

LPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  16791.505
# Max. RPM =  40261.894

# %%
LPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC3.stagesCalculation(29500,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:129.05
# Compression ratio:1.09
# Power [kW]:82.99
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 7370.72,
#  'Rotor outlet pressure [bar]': 4.14,
#  'Rotor outlet temperature [℃]': 31.75,
#  'Diffuser outlet pressure [bar]': 4.23,
#  'Diffuser outlet temperature [℃]': 34.0,
#  'Polytropic efficiency [%]': 85.26,
#  'Isentropic efficiency [%]': 85.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.583,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 18.21,
#  'Rotor outlet diameter [cm]': 31.22,
#  'Diffuser outlet diameter [cm]': 50.13,
#  'Blade height at rotor inlet  [cm]': 3.64,
#  'Blade height at rotor outlet  [cm]': 2.25}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 122.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 122.9,
#                       'Absolute tangential rotor outlet': 267.6,
# ...

# %%
LPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 29500,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 3.87,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 7370.72,
#  'Delta enthalpy [kJ/kg]': 1062.85,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 683.52,
#  'Comp. Isentropic eff. [%]': 82.66,
#  'Comp. Polytropic eff. [%]': 84.17}
