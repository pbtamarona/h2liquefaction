# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import compressor

# %%
P_suction= 1.05435000000000 #bar
P_final  = 7.39971000000000 #bar

n_comp   = 3

R        = (P_final/P_suction)**(1/n_comp)

print(R)

# %%
from hydrogen_liquefaction import compressor

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First low-pressure compressor
T_in    = 297.099984716022 #K
P_in    = 1.05435000000000 #bar
P_out   = R*P_in #bar

m       = round(9263.10098893867/3600,4) #kg/s

LPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 2.5731
#
# Inlet Condition
# P [bar]     =  1.054
# T [Kelvin]  =  297.1
# H [kJ/kg]   =  3916.8
# S [kJ/kg.K] =  53.161
#
#
# Isentropic Outlet Condition
# P [bar]     =  2.019
# T [Kelvin]  =  357.94
# H [kJ/kg]   =  4792.512
# S [kJ/kg.K] =  53.161
#
#
# Δh_is [kJ/kg]  =  875.713
# Power_is [kW]  = 2253.296

# %%
#design constraint
u2_max  = 500  #m/s

LPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  4385.574
# Max. RPM =  10505.545

# %%
LPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC1.stagesCalculation(7920,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:128.18
# Compression ratio:1.09
# Power [kW]:329.82
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 107724.75,
#  'Rotor outlet pressure [bar]': 1.13,
#  'Rotor outlet temperature [℃]': 30.73,
#  'Diffuser outlet pressure [bar]': 1.15,
#  'Diffuser outlet temperature [℃]': 32.9,
#  'Polytropic efficiency [%]': 85.52,
#  'Isentropic efficiency [%]': 85.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.587,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 68.41,
#  'Rotor outlet diameter [cm]': 116.53,
#  'Diffuser outlet diameter [cm]': 187.39,
#  'Blade height at rotor inlet  [cm]': 13.81,
#  'Blade height at rotor outlet  [cm]': 8.79}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 126.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 126.3,
#                       'Absolute tangential rotor outlet': 265.2,
#                       'Absolute meridional rotor outlet': 89.0,
#                       'Absolute rotor outlet': 279.8,
#                       'Absolute diffuser outlet': 126.3,
#                       'Relative tangential rotor inlet': 283.7,
#                       'Relative rotor inlet': 310.5,
#                       'Relative tangential rotor outlet': 218.0,
#                       'Relative rotor outlet': 235.5,
#                       'Blade speed rotor inlet': 283.7,
#                       'Blade speed rotor outlet': 483.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.236,
#                   'Ma at rotor outlet': 0.177,
#                   'Ma at difusser inlet': 0.211,
#                   'Ma at difusser outlet': 0.095},
#  'Non-dimensional': {'Specific speed': 0.754,
#                      'Flow coefficient': 0.261,
#                      "Flow coefficient'": 0.053,
#                      'Work coefficient': 0.549,
#                      'Isentropic work coefficient': 0.469,
#                      'Rotor meridional velocity ratio': 0.705,
#                      'Degree of reaction': 0.757},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.45,
#                      'Relative rotor inlet': 66.01,
#                      'Relative rotor outlet': 67.79}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.757
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.45
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.79
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:129.18
# Compression ratio:1.09
# Power [kW]:332.39
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 101611.58,
#  'Rotor outlet pressure [bar]': 1.23,
#  'Rotor outlet temperature [℃]': 39.63,
#  'Diffuser outlet pressure [bar]': 1.25,
#  'Diffuser outlet temperature [℃]': 41.9,
#  'Polytropic efficiency [%]': 85.25,
#  'Isentropic efficiency [%]': 85.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.583,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 67.69,
#  'Rotor outlet diameter [cm]': 116.09,
#  'Diffuser outlet diameter [cm]': 186.37,
#  'Blade height at rotor inlet  [cm]': 13.53,
#  'Blade height at rotor outlet  [cm]': 8.37}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 122.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 122.6,
#                       'Absolute tangential rotor outlet': 267.2,
#                       'Absolute meridional rotor outlet': 88.6,
#                       'Absolute rotor outlet': 281.5,
#                       'Absolute diffuser outlet': 122.6,
#                       'Relative tangential rotor inlet': 280.7,
#                       'Relative rotor inlet': 306.3,
#                       'Relative tangential rotor outlet': 214.2,
#                       'Relative rotor outlet': 231.8,
#                       'Blade speed rotor inlet': 280.7,
#                       'Blade speed rotor outlet': 481.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.23,
#                   'Ma at rotor outlet': 0.172,
#                   'Ma at difusser inlet': 0.209,
#                   'Ma at difusser outlet': 0.091},
#  'Non-dimensional': {'Specific speed': 0.732,
#                      'Flow coefficient': 0.255,
#                      "Flow coefficient'": 0.051,
#                      'Work coefficient': 0.555,
#                      'Isentropic work coefficient': 0.472,
#                      'Rotor meridional velocity ratio': 0.723,
#                      'Degree of reaction': 0.75},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.65,
#                      'Relative rotor inlet': 66.41,
#                      'Relative rotor outlet': 67.53}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.75
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.65
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.53
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 3
# Delta enthalpy [kJ/kg]:130.19
# Compression ratio:1.09
# Power [kW]:334.99
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 95988.83,
#  'Rotor outlet pressure [bar]': 1.34,
#  'Rotor outlet temperature [℃]': 48.58,
#  'Diffuser outlet pressure [bar]': 1.36,
#  'Diffuser outlet temperature [℃]': 50.96,
#  'Polytropic efficiency [%]': 84.96,
#  'Isentropic efficiency [%]': 84.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.579,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 67.02,
#  'Rotor outlet diameter [cm]': 115.68,
#  'Diffuser outlet diameter [cm]': 185.43,
#  'Blade height at rotor inlet  [cm]': 13.26,
#  'Blade height at rotor outlet  [cm]': 7.98}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 119.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 119.0,
#                       'Absolute tangential rotor outlet': 269.1,
#                       'Absolute meridional rotor outlet': 88.3,
#                       'Absolute rotor outlet': 283.2,
#                       'Absolute diffuser outlet': 119.0,
#                       'Relative tangential rotor inlet': 277.9,
#                       'Relative rotor inlet': 302.3,
#                       'Relative tangential rotor outlet': 210.6,
#                       'Relative rotor outlet': 228.4,
#                       'Blade speed rotor inlet': 277.9,
#                       'Blade speed rotor outlet': 479.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.224,
#                   'Ma at rotor outlet': 0.167,
#                   'Ma at difusser inlet': 0.207,
#                   'Ma at difusser outlet': 0.087},
#  'Non-dimensional': {'Specific speed': 0.712,
#                      'Flow coefficient': 0.248,
#                      "Flow coefficient'": 0.048,
#                      'Work coefficient': 0.561,
#                      'Isentropic work coefficient': 0.476,
#                      'Rotor meridional velocity ratio': 0.742,
#                      'Degree of reaction': 0.744},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.83,
#                      'Relative rotor inlet': 66.81,
#                      'Relative rotor outlet': 67.26}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.744
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.83
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.26
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 4
# Delta enthalpy [kJ/kg]:131.21
# Compression ratio:1.09
# Power [kW]:337.61
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 90806.94,
#  'Rotor outlet pressure [bar]': 1.45,
#  'Rotor outlet temperature [℃]': 57.6,
#  'Diffuser outlet pressure [bar]': 1.48,
#  'Diffuser outlet temperature [℃]': 60.07,
#  'Polytropic efficiency [%]': 84.65,
#  'Isentropic efficiency [%]': 84.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.576,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 66.39,
#  'Rotor outlet diameter [cm]': 115.3,
#  'Diffuser outlet diameter [cm]': 184.54,
#  'Blade height at rotor inlet  [cm]': 13.02,
#  'Blade height at rotor outlet  [cm]': 7.6}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 115.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 115.6,
#                       'Absolute tangential rotor outlet': 270.9,
#                       'Absolute meridional rotor outlet': 88.0,
#                       'Absolute rotor outlet': 284.9,
#                       'Absolute diffuser outlet': 115.6,
#                       'Relative tangential rotor inlet': 275.3,
#                       'Relative rotor inlet': 298.6,
#                       'Relative tangential rotor outlet': 207.2,
#                       'Relative rotor outlet': 225.1,
#                       'Blade speed rotor inlet': 275.3,
#                       'Blade speed rotor outlet': 478.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.218,
#                   'Ma at rotor outlet': 0.163,
#                   'Ma at difusser inlet': 0.206,
#                   'Ma at difusser outlet': 0.083},
#  'Non-dimensional': {'Specific speed': 0.692,
#                      'Flow coefficient': 0.242,
#                      "Flow coefficient'": 0.046,
#                      'Work coefficient': 0.567,
#                      'Isentropic work coefficient': 0.479,
#                      'Rotor meridional velocity ratio': 0.762,
#                      'Degree of reaction': 0.738},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.0,
#                      'Relative rotor inlet': 67.23,
#                      'Relative rotor outlet': 66.98}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.738
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.0
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.98
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:132.23
# Compression ratio:1.08
# Power [kW]:340.25
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 86022.35,
#  'Rotor outlet pressure [bar]': 1.57,
#  'Rotor outlet temperature [℃]': 66.67,
#  'Diffuser outlet pressure [bar]': 1.6,
#  'Diffuser outlet temperature [℃]': 69.24,
#  'Polytropic efficiency [%]': 84.32,
#  'Isentropic efficiency [%]': 84.2}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.572,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 65.8,
#  'Rotor outlet diameter [cm]': 114.94,
#  'Diffuser outlet diameter [cm]': 183.71,
#  'Blade height at rotor inlet  [cm]': 12.79,
#  'Blade height at rotor outlet  [cm]': 7.25}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 112.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 112.2,
#                       'Absolute tangential rotor outlet': 272.7,
#                       'Absolute meridional rotor outlet': 87.8,
#                       'Absolute rotor outlet': 286.5,
#                       'Absolute diffuser outlet': 112.2,
#                       'Relative tangential rotor inlet': 272.9,
#                       'Relative rotor inlet': 295.0,
#                       'Relative tangential rotor outlet': 203.9,
#                       'Relative rotor outlet': 222.0,
#                       'Blade speed rotor inlet': 272.9,
#                       'Blade speed rotor outlet': 476.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.212,
#                   'Ma at rotor outlet': 0.158,
#                   'Ma at difusser inlet': 0.204,
#                   'Ma at difusser outlet': 0.08},
#  'Non-dimensional': {'Specific speed': 0.674,
#                      'Flow coefficient': 0.235,
#                      "Flow coefficient'": 0.044,
#                      'Work coefficient': 0.572,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.783,
#                      'Degree of reaction': 0.733},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.15,
#                      'Relative rotor inlet': 67.65,
#                      'Relative rotor outlet': 66.7}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.733
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.15
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.7
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 6
# Delta enthalpy [kJ/kg]:133.43
# Compression ratio:1.08
# Power [kW]:343.32
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 81596.62,
#  'Rotor outlet pressure [bar]': 1.7,
#  'Rotor outlet temperature [℃]': 75.82,
#  'Diffuser outlet pressure [bar]': 1.74,
#  'Diffuser outlet temperature [℃]': 78.48,
#  'Polytropic efficiency [%]': 83.97,
#  'Isentropic efficiency [%]': 83.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.569,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 65.25,
#  'Rotor outlet diameter [cm]': 114.61,
#  'Diffuser outlet diameter [cm]': 182.94,
#  'Blade height at rotor inlet  [cm]': 12.57,
#  'Blade height at rotor outlet  [cm]': 6.91}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 109.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 109.0,
#                       'Absolute tangential rotor outlet': 274.8,
#                       'Absolute meridional rotor outlet': 87.8,
#                       'Absolute rotor outlet': 288.5,
#                       'Absolute diffuser outlet': 109.0,
#                       'Relative tangential rotor inlet': 270.6,
#                       'Relative rotor inlet': 291.7,
#                       'Relative tangential rotor outlet': 200.4,
#                       'Relative rotor outlet': 218.8,
#                       'Blade speed rotor inlet': 270.6,
#                       'Blade speed rotor outlet': 475.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.207,
#                   'Ma at rotor outlet': 0.154,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.076},
#  'Non-dimensional': {'Specific speed': 0.656,
#                      'Flow coefficient': 0.229,
#                      "Flow coefficient'": 0.042,
#                      'Work coefficient': 0.578,
#                      'Isentropic work coefficient': 0.485,
#                      'Rotor meridional velocity ratio': 0.806,
#                      'Degree of reaction': 0.727},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.29,
#                      'Relative rotor inlet': 68.07,
#                      'Relative rotor outlet': 66.35}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.727
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.29
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.35
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 7
# Delta enthalpy [kJ/kg]:134.47
# Compression ratio:1.08
# Power [kW]:346.02
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 77498.19,
#  'Rotor outlet pressure [bar]': 1.83,
#  'Rotor outlet temperature [℃]': 85.03,
#  'Diffuser outlet pressure [bar]': 1.87,
#  'Diffuser outlet temperature [℃]': 87.79,
#  'Polytropic efficiency [%]': 83.61,
#  'Isentropic efficiency [%]': 83.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.566,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 64.74,
#  'Rotor outlet diameter [cm]': 114.29,
#  'Diffuser outlet diameter [cm]': 182.21,
#  'Blade height at rotor inlet  [cm]': 12.37,
#  'Blade height at rotor outlet  [cm]': 6.6}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 105.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 105.8,
#                       'Absolute tangential rotor outlet': 276.6,
#                       'Absolute meridional rotor outlet': 87.7,
#                       'Absolute rotor outlet': 290.2,
#                       'Absolute diffuser outlet': 105.8,
#                       'Relative tangential rotor inlet': 268.5,
#                       'Relative rotor inlet': 288.6,
#                       'Relative tangential rotor outlet': 197.4,
#                       'Relative rotor outlet': 216.0,
#                       'Blade speed rotor inlet': 268.5,
#                       'Blade speed rotor outlet': 474.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.202,
#                   'Ma at rotor outlet': 0.15,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.073},
#  'Non-dimensional': {'Specific speed': 0.639,
#                      'Flow coefficient': 0.223,
#                      "Flow coefficient'": 0.04,
#                      'Work coefficient': 0.584,
#                      'Isentropic work coefficient': 0.487,
#                      'Rotor meridional velocity ratio': 0.829,
#                      'Degree of reaction': 0.722},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.41,
#                      'Relative rotor inlet': 68.49,
#                      'Relative rotor outlet': 66.05}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.722
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.41
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.05
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 8
# Delta enthalpy [kJ/kg]:135.7
# Compression ratio:1.08
# Power [kW]:349.16
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 73694.21,
#  'Rotor outlet pressure [bar]': 1.97,
#  'Rotor outlet temperature [℃]': 94.31,
#  'Diffuser outlet pressure [bar]': 2.02,
#  'Diffuser outlet temperature [℃]': 97.17,
#  'Polytropic efficiency [%]': 83.23,
#  'Isentropic efficiency [%]': 83.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 64.25,
#  'Rotor outlet diameter [cm]': 114.0,
#  'Diffuser outlet diameter [cm]': 181.53,
#  'Blade height at rotor inlet  [cm]': 12.18,
#  'Blade height at rotor outlet  [cm]': 6.3}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 102.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 102.8,
#                       'Absolute tangential rotor outlet': 278.7,
#                       'Absolute meridional rotor outlet': 87.7,
#                       'Absolute rotor outlet': 292.1,
#                       'Absolute diffuser outlet': 102.8,
#                       'Relative tangential rotor inlet': 266.4,
#                       'Relative rotor inlet': 285.6,
#                       'Relative tangential rotor outlet': 194.1,
#                       'Relative rotor outlet': 213.0,
#                       'Blade speed rotor inlet': 266.4,
#                       'Blade speed rotor outlet': 472.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.198,
#                   'Ma at rotor outlet': 0.146,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.07},
#  'Non-dimensional': {'Specific speed': 0.624,
#                      'Flow coefficient': 0.217,
#                      "Flow coefficient'": 0.038,
#                      'Work coefficient': 0.589,
#                      'Isentropic work coefficient': 0.49,
#                      'Rotor meridional velocity ratio': 0.854,
#                      'Degree of reaction': 0.716},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.53,
#                      'Relative rotor inlet': 68.91,
#                      'Relative rotor outlet': 65.68}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.716
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.53
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.68
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
LPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 2.5731,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 7920,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 1.05,
#  'Inlet temperature [C]': 23.95,
#  'Inlet volumetric [m3/h]': 107724.75,
#  'Delta enthalpy [kJ/kg]': 1054.58,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 2713.55,
#  'Comp. Isentropic eff. [%]': 83.04,
#  'Comp. Polytropic eff. [%]': 84.51}

# %%
#Second low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = P_out
print(P_in)
P_out   = R*P_in #bar

LPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)
# Out:
# 2.018651899815818

# %%
LPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 2.5731
#
# Inlet Condition
# P [bar]     =  2.019
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3932.233
# S [kJ/kg.K] =  50.532
#
#
# Isentropic Outlet Condition
# P [bar]     =  3.865
# T [Kelvin]  =  359.2
# H [kJ/kg]   =  4811.685
# S [kJ/kg.K] =  50.532
#
#
# Δh_is [kJ/kg]  =  879.451
# Power_is [kW]  = 2262.917

# %%
#design constraint
u2_max  = 500  #m/s

LPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  6074.303
# Max. RPM =  14553.117

# %%
LPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC2.stagesCalculation(10540,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:129.33
# Compression ratio:1.09
# Power [kW]:332.78
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 56495.79,
#  'Rotor outlet pressure [bar]': 2.16,
#  'Rotor outlet temperature [℃]': 31.75,
#  'Diffuser outlet pressure [bar]': 2.2,
#  'Diffuser outlet temperature [℃]': 34.02,
#  'Polytropic efficiency [%]': 85.14,
#  'Isentropic efficiency [%]': 85.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.582,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 50.78,
#  'Rotor outlet diameter [cm]': 87.3,
#  'Diffuser outlet diameter [cm]': 140.07,
#  'Blade height at rotor inlet  [cm]': 10.11,
#  'Blade height at rotor outlet  [cm]': 6.18}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 121.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 121.5,
#                       'Absolute tangential rotor outlet': 268.4,
#                       'Absolute meridional rotor outlet': 88.7,
#                       'Absolute rotor outlet': 282.7,
#                       'Absolute diffuser outlet': 121.5,
#                       'Relative tangential rotor inlet': 280.2,
#                       'Relative rotor inlet': 305.4,
#                       'Relative tangential rotor outlet': 213.4,
#                       'Relative rotor outlet': 231.0,
#                       'Blade speed rotor inlet': 280.2,
#                       'Blade speed rotor outlet': 481.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.232,
#                   'Ma at rotor outlet': 0.174,
#                   'Ma at difusser inlet': 0.212,
#                   'Ma at difusser outlet': 0.091},
#  'Non-dimensional': {'Specific speed': 0.724,
#                      'Flow coefficient': 0.252,
#                      "Flow coefficient'": 0.037,
#                      'Work coefficient': 0.557,
#                      'Isentropic work coefficient': 0.474,
#                      'Rotor meridional velocity ratio': 0.73,
#                      'Degree of reaction': 0.748},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.72,
#                      'Relative rotor inlet': 66.56,
#                      'Relative rotor outlet': 67.44}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.748
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.72
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.44
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:130.36
# Compression ratio:1.09
# Power [kW]:335.44
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 53298.55,
#  'Rotor outlet pressure [bar]': 2.35,
#  'Rotor outlet temperature [℃]': 40.73,
#  'Diffuser outlet pressure [bar]': 2.4,
#  'Diffuser outlet temperature [℃]': 43.1,
#  'Polytropic efficiency [%]': 84.83,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.578,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 50.27,
#  'Rotor outlet diameter [cm]': 86.99,
#  'Diffuser outlet diameter [cm]': 139.35,
#  'Blade height at rotor inlet  [cm]': 9.91,
#  'Blade height at rotor outlet  [cm]': 5.88}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 117.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 117.8,
#                       'Absolute tangential rotor outlet': 270.3,
#                       'Absolute meridional rotor outlet': 88.3,
#                       'Absolute rotor outlet': 284.4,
#                       'Absolute diffuser outlet': 117.8,
#                       'Relative tangential rotor inlet': 277.4,
#                       'Relative rotor inlet': 301.4,
#                       'Relative tangential rotor outlet': 209.7,
#                       'Relative rotor outlet': 227.6,
#                       'Blade speed rotor inlet': 277.4,
#                       'Blade speed rotor outlet': 480.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.226,
#                   'Ma at rotor outlet': 0.169,
#                   'Ma at difusser inlet': 0.211,
#                   'Ma at difusser outlet': 0.087},
#  'Non-dimensional': {'Specific speed': 0.703,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.035,
#                      'Work coefficient': 0.563,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.75,
#                      'Degree of reaction': 0.742},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.9,
#                      'Relative rotor inlet': 66.98,
#                      'Relative rotor outlet': 67.16}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.742
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.9
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.16
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 3
# Delta enthalpy [kJ/kg]:131.4
# Compression ratio:1.09
# Power [kW]:338.11
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 50357.64,
#  'Rotor outlet pressure [bar]': 2.55,
#  'Rotor outlet temperature [℃]': 49.76,
#  'Diffuser outlet pressure [bar]': 2.61,
#  'Diffuser outlet temperature [℃]': 52.23,
#  'Polytropic efficiency [%]': 84.5,
#  'Isentropic efficiency [%]': 84.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 49.79,
#  'Rotor outlet diameter [cm]': 86.7,
#  'Diffuser outlet diameter [cm]': 138.68,
#  'Blade height at rotor inlet  [cm]': 9.72,
#  'Blade height at rotor outlet  [cm]': 5.6}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 114.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 114.3,
#                       'Absolute tangential rotor outlet': 272.2,
#                       'Absolute meridional rotor outlet': 88.1,
#                       'Absolute rotor outlet': 286.1,
#                       'Absolute diffuser outlet': 114.3,
#                       'Relative tangential rotor inlet': 274.8,
#                       'Relative rotor inlet': 297.6,
#                       'Relative tangential rotor outlet': 206.3,
#                       'Relative rotor outlet': 224.3,
#                       'Blade speed rotor inlet': 274.8,
#                       'Blade speed rotor outlet': 478.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.22,
#                   'Ma at rotor outlet': 0.164,
#                   'Ma at difusser inlet': 0.209,
#                   'Ma at difusser outlet': 0.083},
#  'Non-dimensional': {'Specific speed': 0.684,
#                      'Flow coefficient': 0.239,
#                      "Flow coefficient'": 0.034,
#                      'Work coefficient': 0.569,
#                      'Isentropic work coefficient': 0.48,
#                      'Rotor meridional velocity ratio': 0.771,
#                      'Degree of reaction': 0.736},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.07,
#                      'Relative rotor inlet': 67.41,
#                      'Relative rotor outlet': 66.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.736
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.07
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:132.6
# Compression ratio:1.09
# Power [kW]:341.21
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 47647.18,
#  'Rotor outlet pressure [bar]': 2.77,
#  'Rotor outlet temperature [℃]': 58.86,
#  'Diffuser outlet pressure [bar]': 2.84,
#  'Diffuser outlet temperature [℃]': 61.43,
#  'Polytropic efficiency [%]': 84.15,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 49.35,
#  'Rotor outlet diameter [cm]': 86.43,
#  'Diffuser outlet diameter [cm]': 138.06,
#  'Blade height at rotor inlet  [cm]': 9.55,
#  'Blade height at rotor outlet  [cm]': 5.33}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 110.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 110.9,
#                       'Absolute tangential rotor outlet': 274.4,
#                       'Absolute meridional rotor outlet': 88.0,
#                       'Absolute rotor outlet': 288.1,
#                       'Absolute diffuser outlet': 110.9,
#                       'Relative tangential rotor inlet': 272.3,
#                       'Relative rotor inlet': 294.0,
#                       'Relative tangential rotor outlet': 202.6,
#                       'Relative rotor outlet': 220.9,
#                       'Blade speed rotor inlet': 272.3,
#                       'Blade speed rotor outlet': 477.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.214,
#                   'Ma at rotor outlet': 0.159,
#                   'Ma at difusser inlet': 0.208,
#                   'Ma at difusser outlet': 0.08},
#  'Non-dimensional': {'Specific speed': 0.665,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.032,
#                      'Work coefficient': 0.575,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.794,
#                      'Degree of reaction': 0.73},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.22,
#                      'Relative rotor inlet': 67.85,
#                      'Relative rotor outlet': 66.52}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.73
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.22
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.52
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:133.67
# Compression ratio:1.08
# Power [kW]:343.93
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 45145.87,
#  'Rotor outlet pressure [bar]': 3.0,
#  'Rotor outlet temperature [℃]': 68.03,
#  'Diffuser outlet pressure [bar]': 3.07,
#  'Diffuser outlet temperature [℃]': 70.7,
#  'Polytropic efficiency [%]': 83.79,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 48.93,
#  'Rotor outlet diameter [cm]': 86.18,
#  'Diffuser outlet diameter [cm]': 137.47,
#  'Blade height at rotor inlet  [cm]': 9.39,
#  'Blade height at rotor outlet  [cm]': 5.08}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 107.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 107.5,
#                       'Absolute tangential rotor outlet': 276.2,
#                       'Absolute meridional rotor outlet': 87.9,
#                       'Absolute rotor outlet': 289.8,
#                       'Absolute diffuser outlet': 107.5,
#                       'Relative tangential rotor inlet': 270.0,
#                       'Relative rotor inlet': 290.7,
#                       'Relative tangential rotor outlet': 199.4,
#                       'Relative rotor outlet': 217.9,
#                       'Blade speed rotor inlet': 270.0,
#                       'Blade speed rotor outlet': 475.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.209,
#                   'Ma at rotor outlet': 0.155,
#                   'Ma at difusser inlet': 0.206,
#                   'Ma at difusser outlet': 0.076},
#  'Non-dimensional': {'Specific speed': 0.647,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.031,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.817,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.28,
#                      'Relative rotor outlet': 66.22}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.22
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 6
# Delta enthalpy [kJ/kg]:134.9
# Compression ratio:1.08
# Power [kW]:347.1
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 42831.98,
#  'Rotor outlet pressure [bar]': 3.25,
#  'Rotor outlet temperature [℃]': 77.26,
#  'Diffuser outlet pressure [bar]': 3.32,
#  'Diffuser outlet temperature [℃]': 80.03,
#  'Polytropic efficiency [%]': 83.41,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 48.54,
#  'Rotor outlet diameter [cm]': 85.94,
#  'Diffuser outlet diameter [cm]': 136.92,
#  'Blade height at rotor inlet  [cm]': 9.23,
#  'Blade height at rotor outlet  [cm]': 4.84}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 104.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 104.3,
#                       'Absolute tangential rotor outlet': 278.3,
#                       'Absolute meridional rotor outlet': 87.9,
#                       'Absolute rotor outlet': 291.8,
#                       'Absolute diffuser outlet': 104.3,
#                       'Relative tangential rotor inlet': 267.9,
#                       'Relative rotor inlet': 287.5,
#                       'Relative tangential rotor outlet': 196.0,
#                       'Relative rotor outlet': 214.8,
#                       'Blade speed rotor inlet': 267.9,
#                       'Blade speed rotor outlet': 474.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.204,
#                   'Ma at rotor outlet': 0.151,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.073},
#  'Non-dimensional': {'Specific speed': 0.631,
#                      'Flow coefficient': 0.22,
#                      "Flow coefficient'": 0.029,
#                      'Work coefficient': 0.587,
#                      'Isentropic work coefficient': 0.489,
#                      'Rotor meridional velocity ratio': 0.842,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.48,
#                      'Relative rotor inlet': 68.72,
#                      'Relative rotor outlet': 65.86}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.48
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.86
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 7
# Delta enthalpy [kJ/kg]:136.14
# Compression ratio:1.08
# Power [kW]:350.31
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 40689.06,
#  'Rotor outlet pressure [bar]': 3.5,
#  'Rotor outlet temperature [℃]': 86.57,
#  'Diffuser outlet pressure [bar]': 3.59,
#  'Diffuser outlet temperature [℃]': 89.45,
#  'Polytropic efficiency [%]': 83.01,
#  'Isentropic efficiency [%]': 82.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.562,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 48.18,
#  'Rotor outlet diameter [cm]': 85.72,
#  'Diffuser outlet diameter [cm]': 136.41,
#  'Blade height at rotor inlet  [cm]': 9.09,
#  'Blade height at rotor outlet  [cm]': 4.61}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 101.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 101.2,
#                       'Absolute tangential rotor outlet': 280.3,
#                       'Absolute meridional rotor outlet': 87.9,
#                       'Absolute rotor outlet': 293.8,
#                       'Absolute diffuser outlet': 101.2,
#                       'Relative tangential rotor inlet': 265.9,
#                       'Relative rotor inlet': 284.5,
#                       'Relative tangential rotor outlet': 192.7,
#                       'Relative rotor outlet': 211.8,
#                       'Blade speed rotor inlet': 265.9,
#                       'Blade speed rotor outlet': 473.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.199,
#                   'Ma at rotor outlet': 0.147,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.07},
#  'Non-dimensional': {'Specific speed': 0.615,
#                      'Flow coefficient': 0.214,
#                      "Flow coefficient'": 0.028,
#                      'Work coefficient': 0.593,
#                      'Isentropic work coefficient': 0.491,
#                      'Rotor meridional velocity ratio': 0.868,
#                      'Degree of reaction': 0.713},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.59,
#                      'Relative rotor inlet': 69.16,
#                      'Relative rotor outlet': 65.48}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.713
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.59
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.48
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 8
# Delta enthalpy [kJ/kg]:137.41
# Compression ratio:1.08
# Power [kW]:353.57
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 38701.15,
#  'Rotor outlet pressure [bar]': 3.78,
#  'Rotor outlet temperature [℃]': 95.97,
#  'Diffuser outlet pressure [bar]': 3.86,
#  'Diffuser outlet temperature [℃]': 98.94,
#  'Polytropic efficiency [%]': 82.6,
#  'Isentropic efficiency [%]': 82.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.56,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 47.84,
#  'Rotor outlet diameter [cm]': 85.51,
#  'Diffuser outlet diameter [cm]': 135.93,
#  'Blade height at rotor inlet  [cm]': 8.96,
#  'Blade height at rotor outlet  [cm]': 4.4}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 98.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 98.2,
#                       'Absolute tangential rotor outlet': 282.4,
#                       'Absolute meridional rotor outlet': 88.0,
#                       'Absolute rotor outlet': 295.8,
#                       'Absolute diffuser outlet': 98.2,
#                       'Relative tangential rotor inlet': 264.0,
#                       'Relative rotor inlet': 281.7,
#                       'Relative tangential rotor outlet': 189.5,
#                       'Relative rotor outlet': 209.0,
#                       'Blade speed rotor inlet': 264.0,
#                       'Blade speed rotor outlet': 471.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.194,
#                   'Ma at rotor outlet': 0.143,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.067},
#  'Non-dimensional': {'Specific speed': 0.599,
#                      'Flow coefficient': 0.208,
#                      "Flow coefficient'": 0.027,
#                      'Work coefficient': 0.598,
#                      'Isentropic work coefficient': 0.494,
#                      'Rotor meridional velocity ratio': 0.896,
#                      'Degree of reaction': 0.708},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.69,
#                      'Relative rotor inlet': 69.59,
#                      'Relative rotor outlet': 65.1}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.708
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.69
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.1
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.35

# %%
LPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 2.5731,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 10540,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 2.02,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 56495.79,
#  'Delta enthalpy [kJ/kg]': 1065.82,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 2742.45,
#  'Comp. Isentropic eff. [%]': 82.51,
#  'Comp. Polytropic eff. [%]': 84.03}

# %%
#Third low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = P_out
print(P_in)
P_out   = R*P_in #bar

LPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)
# Out:
# 3.8648982715701727

# %%
LPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 2.5731
#
# Inlet Condition
# P [bar]     =  3.865
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3933.026
# S [kJ/kg.K] =  47.851
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.4
# T [Kelvin]  =  359.2
# H [kJ/kg]   =  4813.748
# S [kJ/kg.K] =  47.851
#
#
# Δh_is [kJ/kg]  =  880.722
# Power_is [kW]  = 2266.185

# %%
#design constraint
u2_max  = 500  #m/s

LPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  8
# Max. number of stage =  10

# %%
LPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  8406.736
# Max. RPM =  20147.882

# %%
LPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC3.stagesCalculation(14780,8,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:129.37
# Compression ratio:1.09
# Power [kW]:332.87
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 29539.93,
#  'Rotor outlet pressure [bar]': 4.13,
#  'Rotor outlet temperature [℃]': 31.77,
#  'Diffuser outlet pressure [bar]': 4.22,
#  'Diffuser outlet temperature [℃]': 34.02,
#  'Polytropic efficiency [%]': 85.27,
#  'Isentropic efficiency [%]': 85.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.583,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 36.4,
#  'Rotor outlet diameter [cm]': 62.4,
#  'Diffuser outlet diameter [cm]': 100.19,
#  'Blade height at rotor inlet  [cm]': 7.28,
#  'Blade height at rotor outlet  [cm]': 4.51}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 123.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 123.2,
#                       'Absolute tangential rotor outlet': 267.9,
#                       'Absolute meridional rotor outlet': 88.9,
#                       'Absolute rotor outlet': 282.3,
#                       'Absolute diffuser outlet': 123.2,
#                       'Relative tangential rotor inlet': 281.7,
#                       'Relative rotor inlet': 307.5,
#                       'Relative tangential rotor outlet': 215.0,
#                       'Relative rotor outlet': 232.7,
#                       'Blade speed rotor inlet': 281.7,
#                       'Blade speed rotor outlet': 482.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.233,
#                   'Ma at rotor outlet': 0.175,
#                   'Ma at difusser inlet': 0.212,
#                   'Ma at difusser outlet': 0.092},
#  'Non-dimensional': {'Specific speed': 0.734,
#                      'Flow coefficient': 0.255,
#                      "Flow coefficient'": 0.027,
#                      'Work coefficient': 0.555,
#                      'Isentropic work coefficient': 0.472,
#                      'Rotor meridional velocity ratio': 0.722,
#                      'Degree of reaction': 0.751},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.64,
#                      'Relative rotor inlet': 66.38,
#                      'Relative rotor outlet': 67.54}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.751
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.64
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.54
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:130.39
# Compression ratio:1.09
# Power [kW]:335.51
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 27869.05,
#  'Rotor outlet pressure [bar]': 4.5,
#  'Rotor outlet temperature [℃]': 40.74,
#  'Diffuser outlet pressure [bar]': 4.6,
#  'Diffuser outlet temperature [℃]': 43.09,
#  'Polytropic efficiency [%]': 84.97,
#  'Isentropic efficiency [%]': 84.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.579,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 36.03,
#  'Rotor outlet diameter [cm]': 62.18,
#  'Diffuser outlet diameter [cm]': 99.67,
#  'Blade height at rotor inlet  [cm]': 7.13,
#  'Blade height at rotor outlet  [cm]': 4.29}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 119.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 119.5,
#                       'Absolute tangential rotor outlet': 269.8,
#                       'Absolute meridional rotor outlet': 88.6,
#                       'Absolute rotor outlet': 284.0,
#                       'Absolute diffuser outlet': 119.5,
#                       'Relative tangential rotor inlet': 278.8,
#                       'Relative rotor inlet': 303.4,
#                       'Relative tangential rotor outlet': 211.4,
#                       'Relative rotor outlet': 229.2,
#                       'Blade speed rotor inlet': 278.8,
#                       'Blade speed rotor outlet': 481.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.227,
#                   'Ma at rotor outlet': 0.17,
#                   'Ma at difusser inlet': 0.21,
#                   'Ma at difusser outlet': 0.088},
#  'Non-dimensional': {'Specific speed': 0.713,
#                      'Flow coefficient': 0.248,
#                      "Flow coefficient'": 0.026,
#                      'Work coefficient': 0.561,
#                      'Isentropic work coefficient': 0.475,
#                      'Rotor meridional velocity ratio': 0.741,
#                      'Degree of reaction': 0.744},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.83,
#                      'Relative rotor inlet': 66.8,
#                      'Relative rotor outlet': 67.26}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.744
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.83
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.26
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 3
# Delta enthalpy [kJ/kg]:131.43
# Compression ratio:1.09
# Power [kW]:338.17
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 26332.34,
#  'Rotor outlet pressure [bar]': 4.89,
#  'Rotor outlet temperature [℃]': 49.77,
#  'Diffuser outlet pressure [bar]': 5.0,
#  'Diffuser outlet temperature [℃]': 52.21,
#  'Polytropic efficiency [%]': 84.66,
#  'Isentropic efficiency [%]': 84.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.576,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 35.68,
#  'Rotor outlet diameter [cm]': 61.97,
#  'Diffuser outlet diameter [cm]': 99.18,
#  'Blade height at rotor inlet  [cm]': 7.0,
#  'Blade height at rotor outlet  [cm]': 4.09}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 116.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 116.0,
#                       'Absolute tangential rotor outlet': 271.7,
#                       'Absolute meridional rotor outlet': 88.3,
#                       'Absolute rotor outlet': 285.7,
#                       'Absolute diffuser outlet': 116.0,
#                       'Relative tangential rotor inlet': 276.2,
#                       'Relative rotor inlet': 299.5,
#                       'Relative tangential rotor outlet': 207.9,
#                       'Relative rotor outlet': 225.8,
#                       'Blade speed rotor inlet': 276.2,
#                       'Blade speed rotor outlet': 479.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.221,
#                   'Ma at rotor outlet': 0.165,
#                   'Ma at difusser inlet': 0.208,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.693,
#                      'Flow coefficient': 0.242,
#                      "Flow coefficient'": 0.025,
#                      'Work coefficient': 0.567,
#                      'Isentropic work coefficient': 0.479,
#                      'Rotor meridional velocity ratio': 0.761,
#                      'Degree of reaction': 0.738},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.0,
#                      'Relative rotor inlet': 67.22,
#                      'Relative rotor outlet': 66.98}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.738
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.0
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.98
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:132.47
# Compression ratio:1.09
# Power [kW]:340.85
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 24916.23,
#  'Rotor outlet pressure [bar]': 5.31,
#  'Rotor outlet temperature [℃]': 58.85,
#  'Diffuser outlet pressure [bar]': 5.43,
#  'Diffuser outlet temperature [℃]': 61.39,
#  'Polytropic efficiency [%]': 84.32,
#  'Isentropic efficiency [%]': 84.2}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.572,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 35.36,
#  'Rotor outlet diameter [cm]': 61.77,
#  'Diffuser outlet diameter [cm]': 98.73,
#  'Blade height at rotor inlet  [cm]': 6.87,
#  'Blade height at rotor outlet  [cm]': 3.89}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 112.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 112.5,
#                       'Absolute tangential rotor outlet': 273.5,
#                       'Absolute meridional rotor outlet': 88.1,
#                       'Absolute rotor outlet': 287.4,
#                       'Absolute diffuser outlet': 112.5,
#                       'Relative tangential rotor inlet': 273.7,
#                       'Relative rotor inlet': 295.9,
#                       'Relative tangential rotor outlet': 204.5,
#                       'Relative rotor outlet': 222.7,
#                       'Blade speed rotor inlet': 273.7,
#                       'Blade speed rotor outlet': 478.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.215,
#                   'Ma at rotor outlet': 0.16,
#                   'Ma at difusser inlet': 0.207,
#                   'Ma at difusser outlet': 0.081},
#  'Non-dimensional': {'Specific speed': 0.674,
#                      'Flow coefficient': 0.235,
#                      "Flow coefficient'": 0.023,
#                      'Work coefficient': 0.572,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.783,
#                      'Degree of reaction': 0.733},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.15,
#                      'Relative rotor inlet': 67.65,
#                      'Relative rotor outlet': 66.7}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.733
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.15
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.7
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:133.68
# Compression ratio:1.08
# Power [kW]:343.96
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 23608.79,
#  'Rotor outlet pressure [bar]': 5.75,
#  'Rotor outlet temperature [℃]': 68.0,
#  'Diffuser outlet pressure [bar]': 5.88,
#  'Diffuser outlet temperature [℃]': 70.64,
#  'Polytropic efficiency [%]': 83.97,
#  'Isentropic efficiency [%]': 83.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.569,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 35.06,
#  'Rotor outlet diameter [cm]': 61.59,
#  'Diffuser outlet diameter [cm]': 98.3,
#  'Blade height at rotor inlet  [cm]': 6.75,
#  'Blade height at rotor outlet  [cm]': 3.71}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 109.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 109.2,
#                       'Absolute tangential rotor outlet': 275.6,
#                       'Absolute meridional rotor outlet': 88.0,
#                       'Absolute rotor outlet': 289.4,
#                       'Absolute diffuser outlet': 109.2,
#                       'Relative tangential rotor inlet': 271.3,
#                       'Relative rotor inlet': 292.5,
#                       'Relative tangential rotor outlet': 200.9,
#                       'Relative rotor outlet': 219.4,
#                       'Blade speed rotor inlet': 271.3,
#                       'Blade speed rotor outlet': 476.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.21,
#                   'Ma at rotor outlet': 0.156,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.077},
#  'Non-dimensional': {'Specific speed': 0.656,
#                      'Flow coefficient': 0.229,
#                      "Flow coefficient'": 0.022,
#                      'Work coefficient': 0.578,
#                      'Isentropic work coefficient': 0.485,
#                      'Rotor meridional velocity ratio': 0.806,
#                      'Degree of reaction': 0.727},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.29,
#                      'Relative rotor inlet': 68.07,
#                      'Relative rotor outlet': 66.34}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.727
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.29
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.34
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 6
# Delta enthalpy [kJ/kg]:134.74
# Compression ratio:1.08
# Power [kW]:346.7
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 22400.22,
#  'Rotor outlet pressure [bar]': 6.22,
#  'Rotor outlet temperature [℃]': 77.22,
#  'Diffuser outlet pressure [bar]': 6.36,
#  'Diffuser outlet temperature [℃]': 79.96,
#  'Polytropic efficiency [%]': 83.6,
#  'Isentropic efficiency [%]': 83.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.566,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 34.78,
#  'Rotor outlet diameter [cm]': 61.41,
#  'Diffuser outlet diameter [cm]': 97.9,
#  'Blade height at rotor inlet  [cm]': 6.64,
#  'Blade height at rotor outlet  [cm]': 3.54}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 106.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 106.0,
#                       'Absolute tangential rotor outlet': 277.4,
#                       'Absolute meridional rotor outlet': 87.9,
#                       'Absolute rotor outlet': 291.0,
#                       'Absolute diffuser outlet': 106.0,
#                       'Relative tangential rotor inlet': 269.1,
#                       'Relative rotor inlet': 289.3,
#                       'Relative tangential rotor outlet': 197.8,
#                       'Relative rotor outlet': 216.5,
#                       'Blade speed rotor inlet': 269.1,
#                       'Blade speed rotor outlet': 475.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.205,
#                   'Ma at rotor outlet': 0.152,
#                   'Ma at difusser inlet': 0.204,
#                   'Ma at difusser outlet': 0.074},
#  'Non-dimensional': {'Specific speed': 0.639,
#                      'Flow coefficient': 0.223,
#                      "Flow coefficient'": 0.021,
#                      'Work coefficient': 0.584,
#                      'Isentropic work coefficient': 0.487,
#                      'Rotor meridional velocity ratio': 0.829,
#                      'Degree of reaction': 0.721},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.42,
#                      'Relative rotor inlet': 68.51,
#                      'Relative rotor outlet': 66.04}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.721
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.42
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.04
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 7
# Delta enthalpy [kJ/kg]:135.98
# Compression ratio:1.08
# Power [kW]:349.88
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 21280.4,
#  'Rotor outlet pressure [bar]': 6.71,
#  'Rotor outlet temperature [℃]': 86.51,
#  'Diffuser outlet pressure [bar]': 6.87,
#  'Diffuser outlet temperature [℃]': 89.35,
#  'Polytropic efficiency [%]': 83.21,
#  'Isentropic efficiency [%]': 83.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.563,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 34.51,
#  'Rotor outlet diameter [cm]': 61.25,
#  'Diffuser outlet diameter [cm]': 97.53,
#  'Blade height at rotor inlet  [cm]': 6.54,
#  'Blade height at rotor outlet  [cm]': 3.37}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 102.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 102.9,
#                       'Absolute tangential rotor outlet': 279.5,
#                       'Absolute meridional rotor outlet': 87.9,
#                       'Absolute rotor outlet': 293.0,
#                       'Absolute diffuser outlet': 102.9,
#                       'Relative tangential rotor inlet': 267.1,
#                       'Relative rotor inlet': 286.2,
#                       'Relative tangential rotor outlet': 194.5,
#                       'Relative rotor outlet': 213.5,
#                       'Blade speed rotor inlet': 267.1,
#                       'Blade speed rotor outlet': 474.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.2,
#                   'Ma at rotor outlet': 0.148,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.623,
#                      'Flow coefficient': 0.217,
#                      "Flow coefficient'": 0.02,
#                      'Work coefficient': 0.59,
#                      'Isentropic work coefficient': 0.49,
#                      'Rotor meridional velocity ratio': 0.855,
#                      'Degree of reaction': 0.716},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.53,
#                      'Relative rotor inlet': 68.94,
#                      'Relative rotor outlet': 65.67}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.716
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.53
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.67
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 8
# Delta enthalpy [kJ/kg]:137.23
# Compression ratio:1.08
# Power [kW]:353.11
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 20241.73,
#  'Rotor outlet pressure [bar]': 7.23,
#  'Rotor outlet temperature [℃]': 95.87,
#  'Diffuser outlet pressure [bar]': 7.4,
#  'Diffuser outlet temperature [℃]': 98.81,
#  'Polytropic efficiency [%]': 82.81,
#  'Isentropic efficiency [%]': 82.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.561,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 34.27,
#  'Rotor outlet diameter [cm]': 61.1,
#  'Diffuser outlet diameter [cm]': 97.18,
#  'Blade height at rotor inlet  [cm]': 6.44,
#  'Blade height at rotor outlet  [cm]': 3.22}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 99.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 99.9,
#                       'Absolute tangential rotor outlet': 281.5,
#                       'Absolute meridional rotor outlet': 88.0,
#                       'Absolute rotor outlet': 295.0,
#                       'Absolute diffuser outlet': 99.9,
#                       'Relative tangential rotor inlet': 265.2,
#                       'Relative rotor inlet': 283.4,
#                       'Relative tangential rotor outlet': 191.3,
#                       'Relative rotor outlet': 210.6,
#                       'Blade speed rotor inlet': 265.2,
#                       'Blade speed rotor outlet': 472.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.195,
#                   'Ma at rotor outlet': 0.144,
#                   'Ma at difusser inlet': 0.201,
#                   'Ma at difusser outlet': 0.068},
#  'Non-dimensional': {'Specific speed': 0.607,
#                      'Flow coefficient': 0.211,
#                      "Flow coefficient'": 0.019,
#                      'Work coefficient': 0.595,
#                      'Isentropic work coefficient': 0.492,
#                      'Rotor meridional velocity ratio': 0.881,
#                      'Degree of reaction': 0.711},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.64,
#                      'Relative rotor inlet': 69.36,
#                      'Relative rotor outlet': 65.29}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.711
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.64
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.29
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.35

# %%
LPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 2.5731,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 14780,
#  'Number of stages': 8,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 3.86,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 29539.93,
#  'Delta enthalpy [kJ/kg]': 1065.28,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 2741.07,
#  'Comp. Isentropic eff. [%]': 82.68,
#  'Comp. Polytropic eff. [%]': 84.18}
