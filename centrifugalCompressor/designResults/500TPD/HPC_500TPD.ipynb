# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import compressor

# %%
P_suction= 7.39971000000000 #bar
P_final  = 29.8000000000000 #bar

n_comp   = 3
n_para   = 2

R        = (P_final/P_suction)**(1/n_comp)

print(R)

# %%
from hydrogen_liquefaction import compressor

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First high-pressure compressor
T_in    = 293.798891826874 #K
P_in    = 7.39971000000000  #bar
P_out   = R*P_in #bar

m       = round(206043.574725597/(3600*n_para),4) #kg/s

HPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 28.6172
#
# Inlet Condition
# P [bar]     =  7.4
# T [Kelvin]  =  293.8
# H [kJ/kg]   =  3872.26
# S [kJ/kg.K] =  44.959
#
#
# Isentropic Outlet Condition
# P [bar]     =  11.773
# T [Kelvin]  =  335.76
# H [kJ/kg]   =  4477.52
# S [kJ/kg.K] =  44.959
#
#
# Δh_is [kJ/kg]  =  605.26
# Power_is [kW]  = 17320.841

# %%
#design constraint
u2_max  = 500  #m/s

HPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  5
# Max. number of stage =  7

# %%
HPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  3236.501
# Max. RPM =  9033.046

# %%
HPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC1.stagesCalculation(5650,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:118.82
# Compression ratio:1.09
# Power [kW]:3400.24
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 169447.29,
#  'Rotor outlet pressure [bar]': 7.87,
#  'Rotor outlet temperature [℃]': 26.82,
#  'Diffuser outlet pressure [bar]': 8.03,
#  'Diffuser outlet temperature [℃]': 28.92,
#  'Polytropic efficiency [%]': 85.04,
#  'Isentropic efficiency [%]': 84.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.58,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 90.42,
#  'Rotor outlet diameter [cm]': 155.82,
#  'Diffuser outlet diameter [cm]': 249.86,
#  'Blade height at rotor inlet  [cm]': 17.94,
#  'Blade height at rotor outlet  [cm]': 10.89}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 115.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 115.2,
#                       'Absolute tangential rotor outlet': 257.8,
#                       'Absolute meridional rotor outlet': 84.8,
#                       'Absolute rotor outlet': 271.4,
#                       'Absolute diffuser outlet': 115.2,
#                       'Relative tangential rotor inlet': 267.5,
#                       'Relative rotor inlet': 291.3,
#                       'Relative tangential rotor outlet': 203.2,
#                       'Relative rotor outlet': 220.2,
#                       'Blade speed rotor inlet': 267.5,
#                       'Blade speed rotor outlet': 461.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.222,
#                   'Ma at rotor outlet': 0.166,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.087},
#  'Non-dimensional': {'Specific speed': 0.717,
#                      'Flow coefficient': 0.25,
#                      "Flow coefficient'": 0.066,
#                      'Work coefficient': 0.559,
#                      'Isentropic work coefficient': 0.475,
#                      'Rotor meridional velocity ratio': 0.736,
#                      'Degree of reaction': 0.746},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.79,
#                      'Relative rotor inlet': 66.7,
#                      'Relative rotor outlet': 67.34}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.746
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.79
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.34
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:119.73
# Compression ratio:1.08
# Power [kW]:3426.44
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 160568.45,
#  'Rotor outlet pressure [bar]': 8.52,
#  'Rotor outlet temperature [℃]': 35.06,
#  'Diffuser outlet pressure [bar]': 8.7,
#  'Diffuser outlet temperature [℃]': 37.25,
#  'Polytropic efficiency [%]': 84.75,
#  'Isentropic efficiency [%]': 84.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 89.59,
#  'Rotor outlet diameter [cm]': 155.31,
#  'Diffuser outlet diameter [cm]': 248.69,
#  'Blade height at rotor inlet  [cm]': 17.62,
#  'Blade height at rotor outlet  [cm]': 10.4}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 112.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 112.0,
#                       'Absolute tangential rotor outlet': 259.5,
#                       'Absolute meridional rotor outlet': 84.6,
#                       'Absolute rotor outlet': 273.0,
#                       'Absolute diffuser outlet': 112.0,
#                       'Relative tangential rotor inlet': 265.0,
#                       'Relative rotor inlet': 287.7,
#                       'Relative tangential rotor outlet': 199.9,
#                       'Relative rotor outlet': 217.1,
#                       'Blade speed rotor inlet': 265.0,
#                       'Blade speed rotor outlet': 459.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.216,
#                   'Ma at rotor outlet': 0.162,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.083},
#  'Non-dimensional': {'Specific speed': 0.698,
#                      'Flow coefficient': 0.244,
#                      "Flow coefficient'": 0.063,
#                      'Work coefficient': 0.565,
#                      'Isentropic work coefficient': 0.478,
#                      'Rotor meridional velocity ratio': 0.755,
#                      'Degree of reaction': 0.74},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.95,
#                      'Relative rotor inlet': 67.1,
#                      'Relative rotor outlet': 67.07}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.74
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.95
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.07
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:120.66
# Compression ratio:1.08
# Power [kW]:3452.83
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 152355.43,
#  'Rotor outlet pressure [bar]': 9.21,
#  'Rotor outlet temperature [℃]': 43.34,
#  'Diffuser outlet pressure [bar]': 9.41,
#  'Diffuser outlet temperature [℃]': 45.61,
#  'Polytropic efficiency [%]': 84.44,
#  'Isentropic efficiency [%]': 84.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 88.81,
#  'Rotor outlet diameter [cm]': 154.84,
#  'Diffuser outlet diameter [cm]': 247.6,
#  'Blade height at rotor inlet  [cm]': 17.31,
#  'Blade height at rotor outlet  [cm]': 9.93}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 108.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 108.8,
#                       'Absolute tangential rotor outlet': 261.2,
#                       'Absolute meridional rotor outlet': 84.4,
#                       'Absolute rotor outlet': 274.5,
#                       'Absolute diffuser outlet': 108.8,
#                       'Relative tangential rotor inlet': 262.7,
#                       'Relative rotor inlet': 284.4,
#                       'Relative tangential rotor outlet': 196.8,
#                       'Relative rotor outlet': 214.1,
#                       'Blade speed rotor inlet': 262.7,
#                       'Blade speed rotor outlet': 458.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.211,
#                   'Ma at rotor outlet': 0.157,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.08},
#  'Non-dimensional': {'Specific speed': 0.68,
#                      'Flow coefficient': 0.238,
#                      "Flow coefficient'": 0.06,
#                      'Work coefficient': 0.57,
#                      'Isentropic work coefficient': 0.481,
#                      'Rotor meridional velocity ratio': 0.775,
#                      'Degree of reaction': 0.735},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.1,
#                      'Relative rotor inlet': 67.5,
#                      'Relative rotor outlet': 66.79}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.735
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.1
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.79
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:121.59
# Compression ratio:1.08
# Power [kW]:3479.43
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 144745.23,
#  'Rotor outlet pressure [bar]': 9.94,
#  'Rotor outlet temperature [℃]': 51.68,
#  'Diffuser outlet pressure [bar]': 10.15,
#  'Diffuser outlet temperature [℃]': 54.03,
#  'Polytropic efficiency [%]': 84.11,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 88.09,
#  'Rotor outlet diameter [cm]': 154.39,
#  'Diffuser outlet diameter [cm]': 246.57,
#  'Blade height at rotor inlet  [cm]': 17.02,
#  'Blade height at rotor outlet  [cm]': 9.49}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 105.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 105.8,
#                       'Absolute tangential rotor outlet': 262.9,
#                       'Absolute meridional rotor outlet': 84.2,
#                       'Absolute rotor outlet': 276.1,
#                       'Absolute diffuser outlet': 105.8,
#                       'Relative tangential rotor inlet': 260.6,
#                       'Relative rotor inlet': 281.2,
#                       'Relative tangential rotor outlet': 193.8,
#                       'Relative rotor outlet': 211.3,
#                       'Blade speed rotor inlet': 260.6,
#                       'Blade speed rotor outlet': 456.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.206,
#                   'Ma at rotor outlet': 0.153,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.076},
#  'Non-dimensional': {'Specific speed': 0.663,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.057,
#                      'Work coefficient': 0.576,
#                      'Isentropic work coefficient': 0.484,
#                      'Rotor meridional velocity ratio': 0.796,
#                      'Degree of reaction': 0.729},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.24,
#                      'Relative rotor inlet': 67.9,
#                      'Relative rotor outlet': 66.51}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.729
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.24
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.51
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:122.67
# Compression ratio:1.08
# Power [kW]:3510.43
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 137682.03,
#  'Rotor outlet pressure [bar]': 10.71,
#  'Rotor outlet temperature [℃]': 60.07,
#  'Diffuser outlet pressure [bar]': 10.94,
#  'Diffuser outlet temperature [℃]': 62.51,
#  'Polytropic efficiency [%]': 83.77,
#  'Isentropic efficiency [%]': 83.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 87.4,
#  'Rotor outlet diameter [cm]': 153.97,
#  'Diffuser outlet diameter [cm]': 245.6,
#  'Blade height at rotor inlet  [cm]': 16.76,
#  'Blade height at rotor outlet  [cm]': 9.06}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 102.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 102.8,
#                       'Absolute tangential rotor outlet': 264.9,
#                       'Absolute meridional rotor outlet': 84.2,
#                       'Absolute rotor outlet': 278.0,
#                       'Absolute diffuser outlet': 102.8,
#                       'Relative tangential rotor inlet': 258.6,
#                       'Relative rotor inlet': 278.3,
#                       'Relative tangential rotor outlet': 190.6,
#                       'Relative rotor outlet': 208.4,
#                       'Blade speed rotor inlet': 258.6,
#                       'Blade speed rotor outlet': 455.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.201,
#                   'Ma at rotor outlet': 0.149,
#                   'Ma at difusser inlet': 0.199,
#                   'Ma at difusser outlet': 0.073},
#  'Non-dimensional': {'Specific speed': 0.646,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.055,
#                      'Work coefficient': 0.582,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.819,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.36,
#                      'Relative rotor inlet': 68.31,
#                      'Relative rotor outlet': 66.16}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.36
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.16
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:123.62
# Compression ratio:1.08
# Power [kW]:3537.62
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 131120.09,
#  'Rotor outlet pressure [bar]': 11.52,
#  'Rotor outlet temperature [℃]': 68.52,
#  'Diffuser outlet pressure [bar]': 11.77,
#  'Diffuser outlet temperature [℃]': 71.05,
#  'Polytropic efficiency [%]': 83.41,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 86.76,
#  'Rotor outlet diameter [cm]': 153.58,
#  'Diffuser outlet diameter [cm]': 244.7,
#  'Blade height at rotor inlet  [cm]': 16.5,
#  'Blade height at rotor outlet  [cm]': 8.67}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 100.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 100.0,
#                       'Absolute tangential rotor outlet': 266.5,
#                       'Absolute meridional rotor outlet': 84.2,
#                       'Absolute rotor outlet': 279.5,
#                       'Absolute diffuser outlet': 100.0,
#                       'Relative tangential rotor inlet': 256.7,
#                       'Relative rotor inlet': 275.5,
#                       'Relative tangential rotor outlet': 187.8,
#                       'Relative rotor outlet': 205.8,
#                       'Blade speed rotor inlet': 256.7,
#                       'Blade speed rotor outlet': 454.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.197,
#                   'Ma at rotor outlet': 0.146,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.07},
#  'Non-dimensional': {'Specific speed': 0.631,
#                      'Flow coefficient': 0.22,
#                      "Flow coefficient'": 0.052,
#                      'Work coefficient': 0.587,
#                      'Isentropic work coefficient': 0.489,
#                      'Rotor meridional velocity ratio': 0.842,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.47,
#                      'Relative rotor inlet': 68.71,
#                      'Relative rotor outlet': 65.86}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.47
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.86
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 28.6172,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 5650,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 7.4,
#  'Inlet temperature [C]': 20.65,
#  'Inlet volumetric [m3/h]': 169447.29,
#  'Delta enthalpy [kJ/kg]': 727.08,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 20807.0,
#  'Comp. Isentropic eff. [%]': 83.25,
#  'Comp. Polytropic eff. [%]': 84.31}

# %%
#Second high-pressure compressor
T_in    = 298.150000000000 #K
P_in    = P_out
print(P_in)
P_out   = R*P_in #bar

HPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)
# Out:
# 11.77285751510492

# %%
HPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 28.6172
#
# Inlet Condition
# P [bar]     =  11.773
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3936.453
# S [kJ/kg.K] =  43.25
#
#
# Isentropic Outlet Condition
# P [bar]     =  18.73
# T [Kelvin]  =  340.69
# H [kJ/kg]   =  4552.532
# S [kJ/kg.K] =  43.25
#
#
# Δh_is [kJ/kg]  =  616.079
# Power_is [kW]  = 17630.454

# %%
#design constraint
u2_max  = 500  #m/s

HPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  5
# Max. number of stage =  7

# %%
HPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  4099.733
# Max. RPM =  11447.18

# %%
HPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC2.stagesCalculation(7000,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:121.23
# Compression ratio:1.09
# Power [kW]:3469.2
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 108354.7,
#  'Rotor outlet pressure [bar]': 12.51,
#  'Rotor outlet temperature [℃]': 31.24,
#  'Diffuser outlet pressure [bar]': 12.78,
#  'Diffuser outlet temperature [℃]': 33.42,
#  'Polytropic efficiency [%]': 84.8,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 73.06,
#  'Rotor outlet diameter [cm]': 126.54,
#  'Diffuser outlet diameter [cm]': 202.67,
#  'Blade height at rotor inlet  [cm]': 14.39,
#  'Blade height at rotor outlet  [cm]': 8.53}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 113.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 113.5,
#                       'Absolute tangential rotor outlet': 261.4,
#                       'Absolute meridional rotor outlet': 85.3,
#                       'Absolute rotor outlet': 275.0,
#                       'Absolute diffuser outlet': 113.5,
#                       'Relative tangential rotor inlet': 267.8,
#                       'Relative rotor inlet': 290.8,
#                       'Relative tangential rotor outlet': 202.4,
#                       'Relative rotor outlet': 219.6,
#                       'Blade speed rotor inlet': 267.8,
#                       'Blade speed rotor outlet': 463.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.22,
#                   'Ma at rotor outlet': 0.164,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.701,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.051,
#                      'Work coefficient': 0.564,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.752,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.92,
#                      'Relative rotor inlet': 67.03,
#                      'Relative rotor outlet': 67.15}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.92
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.15
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:122.17
# Compression ratio:1.08
# Power [kW]:3496.17
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 102696.56,
#  'Rotor outlet pressure [bar]': 13.55,
#  'Rotor outlet temperature [℃]': 39.62,
#  'Diffuser outlet pressure [bar]': 13.84,
#  'Diffuser outlet temperature [℃]': 41.88,
#  'Polytropic efficiency [%]': 84.48,
#  'Isentropic efficiency [%]': 84.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 72.41,
#  'Rotor outlet diameter [cm]': 126.14,
#  'Diffuser outlet diameter [cm]': 201.75,
#  'Blade height at rotor inlet  [cm]': 14.13,
#  'Blade height at rotor outlet  [cm]': 8.14}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 110.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 110.3,
#                       'Absolute tangential rotor outlet': 263.1,
#                       'Absolute meridional rotor outlet': 85.1,
#                       'Absolute rotor outlet': 276.6,
#                       'Absolute diffuser outlet': 110.3,
#                       'Relative tangential rotor inlet': 265.4,
#                       'Relative rotor inlet': 287.4,
#                       'Relative tangential rotor outlet': 199.2,
#                       'Relative rotor outlet': 216.6,
#                       'Blade speed rotor inlet': 265.4,
#                       'Blade speed rotor outlet': 462.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.214,
#                   'Ma at rotor outlet': 0.16,
#                   'Ma at difusser inlet': 0.204,
#                   'Ma at difusser outlet': 0.081},
#  'Non-dimensional': {'Specific speed': 0.683,
#                      'Flow coefficient': 0.238,
#                      "Flow coefficient'": 0.049,
#                      'Work coefficient': 0.569,
#                      'Isentropic work coefficient': 0.48,
#                      'Rotor meridional velocity ratio': 0.772,
#                      'Degree of reaction': 0.736},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.08,
#                      'Relative rotor inlet': 67.44,
#                      'Relative rotor outlet': 66.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.736
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.08
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:123.27
# Compression ratio:1.08
# Power [kW]:3527.54
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 97463.79,
#  'Rotor outlet pressure [bar]': 14.65,
#  'Rotor outlet temperature [℃]': 48.05,
#  'Diffuser outlet pressure [bar]': 14.97,
#  'Diffuser outlet temperature [℃]': 50.4,
#  'Polytropic efficiency [%]': 84.15,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 71.8,
#  'Rotor outlet diameter [cm]': 125.77,
#  'Diffuser outlet diameter [cm]': 200.89,
#  'Blade height at rotor inlet  [cm]': 13.89,
#  'Blade height at rotor outlet  [cm]': 7.76}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 107.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 107.1,
#                       'Absolute tangential rotor outlet': 265.2,
#                       'Absolute meridional rotor outlet': 85.0,
#                       'Absolute rotor outlet': 278.5,
#                       'Absolute diffuser outlet': 107.1,
#                       'Relative tangential rotor inlet': 263.2,
#                       'Relative rotor inlet': 284.1,
#                       'Relative tangential rotor outlet': 195.8,
#                       'Relative rotor outlet': 213.5,
#                       'Blade speed rotor inlet': 263.2,
#                       'Blade speed rotor outlet': 461.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.209,
#                   'Ma at rotor outlet': 0.155,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.078},
#  'Non-dimensional': {'Specific speed': 0.665,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.047,
#                      'Work coefficient': 0.575,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.794,
#                      'Degree of reaction': 0.73},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.22,
#                      'Relative rotor inlet': 67.85,
#                      'Relative rotor outlet': 66.52}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.73
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.22
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.52
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:124.23
# Compression ratio:1.08
# Power [kW]:3555.07
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 92618.95,
#  'Rotor outlet pressure [bar]': 15.81,
#  'Rotor outlet temperature [℃]': 56.53,
#  'Diffuser outlet pressure [bar]': 16.16,
#  'Diffuser outlet temperature [℃]': 58.97,
#  'Polytropic efficiency [%]': 83.8,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 71.23,
#  'Rotor outlet diameter [cm]': 125.42,
#  'Diffuser outlet diameter [cm]': 200.09,
#  'Blade height at rotor inlet  [cm]': 13.67,
#  'Blade height at rotor outlet  [cm]': 7.42}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 104.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 104.1,
#                       'Absolute tangential rotor outlet': 266.9,
#                       'Absolute meridional rotor outlet': 84.9,
#                       'Absolute rotor outlet': 280.1,
#                       'Absolute diffuser outlet': 104.1,
#                       'Relative tangential rotor inlet': 261.1,
#                       'Relative rotor inlet': 281.1,
#                       'Relative tangential rotor outlet': 192.8,
#                       'Relative rotor outlet': 210.7,
#                       'Blade speed rotor inlet': 261.1,
#                       'Blade speed rotor outlet': 459.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.204,
#                   'Ma at rotor outlet': 0.151,
#                   'Ma at difusser inlet': 0.201,
#                   'Ma at difusser outlet': 0.074},
#  'Non-dimensional': {'Specific speed': 0.648,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.045,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.816,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.26,
#                      'Relative rotor outlet': 66.23}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.23
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:125.35
# Compression ratio:1.08
# Power [kW]:3587.12
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 88123.05,
#  'Rotor outlet pressure [bar]': 17.04,
#  'Rotor outlet temperature [℃]': 65.08,
#  'Diffuser outlet pressure [bar]': 17.41,
#  'Diffuser outlet temperature [℃]': 67.61,
#  'Polytropic efficiency [%]': 83.44,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 70.7,
#  'Rotor outlet diameter [cm]': 125.09,
#  'Diffuser outlet diameter [cm]': 199.33,
#  'Blade height at rotor inlet  [cm]': 13.46,
#  'Blade height at rotor outlet  [cm]': 7.08}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 101.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 101.1,
#                       'Absolute tangential rotor outlet': 268.8,
#                       'Absolute meridional rotor outlet': 85.0,
#                       'Absolute rotor outlet': 281.9,
#                       'Absolute diffuser outlet': 101.1,
#                       'Relative tangential rotor inlet': 259.1,
#                       'Relative rotor inlet': 278.2,
#                       'Relative tangential rotor outlet': 189.6,
#                       'Relative rotor outlet': 207.8,
#                       'Blade speed rotor inlet': 259.1,
#                       'Blade speed rotor outlet': 458.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.199,
#                   'Ma at rotor outlet': 0.147,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.632,
#                      'Flow coefficient': 0.221,
#                      "Flow coefficient'": 0.043,
#                      'Work coefficient': 0.586,
#                      'Isentropic work coefficient': 0.488,
#                      'Rotor meridional velocity ratio': 0.84,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.46,
#                      'Relative rotor inlet': 68.68,
#                      'Relative rotor outlet': 65.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.46
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:126.48
# Compression ratio:1.08
# Power [kW]:3619.61
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 83946.88,
#  'Rotor outlet pressure [bar]': 18.33,
#  'Rotor outlet temperature [℃]': 73.69,
#  'Diffuser outlet pressure [bar]': 18.73,
#  'Diffuser outlet temperature [℃]': 76.3,
#  'Polytropic efficiency [%]': 83.07,
#  'Isentropic efficiency [%]': 82.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.563,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 70.2,
#  'Rotor outlet diameter [cm]': 124.79,
#  'Diffuser outlet diameter [cm]': 198.62,
#  'Blade height at rotor inlet  [cm]': 13.26,
#  'Blade height at rotor outlet  [cm]': 6.77}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 98.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 98.3,
#                       'Absolute tangential rotor outlet': 270.8,
#                       'Absolute meridional rotor outlet': 85.0,
#                       'Absolute rotor outlet': 283.8,
#                       'Absolute diffuser outlet': 98.3,
#                       'Relative tangential rotor inlet': 257.3,
#                       'Relative rotor inlet': 275.4,
#                       'Relative tangential rotor outlet': 186.6,
#                       'Relative rotor outlet': 205.0,
#                       'Blade speed rotor inlet': 257.3,
#                       'Blade speed rotor outlet': 457.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.194,
#                   'Ma at rotor outlet': 0.143,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.068},
#  'Non-dimensional': {'Specific speed': 0.617,
#                      'Flow coefficient': 0.215,
#                      "Flow coefficient'": 0.041,
#                      'Work coefficient': 0.592,
#                      'Isentropic work coefficient': 0.491,
#                      'Rotor meridional velocity ratio': 0.865,
#                      'Degree of reaction': 0.714},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.57,
#                      'Relative rotor inlet': 69.09,
#                      'Relative rotor outlet': 65.5}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.714
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.57
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.5
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 28.6172,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 7000,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 11.77,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 108354.7,
#  'Delta enthalpy [kJ/kg]': 742.72,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 21254.7,
#  'Comp. Isentropic eff. [%]': 82.95,
#  'Comp. Polytropic eff. [%]': 84.02}

# %%
#Third high-pressure compressor
T_in    = 298.150000000000 #K
P_in    = P_out
print(P_in)
P_out   = R*P_in #bar

HPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)
# Out:
# 18.730487285442592

# %%
HPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 28.6172
#
# Inlet Condition
# P [bar]     =  18.73
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3939.509
# S [kJ/kg.K] =  41.328
#
#
# Isentropic Outlet Condition
# P [bar]     =  29.8
# T [Kelvin]  =  340.7
# H [kJ/kg]   =  4558.66
# S [kJ/kg.K] =  41.328
#
#
# Δh_is [kJ/kg]  =  619.152
# Power_is [kW]  = 17718.385

# %%
#design constraint
u2_max  = 500  #m/s

HPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  6
# Max. number of stage =  8

# %%
HPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  4695.667
# Max. RPM =  12614.867

# %%
HPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC3.stagesCalculation(8850,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:121.83
# Compression ratio:1.09
# Power [kW]:3486.5
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 68383.06,
#  'Rotor outlet pressure [bar]': 19.91,
#  'Rotor outlet temperature [℃]': 31.25,
#  'Diffuser outlet pressure [bar]': 20.33,
#  'Diffuser outlet temperature [℃]': 33.43,
#  'Polytropic efficiency [%]': 84.8,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 57.95,
#  'Rotor outlet diameter [cm]': 100.34,
#  'Diffuser outlet diameter [cm]': 160.72,
#  'Blade height at rotor inlet  [cm]': 11.41,
#  'Blade height at rotor outlet  [cm]': 6.77}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 113.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 113.8,
#                       'Absolute tangential rotor outlet': 262.0,
#                       'Absolute meridional rotor outlet': 85.5,
#                       'Absolute rotor outlet': 275.6,
#                       'Absolute diffuser outlet': 113.8,
#                       'Relative tangential rotor inlet': 268.5,
#                       'Relative rotor inlet': 291.7,
#                       'Relative tangential rotor outlet': 203.0,
#                       'Relative rotor outlet': 220.3,
#                       'Blade speed rotor inlet': 268.5,
#                       'Blade speed rotor outlet': 465.0},
#  'Mach Numbers': {'Ma at rotor inlet': 0.219,
#                   'Ma at rotor outlet': 0.164,
#                   'Ma at difusser inlet': 0.205,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.702,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.041,
#                      'Work coefficient': 0.564,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.751,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.92,
#                      'Relative rotor inlet': 67.02,
#                      'Relative rotor outlet': 67.15}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.92
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.15
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:122.78
# Compression ratio:1.08
# Power [kW]:3513.62
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 64828.23,
#  'Rotor outlet pressure [bar]': 21.56,
#  'Rotor outlet temperature [℃]': 39.64,
#  'Diffuser outlet pressure [bar]': 22.03,
#  'Diffuser outlet temperature [℃]': 41.9,
#  'Polytropic efficiency [%]': 84.49,
#  'Isentropic efficiency [%]': 84.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.574,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 57.43,
#  'Rotor outlet diameter [cm]': 100.03,
#  'Diffuser outlet diameter [cm]': 159.99,
#  'Blade height at rotor inlet  [cm]': 11.21,
#  'Blade height at rotor outlet  [cm]': 6.46}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 110.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 110.6,
#                       'Absolute tangential rotor outlet': 263.8,
#                       'Absolute meridional rotor outlet': 85.3,
#                       'Absolute rotor outlet': 277.2,
#                       'Absolute diffuser outlet': 110.6,
#                       'Relative tangential rotor inlet': 266.1,
#                       'Relative rotor inlet': 288.2,
#                       'Relative tangential rotor outlet': 199.8,
#                       'Relative rotor outlet': 217.2,
#                       'Blade speed rotor inlet': 266.1,
#                       'Blade speed rotor outlet': 463.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.214,
#                   'Ma at rotor outlet': 0.159,
#                   'Ma at difusser inlet': 0.203,
#                   'Ma at difusser outlet': 0.081},
#  'Non-dimensional': {'Specific speed': 0.683,
#                      'Flow coefficient': 0.239,
#                      "Flow coefficient'": 0.039,
#                      'Work coefficient': 0.569,
#                      'Isentropic work coefficient': 0.48,
#                      'Rotor meridional velocity ratio': 0.771,
#                      'Degree of reaction': 0.736},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.07,
#                      'Relative rotor inlet': 67.43,
#                      'Relative rotor outlet': 66.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.736
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.07
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:123.88
# Compression ratio:1.08
# Power [kW]:3545.14
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 61541.75,
#  'Rotor outlet pressure [bar]': 23.31,
#  'Rotor outlet temperature [℃]': 48.07,
#  'Diffuser outlet pressure [bar]': 23.82,
#  'Diffuser outlet temperature [℃]': 50.43,
#  'Polytropic efficiency [%]': 84.16,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 56.95,
#  'Rotor outlet diameter [cm]': 99.74,
#  'Diffuser outlet diameter [cm]': 159.31,
#  'Blade height at rotor inlet  [cm]': 11.02,
#  'Blade height at rotor outlet  [cm]': 6.17}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 107.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 107.5,
#                       'Absolute tangential rotor outlet': 265.8,
#                       'Absolute meridional rotor outlet': 85.3,
#                       'Absolute rotor outlet': 279.1,
#                       'Absolute diffuser outlet': 107.5,
#                       'Relative tangential rotor inlet': 263.9,
#                       'Relative rotor inlet': 285.0,
#                       'Relative tangential rotor outlet': 196.4,
#                       'Relative rotor outlet': 214.1,
#                       'Blade speed rotor inlet': 263.9,
#                       'Blade speed rotor outlet': 462.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.208,
#                   'Ma at rotor outlet': 0.155,
#                   'Ma at difusser inlet': 0.202,
#                   'Ma at difusser outlet': 0.077},
#  'Non-dimensional': {'Specific speed': 0.666,
#                      'Flow coefficient': 0.233,
#                      "Flow coefficient'": 0.037,
#                      'Work coefficient': 0.575,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.793,
#                      'Degree of reaction': 0.73},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.21,
#                      'Relative rotor inlet': 67.84,
#                      'Relative rotor outlet': 66.53}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.73
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.21
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.53
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:124.85
# Compression ratio:1.08
# Power [kW]:3572.8
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 58499.91,
#  'Rotor outlet pressure [bar]': 25.16,
#  'Rotor outlet temperature [℃]': 56.57,
#  'Diffuser outlet pressure [bar]': 25.71,
#  'Diffuser outlet temperature [℃]': 59.01,
#  'Polytropic efficiency [%]': 83.82,
#  'Isentropic efficiency [%]': 83.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 56.5,
#  'Rotor outlet diameter [cm]': 99.46,
#  'Diffuser outlet diameter [cm]': 158.68,
#  'Blade height at rotor inlet  [cm]': 10.84,
#  'Blade height at rotor outlet  [cm]': 5.89}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 104.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 104.5,
#                       'Absolute tangential rotor outlet': 267.5,
#                       'Absolute meridional rotor outlet': 85.2,
#                       'Absolute rotor outlet': 280.7,
#                       'Absolute diffuser outlet': 104.5,
#                       'Relative tangential rotor inlet': 261.8,
#                       'Relative rotor inlet': 281.9,
#                       'Relative tangential rotor outlet': 193.4,
#                       'Relative rotor outlet': 211.3,
#                       'Blade speed rotor inlet': 261.8,
#                       'Blade speed rotor outlet': 460.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.203,
#                   'Ma at rotor outlet': 0.151,
#                   'Ma at difusser inlet': 0.2,
#                   'Ma at difusser outlet': 0.074},
#  'Non-dimensional': {'Specific speed': 0.649,
#                      'Flow coefficient': 0.227,
#                      "Flow coefficient'": 0.035,
#                      'Work coefficient': 0.58,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.815,
#                      'Degree of reaction': 0.725},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.34,
#                      'Relative rotor inlet': 68.25,
#                      'Relative rotor outlet': 66.24}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.725
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.34
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.24
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:125.97
# Compression ratio:1.08
# Power [kW]:3604.99
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 55678.01,
#  'Rotor outlet pressure [bar]': 27.11,
#  'Rotor outlet temperature [℃]': 65.12,
#  'Diffuser outlet pressure [bar]': 27.7,
#  'Diffuser outlet temperature [℃]': 67.64,
#  'Polytropic efficiency [%]': 83.46,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 56.08,
#  'Rotor outlet diameter [cm]': 99.2,
#  'Diffuser outlet diameter [cm]': 158.08,
#  'Blade height at rotor inlet  [cm]': 10.68,
#  'Blade height at rotor outlet  [cm]': 5.63}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 101.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 101.5,
#                       'Absolute tangential rotor outlet': 269.5,
#                       'Absolute meridional rotor outlet': 85.2,
#                       'Absolute rotor outlet': 282.6,
#                       'Absolute diffuser outlet': 101.5,
#                       'Relative tangential rotor inlet': 259.9,
#                       'Relative rotor inlet': 279.0,
#                       'Relative tangential rotor outlet': 190.2,
#                       'Relative rotor outlet': 208.4,
#                       'Blade speed rotor inlet': 259.9,
#                       'Blade speed rotor outlet': 459.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.198,
#                   'Ma at rotor outlet': 0.147,
#                   'Ma at difusser inlet': 0.199,
#                   'Ma at difusser outlet': 0.071},
#  'Non-dimensional': {'Specific speed': 0.633,
#                      'Flow coefficient': 0.221,
#                      "Flow coefficient'": 0.034,
#                      'Work coefficient': 0.586,
#                      'Isentropic work coefficient': 0.488,
#                      'Rotor meridional velocity ratio': 0.839,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.46,
#                      'Relative rotor inlet': 68.66,
#                      'Relative rotor outlet': 65.88}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.46
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.88
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:126.96
# Compression ratio:1.08
# Power [kW]:3633.23
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 53057.57,
#  'Rotor outlet pressure [bar]': 29.16,
#  'Rotor outlet temperature [℃]': 73.73,
#  'Diffuser outlet pressure [bar]': 29.8,
#  'Diffuser outlet temperature [℃]': 76.33,
#  'Polytropic efficiency [%]': 83.09,
#  'Isentropic efficiency [%]': 83.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.563,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 55.68,
#  'Rotor outlet diameter [cm]': 98.96,
#  'Diffuser outlet diameter [cm]': 157.52,
#  'Blade height at rotor inlet  [cm]': 10.52,
#  'Blade height at rotor outlet  [cm]': 5.39}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 98.7,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 98.7,
#                       'Absolute tangential rotor outlet': 271.1,
#                       'Absolute meridional rotor outlet': 85.1,
#                       'Absolute rotor outlet': 284.2,
#                       'Absolute diffuser outlet': 98.7,
#                       'Relative tangential rotor inlet': 258.0,
#                       'Relative rotor inlet': 276.3,
#                       'Relative tangential rotor outlet': 187.4,
#                       'Relative rotor outlet': 205.9,
#                       'Blade speed rotor inlet': 258.0,
#                       'Blade speed rotor outlet': 458.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.194,
#                   'Ma at rotor outlet': 0.143,
#                   'Ma at difusser inlet': 0.198,
#                   'Ma at difusser outlet': 0.068},
#  'Non-dimensional': {'Specific speed': 0.618,
#                      'Flow coefficient': 0.215,
#                      "Flow coefficient'": 0.032,
#                      'Work coefficient': 0.591,
#                      'Isentropic work coefficient': 0.491,
#                      'Rotor meridional velocity ratio': 0.862,
#                      'Degree of reaction': 0.714},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.57,
#                      'Relative rotor inlet': 69.06,
#                      'Relative rotor outlet': 65.57}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.714
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.57
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.57
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 28.6172,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 8850,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 18.73,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 68383.06,
#  'Delta enthalpy [kJ/kg]': 746.27,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 21356.27,
#  'Comp. Isentropic eff. [%]': 82.97,
#  'Comp. Polytropic eff. [%]': 84.04}
