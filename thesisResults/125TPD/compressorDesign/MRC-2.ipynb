# %%
from hydrogen_liquefaction import compressor

# %%
P_suction= 12.0660000000000 #bar
P_final  = 35.0000000000000 #bar

n_comp   = 1

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 2.900712746560583

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'
    
fluid   = "REFPROP::NITROGEN[0.1118]&METHANE[0.3566]&ETHANE[0.2921]&PROPANE[0.0303]&BUTANE[0.2092]"

T_in    = 298.150000000000 #K
P_in    = 12.0660000000000 #bar
P_out   = R*P_in #bar

m       = round(60625.3117937560/3600,4) #kg/s

MRC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
MRC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: NITROGEN[0.1118]&METHANE[0.3566]&ETHANE[0.2921]&PROPANE[0.0303]&BUTANE[0.2092]
# Mass flow [kg/s] : 16.8404
#
# Inlet Condition
# P [bar]     =  12.066
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  639.888
# S [kJ/kg.K] =  3.665
#
#
# Isentropic Outlet Condition
# P [bar]     =  35.0
# T [Kelvin]  =  356.21
# H [kJ/kg]   =  722.82
# S [kJ/kg.K] =  3.665
#
#
# Δh_is [kJ/kg]  =  82.932
# Power_is [kW]  = 1396.61

# %%
#design constraint
u2_max  = 500 #m/s

MRC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  1
# Max. number of stage =  3

# %%
MRC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  11158.313
# Max. RPM =  46232.665

# %%
MRC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
MRC2.stagesCalculation(32000,1,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:99.92
# Compression ratio:2.9
# Power [kW]:1682.66
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 3668.02,
#  'Rotor outlet pressure [bar]': 26.63,
#  'Rotor outlet temperature [℃]': 73.15,
#  'Diffuser outlet pressure [bar]': 35.0,
#  'Diffuser outlet temperature [℃]': 90.62,
#  'Polytropic efficiency': 0.85,
#  'Isentropic efficiency': 0.83}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.576,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 14.3,
#  'Rotor outlet diameter [cm]': 24.84,
#  'Diffuser outlet diameter [cm]': 39.76,
#  'Blade height at rotor inlet  [cm]': 2.8,
#  'Blade height at rotor outlet  [cm]': 0.85}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 100.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 100.6,
#                       'Absolute tangential rotor outlet': 240.1,
#                       'Absolute meridional rotor outlet': 78.0,
#                       'Absolute rotor outlet': 252.4,
#                       'Absolute diffuser outlet': 100.6,
#                       'Relative tangential rotor inlet': 239.6,
#                       'Relative rotor inlet': 259.9,
#                       'Relative tangential rotor outlet': 176.1,
#                       'Relative rotor outlet': 192.6,
#                       'Blade speed rotor inlet': 239.6,
#                       'Blade speed rotor outlet': 416.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.898,
#                   'Ma at rotor outlet': 0.633,
#                   'Ma at difusser inlet': 0.83,
#                   'Ma at difusser outlet': 0.325},
#  'Non-dimensional': {'Specific speed': 0.692,
#                      'Flow coefficient': 0.242,
#                      "Flow coefficient'": 0.01,
#                      'Work coefficient': 0.577,
#                      'Isentropic work coefficient': 0.479,
#                      'Rotor meridional velocity ratio': 0.776,
#                      'Degree of reaction': 0.732},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.0,
#                      'Relative rotor inlet': 67.23,
#                      'Relative rotor outlet': 66.11}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.732
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.0
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.11
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.35

# %%
MRC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'NITROGEN[0.1118]&METHANE[0.3566]&ETHANE[0.2921]&PROPANE[0.0303]&BUTANE[0.2092]',
#  'Mass flow [kg/s]': 16.8404,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 32000,
#  'Number of stages': 1,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 12.07,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 3668.02,
#  'Delta enthalpy [kJ/kg]': 99.92,
#  'Compression ratio': 2.9,
#  'Compressor power [kW]': 1682.66,
#  'Comp. Isentropic eff. [%]': 83.0,
#  'Comp. Polytropic eff. [%]': 84.73}
