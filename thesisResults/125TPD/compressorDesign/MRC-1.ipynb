# %%
from hydrogen_liquefaction import compressor

# %%
P_suction= 3.45000000000000 #bar
P_final  = 12.0660000000000 #bar

n_comp   = 1

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 3.497391304347826

# %%
class Format:
    end = '\033[0m'
    underline = '\033[4m'
    
fluid   = "REFPROP::NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]"

T_in    = 292 #K
P_in    = 3.45000000000000  #bar
P_out   = R*P_in #bar

m       = round(72008.0930098340/3600,4) #kg/s

MRC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
MRC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]
# Mass flow [kg/s] : 20.0022
#
# Inlet Condition
# P [bar]     =  3.45
# T [Kelvin]  =  292
# H [kJ/kg]   =  640.066
# S [kJ/kg.K] =  3.786
#
#
# Isentropic Outlet Condition
# P [bar]     =  12.066
# T [Kelvin]  =  350.49
# H [kJ/kg]   =  736.037
# S [kJ/kg.K] =  3.786
#
#
# Δh_is [kJ/kg]  =  95.971
# Power_is [kW]  = 1919.636

# %%
#design constraint
u2_max  = 500 #m/s

MRC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  112.5
# Min. number of stage =  1
# Max. number of stage =  3

# %%
MRC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  6554.921
# Max. RPM =  25715.369

# %%
MRC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
MRC1.stagesCalculation(12000,2,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:55.8
# Compression ratio:1.92
# Power [kW]:1116.07
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 14759.49,
#  'Rotor outlet pressure [bar]': 5.71,
#  'Rotor outlet temperature [℃]': 44.81,
#  'Diffuser outlet pressure [bar]': 6.61,
#  'Diffuser outlet temperature [℃]': 52.54,
#  'Polytropic efficiency': 0.86,
#  'Isentropic efficiency': 0.86}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.593,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 30.35,
#  'Rotor outlet diameter [cm]': 51.2,
#  'Diffuser outlet diameter [cm]': 82.53,
#  'Blade height at rotor inlet  [cm]': 6.22,
#  'Blade height at rotor outlet  [cm]': 2.81}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 87.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 87.0,
#                       'Absolute tangential rotor outlet': 173.4,
#                       'Absolute meridional rotor outlet': 59.2,
#                       'Absolute rotor outlet': 183.3,
#                       'Absolute diffuser outlet': 87.0,
#                       'Relative tangential rotor inlet': 190.7,
#                       'Relative rotor inlet': 209.6,
#                       'Relative tangential rotor outlet': 148.3,
#                       'Relative rotor outlet': 159.7,
#                       'Blade speed rotor inlet': 190.7,
#                       'Blade speed rotor outlet': 321.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.733,
#                   'Ma at rotor outlet': 0.54,
#                   'Ma at difusser inlet': 0.62,
#                   'Ma at difusser outlet': 0.292},
#  'Non-dimensional': {'Specific speed': 0.785,
#                      'Flow coefficient': 0.27,
#                      "Flow coefficient'": 0.025,
#                      'Work coefficient': 0.539,
#                      'Isentropic work coefficient': 0.464,
#                      'Rotor meridional velocity ratio': 0.681,
#                      'Degree of reaction': 0.767},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.15,
#                      'Relative rotor inlet': 65.49,
#                      'Relative rotor outlet': 68.23}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.767
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.15
# Non-optimal rotor outlet relative flow angle (0°-60°):  68.23
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.31
# Stage 2
# Delta enthalpy [kJ/kg]:59.37
# Compression ratio:1.83
# Power [kW]:1187.56
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 8502.7,
#  'Rotor outlet pressure [bar]': 10.08,
#  'Rotor outlet temperature [℃]': 76.43,
#  'Diffuser outlet pressure [bar]': 12.07,
#  'Diffuser outlet temperature [℃]': 86.74,
#  'Polytropic efficiency': 0.82,
#  'Isentropic efficiency': 0.82}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.559,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 27.71,
#  'Rotor outlet diameter [cm]': 49.59,
#  'Diffuser outlet diameter [cm]': 78.81,
#  'Blade height at rotor inlet  [cm]': 5.18,
#  'Blade height at rotor outlet  [cm]': 1.81}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 64.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 64.4,
#                       'Absolute tangential rotor outlet': 187.8,
#                       'Absolute meridional rotor outlet': 58.4,
#                       'Absolute rotor outlet': 196.7,
#                       'Absolute diffuser outlet': 64.4,
#                       'Relative tangential rotor inlet': 174.1,
#                       'Relative rotor inlet': 185.7,
#                       'Relative tangential rotor outlet': 123.8,
#                       'Relative rotor outlet': 136.9,
#                       'Blade speed rotor inlet': 174.1,
#                       'Blade speed rotor outlet': 311.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.623,
#                   'Ma at rotor outlet': 0.447,
#                   'Ma at difusser inlet': 0.643,
#                   'Ma at difusser outlet': 0.208},
#  'Non-dimensional': {'Specific speed': 0.596,
#                      'Flow coefficient': 0.207,
#                      "Flow coefficient'": 0.015,
#                      'Work coefficient': 0.603,
#                      'Isentropic work coefficient': 0.494,
#                      'Rotor meridional velocity ratio': 0.907,
#                      'Degree of reaction': 0.705},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.72,
#                      'Relative rotor inlet': 69.7,
#                      'Relative rotor outlet': 64.73}}
# Warnings:
# Non-optimal work coefficient (0.5-0.6):  0.603
# Non-optimal degree of reaction (0.6-0.7):  0.705
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.72
# Non-optimal rotor outlet relative flow angle (0°-60°):  64.73
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.36

# %%
MRC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'NITROGEN[0.1010]&METHANE[0.3240]&ETHANE[0.2740]&PROPANE[0.0310]&BUTANE[0.2700]',
#  'Mass flow [kg/s]': 20.0022,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 12000,
#  'Number of stages': 2,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 3.45,
#  'Inlet temperature [C]': 18.85,
#  'Inlet volumetric [m3/h]': 14759.49,
#  'Delta enthalpy [kJ/kg]': 115.17,
#  'Compression ratio': 3.5,
#  'Compressor power [kW]': 2303.62,
#  'Comp. Isentropic eff. [%]': 83.33,
#  'Comp. Polytropic eff. [%]': 84.86}
