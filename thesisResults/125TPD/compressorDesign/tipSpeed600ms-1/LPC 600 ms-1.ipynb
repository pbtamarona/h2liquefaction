# %%
P_suction = 1.05913000000000 #bar
P_final   = 7.40146000000000 #bar

n_comp   = 3

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 1.911859803123236

# %%
from hydrogen_liquefaction import compressor

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First low-pressure compressor
T_in    = 297.099998889065 #K
P_in    = 1.05913000000000 #bar
P_out   = R*P_in #bar

m       = round(2315.23292650504/3600,4) #kg/s

LPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  1.059
# T [Kelvin]  =  297.1
# H [kJ/kg]   =  3916.802
# S [kJ/kg.K] =  53.143
#
#
# Isentropic Outlet Condition
# P [bar]     =  2.025
# T [Kelvin]  =  357.8
# H [kJ/kg]   =  4790.406
# S [kJ/kg.K] =  53.143
#
#
# Δh_is [kJ/kg]  =  873.605
# Power_is [kW]  = 561.815

# %%
#design constraint
u2_max  = 600  #m/s

LPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  5
# Max. number of stage =  7

# %%
LPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  11357.352
# Max. RPM =  29908.473

# %%
LPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC1.stagesCalculation(19600,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:170.69
# Compression ratio:1.12
# Power [kW]:109.77
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 26802.43,
#  'Rotor outlet pressure [bar]': 1.16,
#  'Rotor outlet temperature [℃]': 32.96,
#  'Diffuser outlet pressure [bar]': 1.19,
#  'Diffuser outlet temperature [℃]': 35.86,
#  'Polytropic efficiency [%]': 85.49,
#  'Isentropic efficiency [%]': 85.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.587,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 31.84,
#  'Rotor outlet diameter [cm]': 54.28,
#  'Diffuser outlet diameter [cm]': 87.27,
#  'Blade height at rotor inlet  [cm]': 6.42,
#  'Blade height at rotor outlet  [cm]': 4.01}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 145.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 145.2,
#                       'Absolute tangential rotor outlet': 306.4,
#                       'Absolute meridional rotor outlet': 102.7,
#                       'Absolute rotor outlet': 323.1,
#                       'Absolute diffuser outlet': 145.2,
#                       'Relative tangential rotor inlet': 326.8,
#                       'Relative rotor inlet': 357.6,
#                       'Relative tangential rotor outlet': 250.7,
#                       'Relative rotor outlet': 270.9,
#                       'Blade speed rotor inlet': 326.8,
#                       'Blade speed rotor outlet': 557.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.272,
#                   'Ma at rotor outlet': 0.203,
#                   'Ma at difusser inlet': 0.243,
#                   'Ma at difusser outlet': 0.108},
#  'Non-dimensional': {'Specific speed': 0.751,
#                      'Flow coefficient': 0.261,
#                      "Flow coefficient'": 0.025,
#                      'Work coefficient': 0.55,
#                      'Isentropic work coefficient': 0.469,
#                      'Rotor meridional velocity ratio': 0.707,
#                      'Degree of reaction': 0.756},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.48,
#                      'Relative rotor inlet': 66.05,
#                      'Relative rotor outlet': 67.73}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.756
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.48
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.73
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:172.47
# Compression ratio:1.12
# Power [kW]:110.92
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 24806.66,
#  'Rotor outlet pressure [bar]': 1.29,
#  'Rotor outlet temperature [℃]': 44.79,
#  'Diffuser outlet pressure [bar]': 1.33,
#  'Diffuser outlet temperature [℃]': 47.87,
#  'Polytropic efficiency [%]': 85.12,
#  'Isentropic efficiency [%]': 84.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.581,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 31.4,
#  'Rotor outlet diameter [cm]': 54.02,
#  'Diffuser outlet diameter [cm]': 86.65,
#  'Blade height at rotor inlet  [cm]': 6.25,
#  'Blade height at rotor outlet  [cm]': 3.76}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 139.5,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 139.5,
#                       'Absolute tangential rotor outlet': 309.4,
#                       'Absolute meridional rotor outlet': 102.1,
#                       'Absolute rotor outlet': 325.8,
#                       'Absolute diffuser outlet': 139.5,
#                       'Relative tangential rotor inlet': 322.3,
#                       'Relative rotor inlet': 351.2,
#                       'Relative tangential rotor outlet': 245.0,
#                       'Relative rotor outlet': 265.4,
#                       'Blade speed rotor inlet': 322.3,
#                       'Blade speed rotor outlet': 554.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.262,
#                   'Ma at rotor outlet': 0.196,
#                   'Ma at difusser inlet': 0.24,
#                   'Ma at difusser outlet': 0.102},
#  'Non-dimensional': {'Specific speed': 0.723,
#                      'Flow coefficient': 0.252,
#                      "Flow coefficient'": 0.023,
#                      'Work coefficient': 0.558,
#                      'Isentropic work coefficient': 0.474,
#                      'Rotor meridional velocity ratio': 0.732,
#                      'Degree of reaction': 0.747},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.74,
#                      'Relative rotor inlet': 66.59,
#                      'Relative rotor outlet': 67.37}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.747
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.74
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.37
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 3
# Delta enthalpy [kJ/kg]:174.27
# Compression ratio:1.12
# Power [kW]:112.07
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 23019.47,
#  'Rotor outlet pressure [bar]': 1.44,
#  'Rotor outlet temperature [℃]': 56.72,
#  'Diffuser outlet pressure [bar]': 1.49,
#  'Diffuser outlet temperature [℃]': 59.98,
#  'Polytropic efficiency [%]': 84.72,
#  'Isentropic efficiency [%]': 84.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 31.0,
#  'Rotor outlet diameter [cm]': 53.77,
#  'Diffuser outlet diameter [cm]': 86.09,
#  'Blade height at rotor inlet  [cm]': 6.09,
#  'Blade height at rotor outlet  [cm]': 3.53}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 134.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 134.2,
#                       'Absolute tangential rotor outlet': 312.2,
#                       'Absolute meridional rotor outlet': 101.7,
#                       'Absolute rotor outlet': 328.4,
#                       'Absolute diffuser outlet': 134.2,
#                       'Relative tangential rotor inlet': 318.2,
#                       'Relative rotor inlet': 345.3,
#                       'Relative tangential rotor outlet': 239.6,
#                       'Relative rotor outlet': 260.3,
#                       'Blade speed rotor inlet': 318.2,
#                       'Blade speed rotor outlet': 551.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.253,
#                   'Ma at rotor outlet': 0.188,
#                   'Ma at difusser inlet': 0.238,
#                   'Ma at difusser outlet': 0.097},
#  'Non-dimensional': {'Specific speed': 0.696,
#                      'Flow coefficient': 0.243,
#                      "Flow coefficient'": 0.022,
#                      'Work coefficient': 0.566,
#                      'Isentropic work coefficient': 0.478,
#                      'Rotor meridional velocity ratio': 0.758,
#                      'Degree of reaction': 0.739},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.96,
#                      'Relative rotor inlet': 67.14,
#                      'Relative rotor outlet': 67.01}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.739
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.96
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.01
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:176.08
# Compression ratio:1.11
# Power [kW]:113.24
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 21413.58,
#  'Rotor outlet pressure [bar]': 1.61,
#  'Rotor outlet temperature [℃]': 68.76,
#  'Diffuser outlet pressure [bar]': 1.65,
#  'Diffuser outlet temperature [℃]': 72.19,
#  'Polytropic efficiency [%]': 84.28,
#  'Isentropic efficiency [%]': 84.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.572,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 30.63,
#  'Rotor outlet diameter [cm]': 53.55,
#  'Diffuser outlet diameter [cm]': 85.57,
#  'Blade height at rotor inlet  [cm]': 5.95,
#  'Blade height at rotor outlet  [cm]': 3.32}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 129.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 129.0,
#                       'Absolute tangential rotor outlet': 315.0,
#                       'Absolute meridional rotor outlet': 101.4,
#                       'Absolute rotor outlet': 330.9,
#                       'Absolute diffuser outlet': 129.0,
#                       'Relative tangential rotor inlet': 314.4,
#                       'Relative rotor inlet': 339.8,
#                       'Relative tangential rotor outlet': 234.5,
#                       'Relative rotor outlet': 255.5,
#                       'Blade speed rotor inlet': 314.4,
#                       'Blade speed rotor outlet': 549.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.245,
#                   'Ma at rotor outlet': 0.182,
#                   'Ma at difusser inlet': 0.235,
#                   'Ma at difusser outlet': 0.091},
#  'Non-dimensional': {'Specific speed': 0.672,
#                      'Flow coefficient': 0.235,
#                      "Flow coefficient'": 0.02,
#                      'Work coefficient': 0.573,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.786,
#                      'Degree of reaction': 0.732},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.17,
#                      'Relative rotor inlet': 67.69,
#                      'Relative rotor outlet': 66.62}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.732
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.17
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.62
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:178.13
# Compression ratio:1.11
# Power [kW]:114.56
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 19965.97,
#  'Rotor outlet pressure [bar]': 1.78,
#  'Rotor outlet temperature [℃]': 80.92,
#  'Diffuser outlet pressure [bar]': 1.83,
#  'Diffuser outlet temperature [℃]': 84.52,
#  'Polytropic efficiency [%]': 83.81,
#  'Isentropic efficiency [%]': 83.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 30.3,
#  'Rotor outlet diameter [cm]': 53.34,
#  'Diffuser outlet diameter [cm]': 85.1,
#  'Blade height at rotor inlet  [cm]': 5.81,
#  'Blade height at rotor outlet  [cm]': 3.11}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 124.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 124.0,
#                       'Absolute tangential rotor outlet': 318.1,
#                       'Absolute meridional rotor outlet': 101.3,
#                       'Absolute rotor outlet': 333.9,
#                       'Absolute diffuser outlet': 124.0,
#                       'Relative tangential rotor inlet': 310.9,
#                       'Relative rotor inlet': 334.8,
#                       'Relative tangential rotor outlet': 229.3,
#                       'Relative rotor outlet': 250.7,
#                       'Blade speed rotor inlet': 310.9,
#                       'Blade speed rotor outlet': 547.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.237,
#                   'Ma at rotor outlet': 0.175,
#                   'Ma at difusser inlet': 0.233,
#                   'Ma at difusser outlet': 0.086},
#  'Non-dimensional': {'Specific speed': 0.648,
#                      'Flow coefficient': 0.227,
#                      "Flow coefficient'": 0.019,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.817,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.34,
#                      'Relative rotor inlet': 68.26,
#                      'Relative rotor outlet': 66.17}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.34
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.17
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:180.22
# Compression ratio:1.11
# Power [kW]:115.9
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 18657.82,
#  'Rotor outlet pressure [bar]': 1.97,
#  'Rotor outlet temperature [℃]': 93.21,
#  'Diffuser outlet pressure [bar]': 2.02,
#  'Diffuser outlet temperature [℃]': 96.98,
#  'Polytropic efficiency [%]': 83.32,
#  'Isentropic efficiency [%]': 83.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 29.99,
#  'Rotor outlet diameter [cm]': 53.15,
#  'Diffuser outlet diameter [cm]': 84.66,
#  'Blade height at rotor inlet  [cm]': 5.69,
#  'Blade height at rotor outlet  [cm]': 2.93}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 119.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 119.3,
#                       'Absolute tangential rotor outlet': 321.2,
#                       'Absolute meridional rotor outlet': 101.3,
#                       'Absolute rotor outlet': 336.8,
#                       'Absolute diffuser outlet': 119.3,
#                       'Relative tangential rotor inlet': 307.8,
#                       'Relative rotor inlet': 330.1,
#                       'Relative tangential rotor outlet': 224.3,
#                       'Relative rotor outlet': 246.1,
#                       'Blade speed rotor inlet': 307.8,
#                       'Blade speed rotor outlet': 545.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.229,
#                   'Ma at rotor outlet': 0.169,
#                   'Ma at difusser inlet': 0.231,
#                   'Ma at difusser outlet': 0.082},
#  'Non-dimensional': {'Specific speed': 0.627,
#                      'Flow coefficient': 0.219,
#                      "Flow coefficient'": 0.018,
#                      'Work coefficient': 0.589,
#                      'Isentropic work coefficient': 0.489,
#                      'Rotor meridional velocity ratio': 0.849,
#                      'Degree of reaction': 0.717},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.5,
#                      'Relative rotor inlet': 68.82,
#                      'Relative rotor outlet': 65.7}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.717
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.5
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.7
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
LPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 19600,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 1.06,
#  'Inlet temperature [C]': 23.95,
#  'Inlet volumetric [m3/h]': 26802.43,
#  'Delta enthalpy [kJ/kg]': 1051.87,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 676.46,
#  'Comp. Isentropic eff. [%]': 83.05,
#  'Comp. Polytropic eff. [%]': 84.52}

# %%
#Second low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 2.02490807328191 #bar
P_out   = R*P_in #bar

LPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  2.025
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3932.236
# S [kJ/kg.K] =  50.519
#
#
# Isentropic Outlet Condition
# P [bar]     =  3.871
# T [Kelvin]  =  359.05
# H [kJ/kg]   =  4809.571
# S [kJ/kg.K] =  50.519
#
#
# Δh_is [kJ/kg]  =  877.335
# Power_is [kW]  = 564.214

# %%
#design constraint
u2_max  = 600  #m/s

LPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  5
# Max. number of stage =  7

# %%
LPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  15719.593
# Max. RPM =  41402.007

# %%
LPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC2.stagesCalculation(26100,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:172.23
# Compression ratio:1.12
# Power [kW]:110.76
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 14076.53,
#  'Rotor outlet pressure [bar]': 2.21,
#  'Rotor outlet temperature [℃]': 33.98,
#  'Diffuser outlet pressure [bar]': 2.28,
#  'Diffuser outlet temperature [℃]': 37.01,
#  'Polytropic efficiency [%]': 85.12,
#  'Isentropic efficiency [%]': 84.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.581,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 23.63,
#  'Rotor outlet diameter [cm]': 40.65,
#  'Diffuser outlet diameter [cm]': 65.21,
#  'Blade height at rotor inlet  [cm]': 4.7,
#  'Blade height at rotor outlet  [cm]': 2.82}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 139.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 139.8,
#                       'Absolute tangential rotor outlet': 310.0,
#                       'Absolute meridional rotor outlet': 102.3,
#                       'Absolute rotor outlet': 326.5,
#                       'Absolute diffuser outlet': 139.8,
#                       'Relative tangential rotor inlet': 323.0,
#                       'Relative rotor inlet': 351.9,
#                       'Relative tangential rotor outlet': 245.5,
#                       'Relative rotor outlet': 266.0,
#                       'Blade speed rotor inlet': 323.0,
#                       'Blade speed rotor outlet': 555.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.267,
#                   'Ma at rotor outlet': 0.199,
#                   'Ma at difusser inlet': 0.244,
#                   'Ma at difusser outlet': 0.104},
#  'Non-dimensional': {'Specific speed': 0.723,
#                      'Flow coefficient': 0.252,
#                      "Flow coefficient'": 0.017,
#                      'Work coefficient': 0.558,
#                      'Isentropic work coefficient': 0.474,
#                      'Rotor meridional velocity ratio': 0.732,
#                      'Degree of reaction': 0.747},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.74,
#                      'Relative rotor inlet': 66.59,
#                      'Relative rotor outlet': 67.37}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.747
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.74
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.37
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:174.06
# Compression ratio:1.12
# Power [kW]:111.94
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 13031.21,
#  'Rotor outlet pressure [bar]': 2.47,
#  'Rotor outlet temperature [℃]': 45.91,
#  'Diffuser outlet pressure [bar]': 2.55,
#  'Diffuser outlet temperature [℃]': 49.12,
#  'Polytropic efficiency [%]': 84.7,
#  'Isentropic efficiency [%]': 84.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.576,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 23.32,
#  'Rotor outlet diameter [cm]': 40.46,
#  'Diffuser outlet diameter [cm]': 64.77,
#  'Blade height at rotor inlet  [cm]': 4.58,
#  'Blade height at rotor outlet  [cm]': 2.65}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 134.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 134.3,
#                       'Absolute tangential rotor outlet': 313.0,
#                       'Absolute meridional rotor outlet': 101.9,
#                       'Absolute rotor outlet': 329.1,
#                       'Absolute diffuser outlet': 134.3,
#                       'Relative tangential rotor inlet': 318.7,
#                       'Relative rotor inlet': 345.8,
#                       'Relative tangential rotor outlet': 240.0,
#                       'Relative rotor outlet': 260.7,
#                       'Blade speed rotor inlet': 318.7,
#                       'Blade speed rotor outlet': 552.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.258,
#                   'Ma at rotor outlet': 0.192,
#                   'Ma at difusser inlet': 0.242,
#                   'Ma at difusser outlet': 0.098},
#  'Non-dimensional': {'Specific speed': 0.695,
#                      'Flow coefficient': 0.243,
#                      "Flow coefficient'": 0.016,
#                      'Work coefficient': 0.566,
#                      'Isentropic work coefficient': 0.478,
#                      'Rotor meridional velocity ratio': 0.759,
#                      'Degree of reaction': 0.739},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.97,
#                      'Relative rotor inlet': 67.16,
#                      'Relative rotor outlet': 67.0}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.739
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.97
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.0
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:176.12
# Compression ratio:1.12
# Power [kW]:113.26
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 12095.08,
#  'Rotor outlet pressure [bar]': 2.76,
#  'Rotor outlet temperature [℃]': 57.95,
#  'Diffuser outlet pressure [bar]': 2.84,
#  'Diffuser outlet temperature [℃]': 61.34,
#  'Polytropic efficiency [%]': 84.25,
#  'Isentropic efficiency [%]': 84.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.572,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 23.04,
#  'Rotor outlet diameter [cm]': 40.29,
#  'Diffuser outlet diameter [cm]': 64.37,
#  'Blade height at rotor inlet  [cm]': 4.47,
#  'Blade height at rotor outlet  [cm]': 2.48}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 128.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 128.9,
#                       'Absolute tangential rotor outlet': 316.2,
#                       'Absolute meridional rotor outlet': 101.6,
#                       'Absolute rotor outlet': 332.1,
#                       'Absolute diffuser outlet': 128.9,
#                       'Relative tangential rotor inlet': 314.8,
#                       'Relative rotor inlet': 340.2,
#                       'Relative tangential rotor outlet': 234.4,
#                       'Relative rotor outlet': 255.5,
#                       'Blade speed rotor inlet': 314.8,
#                       'Blade speed rotor outlet': 550.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.249,
#                   'Ma at rotor outlet': 0.184,
#                   'Ma at difusser inlet': 0.24,
#                   'Ma at difusser outlet': 0.093},
#  'Non-dimensional': {'Specific speed': 0.67,
#                      'Flow coefficient': 0.234,
#                      "Flow coefficient'": 0.015,
#                      'Work coefficient': 0.574,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.789,
#                      'Degree of reaction': 0.731},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.18,
#                      'Relative rotor inlet': 67.73,
#                      'Relative rotor outlet': 66.56}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.731
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.18
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.56
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:178.0
# Compression ratio:1.11
# Power [kW]:114.47
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 11254.34,
#  'Rotor outlet pressure [bar]': 3.07,
#  'Rotor outlet temperature [℃]': 70.11,
#  'Diffuser outlet pressure [bar]': 3.16,
#  'Diffuser outlet temperature [℃]': 73.68,
#  'Polytropic efficiency [%]': 83.76,
#  'Isentropic efficiency [%]': 83.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 22.78,
#  'Rotor outlet diameter [cm]': 40.13,
#  'Diffuser outlet diameter [cm]': 64.01,
#  'Blade height at rotor inlet  [cm]': 4.37,
#  'Blade height at rotor outlet  [cm]': 2.33}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 123.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 123.8,
#                       'Absolute tangential rotor outlet': 318.9,
#                       'Absolute meridional rotor outlet': 101.4,
#                       'Absolute rotor outlet': 334.7,
#                       'Absolute diffuser outlet': 123.8,
#                       'Relative tangential rotor inlet': 311.3,
#                       'Relative rotor inlet': 335.0,
#                       'Relative tangential rotor outlet': 229.5,
#                       'Relative rotor outlet': 250.9,
#                       'Blade speed rotor inlet': 311.3,
#                       'Blade speed rotor outlet': 548.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.241,
#                   'Ma at rotor outlet': 0.178,
#                   'Ma at difusser inlet': 0.237,
#                   'Ma at difusser outlet': 0.087},
#  'Non-dimensional': {'Specific speed': 0.646,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.014,
#                      'Work coefficient': 0.582,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.819,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.36,
#                      'Relative rotor inlet': 68.31,
#                      'Relative rotor outlet': 66.16}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.36
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.16
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 5
# Delta enthalpy [kJ/kg]:180.33
# Compression ratio:1.11
# Power [kW]:115.97
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 10496.38,
#  'Rotor outlet pressure [bar]': 3.4,
#  'Rotor outlet temperature [℃]': 82.4,
#  'Diffuser outlet pressure [bar]': 3.5,
#  'Diffuser outlet temperature [℃]': 86.15,
#  'Polytropic efficiency [%]': 83.25,
#  'Isentropic efficiency [%]': 83.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 22.54,
#  'Rotor outlet diameter [cm]': 39.98,
#  'Diffuser outlet diameter [cm]': 63.67,
#  'Blade height at rotor inlet  [cm]': 4.27,
#  'Blade height at rotor outlet  [cm]': 2.18}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 118.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 118.9,
#                       'Absolute tangential rotor outlet': 322.4,
#                       'Absolute meridional rotor outlet': 101.5,
#                       'Absolute rotor outlet': 338.0,
#                       'Absolute diffuser outlet': 118.9,
#                       'Relative tangential rotor inlet': 308.0,
#                       'Relative rotor inlet': 330.2,
#                       'Relative tangential rotor outlet': 224.0,
#                       'Relative rotor outlet': 245.9,
#                       'Blade speed rotor inlet': 308.0,
#                       'Blade speed rotor outlet': 546.4},
#  'Mach Numbers': {'Ma at rotor inlet': 0.233,
#                   'Ma at rotor outlet': 0.171,
#                   'Ma at difusser inlet': 0.235,
#                   'Ma at difusser outlet': 0.082},
#  'Non-dimensional': {'Specific speed': 0.624,
#                      'Flow coefficient': 0.218,
#                      "Flow coefficient'": 0.013,
#                      'Work coefficient': 0.59,
#                      'Isentropic work coefficient': 0.49,
#                      'Rotor meridional velocity ratio': 0.854,
#                      'Degree of reaction': 0.716},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.52,
#                      'Relative rotor inlet': 68.9,
#                      'Relative rotor outlet': 65.62}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.716
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.52
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.62
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:182.49
# Compression ratio:1.11
# Power [kW]:117.36
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 9811.79,
#  'Rotor outlet pressure [bar]': 3.75,
#  'Rotor outlet temperature [℃]': 94.83,
#  'Diffuser outlet pressure [bar]': 3.87,
#  'Diffuser outlet temperature [℃]': 98.76,
#  'Polytropic efficiency [%]': 82.71,
#  'Isentropic efficiency [%]': 82.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.56,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 22.32,
#  'Rotor outlet diameter [cm]': 39.85,
#  'Diffuser outlet diameter [cm]': 63.37,
#  'Blade height at rotor inlet  [cm]': 4.19,
#  'Blade height at rotor outlet  [cm]': 2.05}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 114.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 114.2,
#                       'Absolute tangential rotor outlet': 325.5,
#                       'Absolute meridional rotor outlet': 101.6,
#                       'Absolute rotor outlet': 340.9,
#                       'Absolute diffuser outlet': 114.2,
#                       'Relative tangential rotor inlet': 305.1,
#                       'Relative rotor inlet': 325.8,
#                       'Relative tangential rotor outlet': 219.1,
#                       'Relative rotor outlet': 241.5,
#                       'Blade speed rotor inlet': 305.1,
#                       'Blade speed rotor outlet': 544.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.226,
#                   'Ma at rotor outlet': 0.165,
#                   'Ma at difusser inlet': 0.233,
#                   'Ma at difusser outlet': 0.078},
#  'Non-dimensional': {'Specific speed': 0.603,
#                      'Flow coefficient': 0.21,
#                      "Flow coefficient'": 0.013,
#                      'Work coefficient': 0.598,
#                      'Isentropic work coefficient': 0.493,
#                      'Rotor meridional velocity ratio': 0.889,
#                      'Degree of reaction': 0.709},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.67,
#                      'Relative rotor inlet': 69.47,
#                      'Relative rotor outlet': 65.13}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.709
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.67
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.13
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.35

# %%
LPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 26100,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 2.02,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 14076.53,
#  'Delta enthalpy [kJ/kg]': 1063.22,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 683.76,
#  'Comp. Isentropic eff. [%]': 82.52,
#  'Comp. Polytropic eff. [%]': 84.03}

# %%
#Third low-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 3.87134035032741 #bar
P_out   = R*P_in #bar

LPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
LPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  3.871
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3933.029
# S [kJ/kg.K] =  47.844
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.401
# T [Kelvin]  =  359.06
# H [kJ/kg]   =  4811.631
# S [kJ/kg.K] =  47.844
#
#
# Δh_is [kJ/kg]  =  878.601
# Power_is [kW]  = 565.029

# %%
#design constraint
u2_max  = 600  #m/s

LPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  5
# Max. number of stage =  7

# %%
LPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  21740.575
# Max. RPM =  57277.517

# %%
LPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
LPC3.stagesCalculation(36600,6,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:172.07
# Compression ratio:1.12
# Power [kW]:110.66
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 7370.72,
#  'Rotor outlet pressure [bar]': 4.23,
#  'Rotor outlet temperature [℃]': 34.0,
#  'Diffuser outlet pressure [bar]': 4.35,
#  'Diffuser outlet temperature [℃]': 36.99,
#  'Polytropic efficiency [%]': 85.26,
#  'Isentropic efficiency [%]': 85.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.583,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 16.95,
#  'Rotor outlet diameter [cm]': 29.06,
#  'Diffuser outlet diameter [cm]': 46.65,
#  'Blade height at rotor inlet  [cm]': 3.39,
#  'Blade height at rotor outlet  [cm]': 2.06}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 141.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 141.9,
#                       'Absolute tangential rotor outlet': 309.0,
#                       'Absolute meridional rotor outlet': 102.5,
#                       'Absolute rotor outlet': 325.6,
#                       'Absolute diffuser outlet': 141.9,
#                       'Relative tangential rotor inlet': 324.7,
#                       'Relative rotor inlet': 354.4,
#                       'Relative tangential rotor outlet': 247.9,
#                       'Relative rotor outlet': 268.2,
#                       'Blade speed rotor inlet': 324.7,
#                       'Blade speed rotor outlet': 556.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.269,
#                   'Ma at rotor outlet': 0.201,
#                   'Ma at difusser inlet': 0.243,
#                   'Ma at difusser outlet': 0.106},
#  'Non-dimensional': {'Specific speed': 0.733,
#                      'Flow coefficient': 0.255,
#                      "Flow coefficient'": 0.013,
#                      'Work coefficient': 0.555,
#                      'Isentropic work coefficient': 0.472,
#                      'Rotor meridional velocity ratio': 0.722,
#                      'Degree of reaction': 0.751},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.65,
#                      'Relative rotor inlet': 66.4,
#                      'Relative rotor outlet': 67.53}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.751
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.65
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.53
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:173.88
# Compression ratio:1.12
# Power [kW]:111.82
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 6823.36,
#  'Rotor outlet pressure [bar]': 4.73,
#  'Rotor outlet temperature [℃]': 45.91,
#  'Diffuser outlet pressure [bar]': 4.87,
#  'Diffuser outlet temperature [℃]': 49.07,
#  'Polytropic efficiency [%]': 84.86,
#  'Isentropic efficiency [%]': 84.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.578,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 16.72,
#  'Rotor outlet diameter [cm]': 28.92,
#  'Diffuser outlet diameter [cm]': 46.33,
#  'Blade height at rotor inlet  [cm]': 3.3,
#  'Blade height at rotor outlet  [cm]': 1.94}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 136.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 136.3,
#                       'Absolute tangential rotor outlet': 311.9,
#                       'Absolute meridional rotor outlet': 102.0,
#                       'Absolute rotor outlet': 328.2,
#                       'Absolute diffuser outlet': 136.3,
#                       'Relative tangential rotor inlet': 320.4,
#                       'Relative rotor inlet': 348.2,
#                       'Relative tangential rotor outlet': 242.3,
#                       'Relative rotor outlet': 262.9,
#                       'Blade speed rotor inlet': 320.4,
#                       'Blade speed rotor outlet': 554.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.259,
#                   'Ma at rotor outlet': 0.193,
#                   'Ma at difusser inlet': 0.241,
#                   'Ma at difusser outlet': 0.1},
#  'Non-dimensional': {'Specific speed': 0.705,
#                      'Flow coefficient': 0.246,
#                      "Flow coefficient'": 0.012,
#                      'Work coefficient': 0.563,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.748,
#                      'Degree of reaction': 0.742},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.89,
#                      'Relative rotor inlet': 66.95,
#                      'Relative rotor outlet': 67.17}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.742
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.89
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.17
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 3
# Delta enthalpy [kJ/kg]:175.92
# Compression ratio:1.12
# Power [kW]:113.14
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 6333.27,
#  'Rotor outlet pressure [bar]': 5.28,
#  'Rotor outlet temperature [℃]': 57.92,
#  'Diffuser outlet pressure [bar]': 5.43,
#  'Diffuser outlet temperature [℃]': 61.27,
#  'Polytropic efficiency [%]': 84.42,
#  'Isentropic efficiency [%]': 84.2}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.573,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 16.51,
#  'Rotor outlet diameter [cm]': 28.79,
#  'Diffuser outlet diameter [cm]': 46.04,
#  'Blade height at rotor inlet  [cm]': 3.22,
#  'Blade height at rotor outlet  [cm]': 1.81}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 130.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 130.9,
#                       'Absolute tangential rotor outlet': 315.2,
#                       'Absolute meridional rotor outlet': 101.8,
#                       'Absolute rotor outlet': 331.2,
#                       'Absolute diffuser outlet': 130.9,
#                       'Relative tangential rotor inlet': 316.4,
#                       'Relative rotor inlet': 342.4,
#                       'Relative tangential rotor outlet': 236.6,
#                       'Relative rotor outlet': 257.6,
#                       'Blade speed rotor inlet': 316.4,
#                       'Blade speed rotor outlet': 551.8},
#  'Mach Numbers': {'Ma at rotor inlet': 0.25,
#                   'Ma at rotor outlet': 0.186,
#                   'Ma at difusser inlet': 0.239,
#                   'Ma at difusser outlet': 0.094},
#  'Non-dimensional': {'Specific speed': 0.679,
#                      'Flow coefficient': 0.237,
#                      "Flow coefficient'": 0.011,
#                      'Work coefficient': 0.571,
#                      'Isentropic work coefficient': 0.481,
#                      'Rotor meridional velocity ratio': 0.777,
#                      'Degree of reaction': 0.734},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.11,
#                      'Relative rotor inlet': 67.52,
#                      'Relative rotor outlet': 66.73}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.734
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.11
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.73
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:177.78
# Compression ratio:1.11
# Power [kW]:114.33
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 5893.23,
#  'Rotor outlet pressure [bar]': 5.86,
#  'Rotor outlet temperature [℃]': 70.06,
#  'Diffuser outlet pressure [bar]': 6.04,
#  'Diffuser outlet temperature [℃]': 73.57,
#  'Polytropic efficiency [%]': 83.95,
#  'Isentropic efficiency [%]': 83.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.569,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 16.32,
#  'Rotor outlet diameter [cm]': 28.68,
#  'Diffuser outlet diameter [cm]': 45.77,
#  'Blade height at rotor inlet  [cm]': 3.14,
#  'Blade height at rotor outlet  [cm]': 1.7}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 125.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 125.8,
#                       'Absolute tangential rotor outlet': 317.9,
#                       'Absolute meridional rotor outlet': 101.5,
#                       'Absolute rotor outlet': 333.8,
#                       'Absolute diffuser outlet': 125.8,
#                       'Relative tangential rotor inlet': 312.8,
#                       'Relative rotor inlet': 337.2,
#                       'Relative tangential rotor outlet': 231.6,
#                       'Relative rotor outlet': 252.9,
#                       'Blade speed rotor inlet': 312.8,
#                       'Blade speed rotor outlet': 549.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.242,
#                   'Ma at rotor outlet': 0.179,
#                   'Ma at difusser inlet': 0.236,
#                   'Ma at difusser outlet': 0.089},
#  'Non-dimensional': {'Specific speed': 0.655,
#                      'Flow coefficient': 0.229,
#                      "Flow coefficient'": 0.01,
#                      'Work coefficient': 0.579,
#                      'Isentropic work coefficient': 0.485,
#                      'Rotor meridional velocity ratio': 0.807,
#                      'Degree of reaction': 0.727},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.29,
#                      'Relative rotor inlet': 68.09,
#                      'Relative rotor outlet': 66.34}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.727
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.29
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.34
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 5
# Delta enthalpy [kJ/kg]:179.87
# Compression ratio:1.11
# Power [kW]:115.68
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 5496.58,
#  'Rotor outlet pressure [bar]': 6.5,
#  'Rotor outlet temperature [℃]': 82.31,
#  'Diffuser outlet pressure [bar]': 6.7,
#  'Diffuser outlet temperature [℃]': 86.0,
#  'Polytropic efficiency [%]': 83.45,
#  'Isentropic efficiency [%]': 83.3}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.565,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 16.15,
#  'Rotor outlet diameter [cm]': 28.57,
#  'Diffuser outlet diameter [cm]': 45.53,
#  'Blade height at rotor inlet  [cm]': 3.07,
#  'Blade height at rotor outlet  [cm]': 1.6}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 120.9,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 120.9,
#                       'Absolute tangential rotor outlet': 321.0,
#                       'Absolute meridional rotor outlet': 101.5,
#                       'Absolute rotor outlet': 336.7,
#                       'Absolute diffuser outlet': 120.9,
#                       'Relative tangential rotor inlet': 309.5,
#                       'Relative rotor inlet': 332.3,
#                       'Relative tangential rotor outlet': 226.5,
#                       'Relative rotor outlet': 248.2,
#                       'Blade speed rotor inlet': 309.5,
#                       'Blade speed rotor outlet': 547.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.234,
#                   'Ma at rotor outlet': 0.173,
#                   'Ma at difusser inlet': 0.234,
#                   'Ma at difusser outlet': 0.084},
#  'Non-dimensional': {'Specific speed': 0.633,
#                      'Flow coefficient': 0.221,
#                      "Flow coefficient'": 0.01,
#                      'Work coefficient': 0.586,
#                      'Isentropic work coefficient': 0.488,
#                      'Rotor meridional velocity ratio': 0.839,
#                      'Degree of reaction': 0.719},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.46,
#                      'Relative rotor inlet': 68.67,
#                      'Relative rotor outlet': 65.87}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.719
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.46
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.87
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 6
# Delta enthalpy [kJ/kg]:182.23
# Compression ratio:1.11
# Power [kW]:117.19
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 5138.19,
#  'Rotor outlet pressure [bar]': 7.18,
#  'Rotor outlet temperature [℃]': 94.69,
#  'Diffuser outlet pressure [bar]': 7.4,
#  'Diffuser outlet temperature [℃]': 98.57,
#  'Polytropic efficiency [%]': 82.93,
#  'Isentropic efficiency [%]': 82.7}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.562,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 15.99,
#  'Rotor outlet diameter [cm]': 28.48,
#  'Diffuser outlet diameter [cm]': 45.31,
#  'Blade height at rotor inlet  [cm]': 3.01,
#  'Blade height at rotor outlet  [cm]': 1.5}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 116.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 116.2,
#                       'Absolute tangential rotor outlet': 324.5,
#                       'Absolute meridional rotor outlet': 101.6,
#                       'Absolute rotor outlet': 340.0,
#                       'Absolute diffuser outlet': 116.2,
#                       'Relative tangential rotor inlet': 306.5,
#                       'Relative rotor inlet': 327.8,
#                       'Relative tangential rotor outlet': 221.2,
#                       'Relative rotor outlet': 243.5,
#                       'Blade speed rotor inlet': 306.5,
#                       'Blade speed rotor outlet': 545.7},
#  'Mach Numbers': {'Ma at rotor inlet': 0.227,
#                   'Ma at rotor outlet': 0.166,
#                   'Ma at difusser inlet': 0.232,
#                   'Ma at difusser outlet': 0.079},
#  'Non-dimensional': {'Specific speed': 0.612,
#                      'Flow coefficient': 0.213,
#                      "Flow coefficient'": 0.009,
#                      'Work coefficient': 0.595,
#                      'Isentropic work coefficient': 0.492,
#                      'Rotor meridional velocity ratio': 0.875,
#                      'Degree of reaction': 0.712},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.61,
#                      'Relative rotor inlet': 69.24,
#                      'Relative rotor outlet': 65.33}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.712
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.61
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.33
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.35

# %%
LPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 36600,
#  'Number of stages': 6,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 3.87,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 7370.72,
#  'Delta enthalpy [kJ/kg]': 1061.76,
#  'Compression ratio': 1.91,
#  'Compressor power [kW]': 682.82,
#  'Comp. Isentropic eff. [%]': 82.75,
#  'Comp. Polytropic eff. [%]': 84.24}
