# %%
P_suction= 7.40146000000000 #bar
P_final  = 29.8000000000000 #bar

n_comp   = 3

R        = (P_final/P_suction)**(1/n_comp)

print(R)
# Out:
# 1.5908636398536855

# %%
from hydrogen_liquefaction import compressor

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

#First high-pressure compressor
T_in    = 293.802876417080 #K
P_in    = 7.40146000000000  #bar
P_out   = R*P_in #bar

m       = round(51498.8305826687/3600,4) #kg/s

HPC1 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC1.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  7.401
# T [Kelvin]  =  293.8
# H [kJ/kg]   =  3872.318
# S [kJ/kg.K] =  44.958
#
#
# Isentropic Outlet Condition
# P [bar]     =  11.775
# T [Kelvin]  =  335.75
# H [kJ/kg]   =  4477.477
# S [kJ/kg.K] =  44.958
#
#
# Δh_is [kJ/kg]  =  605.159
# Power_is [kW]  = 8656.919

# %%
#design constraint
u2_max  = 600  #m/s

HPC1.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  4
# Max. number of stage =  6

# %%
HPC1.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  5119.333
# Max. RPM =  15103.485

# %%
HPC1.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC1.stagesCalculation(10850,4,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:178.41
# Compression ratio:1.13
# Power [kW]:2552.16
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 84684.72,
#  'Rotor outlet pressure [bar]': 8.11,
#  'Rotor outlet temperature [℃]': 29.92,
#  'Diffuser outlet pressure [bar]': 8.36,
#  'Diffuser outlet temperature [℃]': 33.07,
#  'Polytropic efficiency [%]': 85.06,
#  'Isentropic efficiency [%]': 84.8}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.581,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 57.7,
#  'Rotor outlet diameter [cm]': 99.39,
#  'Diffuser outlet diameter [cm]': 159.39,
#  'Blade height at rotor inlet  [cm]': 11.46,
#  'Blade height at rotor outlet  [cm]': 6.82}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 141.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 141.3,
#                       'Absolute tangential rotor outlet': 316.0,
#                       'Absolute meridional rotor outlet': 104.0,
#                       'Absolute rotor outlet': 332.7,
#                       'Absolute diffuser outlet': 141.3,
#                       'Relative tangential rotor inlet': 327.8,
#                       'Relative rotor inlet': 357.0,
#                       'Relative tangential rotor outlet': 248.7,
#                       'Relative rotor outlet': 269.5,
#                       'Blade speed rotor inlet': 327.8,
#                       'Blade speed rotor outlet': 564.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.272,
#                   'Ma at rotor outlet': 0.202,
#                   'Ma at difusser inlet': 0.25,
#                   'Ma at difusser outlet': 0.106},
#  'Non-dimensional': {'Specific speed': 0.718,
#                      'Flow coefficient': 0.25,
#                      "Flow coefficient'": 0.042,
#                      'Work coefficient': 0.56,
#                      'Isentropic work coefficient': 0.475,
#                      'Rotor meridional velocity ratio': 0.736,
#                      'Degree of reaction': 0.746},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.78,
#                      'Relative rotor inlet': 66.68,
#                      'Relative rotor outlet': 67.3}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.746
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.78
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.3
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.32
# Stage 2
# Delta enthalpy [kJ/kg]:180.36
# Compression ratio:1.13
# Power [kW]:2580.11
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 78154.26,
#  'Rotor outlet pressure [bar]': 9.12,
#  'Rotor outlet temperature [℃]': 42.25,
#  'Diffuser outlet pressure [bar]': 9.41,
#  'Diffuser outlet temperature [℃]': 45.59,
#  'Polytropic efficiency [%]': 84.61,
#  'Isentropic efficiency [%]': 84.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.575,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 56.92,
#  'Rotor outlet diameter [cm]': 98.91,
#  'Diffuser outlet diameter [cm]': 158.29,
#  'Blade height at rotor inlet  [cm]': 11.15,
#  'Blade height at rotor outlet  [cm]': 6.37}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 135.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 135.4,
#                       'Absolute tangential rotor outlet': 319.0,
#                       'Absolute meridional rotor outlet': 103.6,
#                       'Absolute rotor outlet': 335.4,
#                       'Absolute diffuser outlet': 135.4,
#                       'Relative tangential rotor inlet': 323.3,
#                       'Relative rotor inlet': 350.6,
#                       'Relative tangential rotor outlet': 242.9,
#                       'Relative rotor outlet': 264.1,
#                       'Blade speed rotor inlet': 323.3,
#                       'Blade speed rotor outlet': 561.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.262,
#                   'Ma at rotor outlet': 0.194,
#                   'Ma at difusser inlet': 0.247,
#                   'Ma at difusser outlet': 0.099},
#  'Non-dimensional': {'Specific speed': 0.69,
#                      'Flow coefficient': 0.241,
#                      "Flow coefficient'": 0.039,
#                      'Work coefficient': 0.568,
#                      'Isentropic work coefficient': 0.479,
#                      'Rotor meridional velocity ratio': 0.765,
#                      'Degree of reaction': 0.737},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.02,
#                      'Relative rotor inlet': 67.27,
#                      'Relative rotor outlet': 66.91}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.737
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.02
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.91
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:182.55
# Compression ratio:1.12
# Power [kW]:2611.39
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 72335.43,
#  'Rotor outlet pressure [bar]': 10.22,
#  'Rotor outlet temperature [℃]': 54.69,
#  'Diffuser outlet pressure [bar]': 10.54,
#  'Diffuser outlet temperature [℃]': 58.22,
#  'Polytropic efficiency [%]': 84.13,
#  'Isentropic efficiency [%]': 83.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.571,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 56.2,
#  'Rotor outlet diameter [cm]': 98.48,
#  'Diffuser outlet diameter [cm]': 157.28,
#  'Blade height at rotor inlet  [cm]': 10.87,
#  'Blade height at rotor outlet  [cm]': 5.96}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 129.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 129.8,
#                       'Absolute tangential rotor outlet': 322.3,
#                       'Absolute meridional rotor outlet': 103.3,
#                       'Absolute rotor outlet': 338.5,
#                       'Absolute diffuser outlet': 129.8,
#                       'Relative tangential rotor inlet': 319.3,
#                       'Relative rotor inlet': 344.7,
#                       'Relative tangential rotor outlet': 237.1,
#                       'Relative rotor outlet': 258.7,
#                       'Blade speed rotor inlet': 319.3,
#                       'Blade speed rotor outlet': 559.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.252,
#                   'Ma at rotor outlet': 0.187,
#                   'Ma at difusser inlet': 0.244,
#                   'Ma at difusser outlet': 0.093},
#  'Non-dimensional': {'Specific speed': 0.664,
#                      'Flow coefficient': 0.232,
#                      "Flow coefficient'": 0.036,
#                      'Work coefficient': 0.576,
#                      'Isentropic work coefficient': 0.483,
#                      'Rotor meridional velocity ratio': 0.796,
#                      'Degree of reaction': 0.729},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.23,
#                      'Relative rotor inlet': 67.88,
#                      'Relative rotor outlet': 66.46}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.729
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.23
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.46
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 4
# Delta enthalpy [kJ/kg]:184.77
# Compression ratio:1.12
# Power [kW]:2643.16
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 67134.36,
#  'Rotor outlet pressure [bar]': 11.41,
#  'Rotor outlet temperature [℃]': 67.26,
#  'Diffuser outlet pressure [bar]': 11.77,
#  'Diffuser outlet temperature [℃]': 70.98,
#  'Polytropic efficiency [%]': 83.61,
#  'Isentropic efficiency [%]': 83.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.566,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 55.56,
#  'Rotor outlet diameter [cm]': 98.08,
#  'Diffuser outlet diameter [cm]': 156.37,
#  'Blade height at rotor inlet  [cm]': 10.61,
#  'Blade height at rotor outlet  [cm]': 5.57}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 124.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 124.4,
#                       'Absolute tangential rotor outlet': 325.6,
#                       'Absolute meridional rotor outlet': 103.2,
#                       'Absolute rotor outlet': 341.5,
#                       'Absolute diffuser outlet': 124.4,
#                       'Relative tangential rotor inlet': 315.6,
#                       'Relative rotor inlet': 339.3,
#                       'Relative tangential rotor outlet': 231.7,
#                       'Relative rotor outlet': 253.6,
#                       'Blade speed rotor inlet': 315.6,
#                       'Blade speed rotor outlet': 557.2},
#  'Mach Numbers': {'Ma at rotor inlet': 0.244,
#                   'Ma at rotor outlet': 0.18,
#                   'Ma at difusser inlet': 0.242,
#                   'Ma at difusser outlet': 0.088},
#  'Non-dimensional': {'Specific speed': 0.64,
#                      'Flow coefficient': 0.223,
#                      "Flow coefficient'": 0.034,
#                      'Work coefficient': 0.584,
#                      'Isentropic work coefficient': 0.487,
#                      'Rotor meridional velocity ratio': 0.829,
#                      'Degree of reaction': 0.721},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.41,
#                      'Relative rotor inlet': 68.48,
#                      'Relative rotor outlet': 65.99}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.721
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.41
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.99
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC1.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 10850,
#  'Number of stages': 4,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 7.4,
#  'Inlet temperature [C]': 20.65,
#  'Inlet volumetric [m3/h]': 84684.72,
#  'Delta enthalpy [kJ/kg]': 726.09,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10386.81,
#  'Comp. Isentropic eff. [%]': 83.35,
#  'Comp. Polytropic eff. [%]': 84.4}

# %%
#Second high-pressure compressor
T_in    = 298.15 #K
P_in    = 11.7747135958315 #bar
P_out   = R*P_in #bar

HPC2 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC2.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  11.775
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3936.454
# S [kJ/kg.K] =  43.249
#
#
# Isentropic Outlet Condition
# P [bar]     =  18.732
# T [Kelvin]  =  340.69
# H [kJ/kg]   =  4552.422
# S [kJ/kg.K] =  43.249
#
#
# Δh_is [kJ/kg]  =  615.968
# Power_is [kW]  = 8811.543

# %%
#design constraint
u2_max  = 600  #m/s

HPC2.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  4
# Max. number of stage =  6

# %%
HPC2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  6484.569
# Max. RPM =  19139.161

# %%
HPC2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC2.stagesCalculation(13450,4,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:182.02
# Compression ratio:1.13
# Power [kW]:2603.88
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 54156.0,
#  'Rotor outlet pressure [bar]': 12.9,
#  'Rotor outlet temperature [℃]': 34.37,
#  'Diffuser outlet pressure [bar]': 13.3,
#  'Diffuser outlet temperature [℃]': 37.63,
#  'Polytropic efficiency [%]': 84.82,
#  'Isentropic efficiency [%]': 84.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.578,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 46.61,
#  'Rotor outlet diameter [cm]': 80.67,
#  'Diffuser outlet diameter [cm]': 129.22,
#  'Blade height at rotor inlet  [cm]': 9.18,
#  'Blade height at rotor outlet  [cm]': 5.34}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 139.3,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 139.3,
#                       'Absolute tangential rotor outlet': 320.4,
#                       'Absolute meridional rotor outlet': 104.7,
#                       'Absolute rotor outlet': 337.0,
#                       'Absolute diffuser outlet': 139.3,
#                       'Relative tangential rotor inlet': 328.2,
#                       'Relative rotor inlet': 356.6,
#                       'Relative tangential rotor outlet': 247.7,
#                       'Relative rotor outlet': 268.9,
#                       'Blade speed rotor inlet': 328.2,
#                       'Blade speed rotor outlet': 568.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.269,
#                   'Ma at rotor outlet': 0.2,
#                   'Ma at difusser inlet': 0.251,
#                   'Ma at difusser outlet': 0.103},
#  'Non-dimensional': {'Specific speed': 0.703,
#                      'Flow coefficient': 0.245,
#                      "Flow coefficient'": 0.033,
#                      'Work coefficient': 0.564,
#                      'Isentropic work coefficient': 0.477,
#                      'Rotor meridional velocity ratio': 0.751,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.91,
#                      'Relative rotor inlet': 67.0,
#                      'Relative rotor outlet': 67.1}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.91
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.1
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 2
# Delta enthalpy [kJ/kg]:184.25
# Compression ratio:1.13
# Power [kW]:2635.8
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 49994.29,
#  'Rotor outlet pressure [bar]': 14.5,
#  'Rotor outlet temperature [℃]': 46.91,
#  'Diffuser outlet pressure [bar]': 14.97,
#  'Diffuser outlet temperature [℃]': 50.37,
#  'Polytropic efficiency [%]': 84.35,
#  'Isentropic efficiency [%]': 84.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.573,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 45.99,
#  'Rotor outlet diameter [cm]': 80.3,
#  'Diffuser outlet diameter [cm]': 128.36,
#  'Blade height at rotor inlet  [cm]': 8.94,
#  'Blade height at rotor outlet  [cm]': 4.99}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 133.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 133.4,
#                       'Absolute tangential rotor outlet': 323.8,
#                       'Absolute meridional rotor outlet': 104.4,
#                       'Absolute rotor outlet': 340.2,
#                       'Absolute diffuser outlet': 133.4,
#                       'Relative tangential rotor inlet': 323.9,
#                       'Relative rotor inlet': 350.3,
#                       'Relative tangential rotor outlet': 241.7,
#                       'Relative rotor outlet': 263.3,
#                       'Blade speed rotor inlet': 323.9,
#                       'Blade speed rotor outlet': 565.5},
#  'Mach Numbers': {'Ma at rotor inlet': 0.259,
#                   'Ma at rotor outlet': 0.192,
#                   'Ma at difusser inlet': 0.248,
#                   'Ma at difusser outlet': 0.097},
#  'Non-dimensional': {'Specific speed': 0.675,
#                      'Flow coefficient': 0.236,
#                      "Flow coefficient'": 0.031,
#                      'Work coefficient': 0.573,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.782,
#                      'Degree of reaction': 0.733},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.14,
#                      'Relative rotor inlet': 67.61,
#                      'Relative rotor outlet': 66.65}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.733
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.14
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.65
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:186.52
# Compression ratio:1.12
# Power [kW]:2668.17
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 46289.35,
#  'Rotor outlet pressure [bar]': 16.25,
#  'Rotor outlet temperature [℃]': 59.58,
#  'Diffuser outlet pressure [bar]': 16.78,
#  'Diffuser outlet temperature [℃]': 63.24,
#  'Polytropic efficiency [%]': 83.84,
#  'Isentropic efficiency [%]': 83.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 45.43,
#  'Rotor outlet diameter [cm]': 79.96,
#  'Diffuser outlet diameter [cm]': 127.57,
#  'Blade height at rotor inlet  [cm]': 8.72,
#  'Blade height at rotor outlet  [cm]': 4.66}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 127.8,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 127.8,
#                       'Absolute tangential rotor outlet': 327.1,
#                       'Absolute meridional rotor outlet': 104.2,
#                       'Absolute rotor outlet': 343.3,
#                       'Absolute diffuser outlet': 127.8,
#                       'Relative tangential rotor inlet': 320.0,
#                       'Relative rotor inlet': 344.5,
#                       'Relative tangential rotor outlet': 236.0,
#                       'Relative rotor outlet': 258.0,
#                       'Blade speed rotor inlet': 320.0,
#                       'Blade speed rotor outlet': 563.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.25,
#                   'Ma at rotor outlet': 0.184,
#                   'Ma at difusser inlet': 0.245,
#                   'Ma at difusser outlet': 0.091},
#  'Non-dimensional': {'Specific speed': 0.65,
#                      'Flow coefficient': 0.227,
#                      "Flow coefficient'": 0.029,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.815,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.34,
#                      'Relative rotor inlet': 68.23,
#                      'Relative rotor outlet': 66.18}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.34
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.18
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 4
# Delta enthalpy [kJ/kg]:188.81
# Compression ratio:1.12
# Power [kW]:2701.03
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 42978.57,
#  'Rotor outlet pressure [bar]': 18.14,
#  'Rotor outlet temperature [℃]': 72.38,
#  'Diffuser outlet pressure [bar]': 18.73,
#  'Diffuser outlet temperature [℃]': 76.23,
#  'Polytropic efficiency [%]': 83.3,
#  'Isentropic efficiency [%]': 83.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 44.93,
#  'Rotor outlet diameter [cm]': 79.65,
#  'Diffuser outlet diameter [cm]': 126.86,
#  'Blade height at rotor inlet  [cm]': 8.53,
#  'Blade height at rotor outlet  [cm]': 4.36}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 122.4,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 122.4,
#                       'Absolute tangential rotor outlet': 330.4,
#                       'Absolute meridional rotor outlet': 104.1,
#                       'Absolute rotor outlet': 346.4,
#                       'Absolute diffuser outlet': 122.4,
#                       'Relative tangential rotor inlet': 316.4,
#                       'Relative rotor inlet': 339.3,
#                       'Relative tangential rotor outlet': 230.6,
#                       'Relative rotor outlet': 253.0,
#                       'Blade speed rotor inlet': 316.4,
#                       'Blade speed rotor outlet': 560.9},
#  'Mach Numbers': {'Ma at rotor inlet': 0.241,
#                   'Ma at rotor outlet': 0.177,
#                   'Ma at difusser inlet': 0.243,
#                   'Ma at difusser outlet': 0.085},
#  'Non-dimensional': {'Specific speed': 0.626,
#                      'Flow coefficient': 0.218,
#                      "Flow coefficient'": 0.027,
#                      'Work coefficient': 0.589,
#                      'Isentropic work coefficient': 0.489,
#                      'Rotor meridional velocity ratio': 0.85,
#                      'Degree of reaction': 0.717},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.51,
#                      'Relative rotor inlet': 68.84,
#                      'Relative rotor outlet': 65.7}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.717
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.51
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.7
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC2.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 13450,
#  'Number of stages': 4,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 11.77,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 54156.0,
#  'Delta enthalpy [kJ/kg]': 741.61,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10608.89,
#  'Comp. Isentropic eff. [%]': 83.06,
#  'Comp. Polytropic eff. [%]': 84.13}

# %%
#Third high-pressure compressor
T_in    = 298.150000000000 #K
P_in    = 18.7319637292991 #bar
P_out   = R*P_in #bar

HPC3 = compressor.Compressor(fluid, T_in, P_in, P_out, m)

# %%
HPC3.initialSpec()
# Out:
# RADIAL COMPRESSOR INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 14.3052
#
# Inlet Condition
# P [bar]     =  18.732
# T [Kelvin]  =  298.15
# H [kJ/kg]   =  3939.509
# S [kJ/kg.K] =  41.327
#
#
# Isentropic Outlet Condition
# P [bar]     =  29.8
# T [Kelvin]  =  340.7
# H [kJ/kg]   =  4558.549
# S [kJ/kg.K] =  41.327
#
#
# Δh_is [kJ/kg]  =  619.04
# Power_is [kW]  = 8855.487

# %%
#design constraint
u2_max  = 600  #m/s

HPC3.noOfStages(u2_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  600
# Δh_max/stage [kJ/kg] =  162.0
# Min. number of stage =  4
# Max. number of stage =  6

# %%
HPC3.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  8186.735
# Max. RPM =  24181.085

# %%
HPC3.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-1.0

# %%
HPC3.stagesCalculation(16920,4,True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:182.93
# Compression ratio:1.13
# Power [kW]:2616.87
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 34180.74,
#  'Rotor outlet pressure [bar]': 20.52,
#  'Rotor outlet temperature [℃]': 34.37,
#  'Diffuser outlet pressure [bar]': 21.17,
#  'Diffuser outlet temperature [℃]': 37.65,
#  'Polytropic efficiency [%]': 84.77,
#  'Isentropic efficiency [%]': 84.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.577,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 37.09,
#  'Rotor outlet diameter [cm]': 64.25,
#  'Diffuser outlet diameter [cm]': 102.9,
#  'Blade height at rotor inlet  [cm]': 7.3,
#  'Blade height at rotor outlet  [cm]': 4.23}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 139.0,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 139.0,
#                       'Absolute tangential rotor outlet': 321.4,
#                       'Absolute meridional rotor outlet': 104.8,
#                       'Absolute rotor outlet': 338.0,
#                       'Absolute diffuser outlet': 139.0,
#                       'Relative tangential rotor inlet': 328.5,
#                       'Relative rotor inlet': 356.8,
#                       'Relative tangential rotor outlet': 247.9,
#                       'Relative rotor outlet': 269.1,
#                       'Blade speed rotor inlet': 328.5,
#                       'Blade speed rotor outlet': 569.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.268,
#                   'Ma at rotor outlet': 0.199,
#                   'Ma at difusser inlet': 0.25,
#                   'Ma at difusser outlet': 0.102},
#  'Non-dimensional': {'Specific speed': 0.7,
#                      'Flow coefficient': 0.244,
#                      "Flow coefficient'": 0.026,
#                      'Work coefficient': 0.565,
#                      'Isentropic work coefficient': 0.478,
#                      'Rotor meridional velocity ratio': 0.754,
#                      'Degree of reaction': 0.741},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 71.94,
#                      'Relative rotor inlet': 67.06,
#                      'Relative rotor outlet': 67.08}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.741
# Non-optimal rotor outlet absolute flow angle (60°-70°):  71.94
# Non-optimal rotor outlet relative flow angle (0°-60°):  67.08
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 2
# Delta enthalpy [kJ/kg]:185.17
# Compression ratio:1.13
# Power [kW]:2648.95
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 31566.07,
#  'Rotor outlet pressure [bar]': 23.07,
#  'Rotor outlet temperature [℃]': 46.93,
#  'Diffuser outlet pressure [bar]': 23.82,
#  'Diffuser outlet temperature [℃]': 50.4,
#  'Polytropic efficiency [%]': 84.3,
#  'Isentropic efficiency [%]': 84.1}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.572,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 36.6,
#  'Rotor outlet diameter [cm]': 63.96,
#  'Diffuser outlet diameter [cm]': 102.22,
#  'Blade height at rotor inlet  [cm]': 7.11,
#  'Blade height at rotor outlet  [cm]': 3.95}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 133.1,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 133.1,
#                       'Absolute tangential rotor outlet': 324.8,
#                       'Absolute meridional rotor outlet': 104.5,
#                       'Absolute rotor outlet': 341.2,
#                       'Absolute diffuser outlet': 133.1,
#                       'Relative tangential rotor inlet': 324.3,
#                       'Relative rotor inlet': 350.5,
#                       'Relative tangential rotor outlet': 241.9,
#                       'Relative rotor outlet': 263.5,
#                       'Blade speed rotor inlet': 324.3,
#                       'Blade speed rotor outlet': 566.6},
#  'Mach Numbers': {'Ma at rotor inlet': 0.258,
#                   'Ma at rotor outlet': 0.191,
#                   'Ma at difusser inlet': 0.247,
#                   'Ma at difusser outlet': 0.096},
#  'Non-dimensional': {'Specific speed': 0.672,
#                      'Flow coefficient': 0.235,
#                      "Flow coefficient'": 0.024,
#                      'Work coefficient': 0.573,
#                      'Isentropic work coefficient': 0.482,
#                      'Rotor meridional velocity ratio': 0.785,
#                      'Degree of reaction': 0.732},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.16,
#                      'Relative rotor inlet': 67.68,
#                      'Relative rotor outlet': 66.63}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.732
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.16
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.63
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.33
# Stage 3
# Delta enthalpy [kJ/kg]:187.45
# Compression ratio:1.12
# Power [kW]:2681.48
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 29239.53,
#  'Rotor outlet pressure [bar]': 25.85,
#  'Rotor outlet temperature [℃]': 59.61,
#  'Diffuser outlet pressure [bar]': 26.69,
#  'Diffuser outlet temperature [℃]': 63.27,
#  'Polytropic efficiency [%]': 83.78,
#  'Isentropic efficiency [%]': 83.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.568,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 36.16,
#  'Rotor outlet diameter [cm]': 63.69,
#  'Diffuser outlet diameter [cm]': 101.6,
#  'Blade height at rotor inlet  [cm]': 6.93,
#  'Blade height at rotor outlet  [cm]': 3.69}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 127.6,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 127.6,
#                       'Absolute tangential rotor outlet': 328.1,
#                       'Absolute meridional rotor outlet': 104.4,
#                       'Absolute rotor outlet': 344.3,
#                       'Absolute diffuser outlet': 127.6,
#                       'Relative tangential rotor inlet': 320.4,
#                       'Relative rotor inlet': 344.8,
#                       'Relative tangential rotor outlet': 236.2,
#                       'Relative rotor outlet': 258.2,
#                       'Blade speed rotor inlet': 320.4,
#                       'Blade speed rotor outlet': 564.3},
#  'Mach Numbers': {'Ma at rotor inlet': 0.249,
#                   'Ma at rotor outlet': 0.183,
#                   'Ma at difusser inlet': 0.245,
#                   'Ma at difusser outlet': 0.09},
#  'Non-dimensional': {'Specific speed': 0.647,
#                      'Flow coefficient': 0.226,
#                      "Flow coefficient'": 0.023,
#                      'Work coefficient': 0.581,
#                      'Isentropic work coefficient': 0.486,
#                      'Rotor meridional velocity ratio': 0.818,
#                      'Degree of reaction': 0.724},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.35,
#                      'Relative rotor inlet': 68.29,
#                      'Relative rotor outlet': 66.16}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.724
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.35
# Non-optimal rotor outlet relative flow angle (0°-60°):  66.16
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34
# Stage 4
# Delta enthalpy [kJ/kg]:189.98
# Compression ratio:1.12
# Power [kW]:2717.74
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 27161.47,
#  'Rotor outlet pressure [bar]': 28.85,
#  'Rotor outlet temperature [℃]': 72.42,
#  'Diffuser outlet pressure [bar]': 29.8,
#  'Diffuser outlet temperature [℃]': 76.28,
#  'Polytropic efficiency [%]': 83.24,
#  'Isentropic efficiency [%]': 83.0}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.35,
#  'Rotor inlet diameter [cm]': 35.76,
#  'Rotor outlet diameter [cm]': 63.45,
#  'Diffuser outlet diameter [cm]': 101.04,
#  'Blade height at rotor inlet  [cm]': 6.78,
#  'Blade height at rotor outlet  [cm]': 3.45}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 122.2,
#                       'Absolute tangential rotor inlet': 0.0,
#                       'Absolute rotor inlet': 122.2,
#                       'Absolute tangential rotor outlet': 331.7,
#                       'Absolute meridional rotor outlet': 104.4,
#                       'Absolute rotor outlet': 347.8,
#                       'Absolute diffuser outlet': 122.2,
#                       'Relative tangential rotor inlet': 316.8,
#                       'Relative rotor inlet': 339.6,
#                       'Relative tangential rotor outlet': 230.4,
#                       'Relative rotor outlet': 253.0,
#                       'Blade speed rotor inlet': 316.8,
#                       'Blade speed rotor outlet': 562.1},
#  'Mach Numbers': {'Ma at rotor inlet': 0.24,
#                   'Ma at rotor outlet': 0.176,
#                   'Ma at difusser inlet': 0.242,
#                   'Ma at difusser outlet': 0.085},
#  'Non-dimensional': {'Specific speed': 0.624,
#                      'Flow coefficient': 0.217,
#                      "Flow coefficient'": 0.021,
#                      'Work coefficient': 0.59,
#                      'Isentropic work coefficient': 0.49,
#                      'Rotor meridional velocity ratio': 0.854,
#                      'Degree of reaction': 0.716},
#  'Flow angles [°]': {'Absolute rotor inlet': 0,
#                      'Absolute rotor outlet': 72.53,
#                      'Relative rotor inlet': 68.91,
#                      'Relative rotor outlet': 65.62}}
# Warnings:
# Non-optimal degree of reaction (0.6-0.7):  0.716
# Non-optimal rotor outlet absolute flow angle (60°-70°):  72.53
# Non-optimal rotor outlet relative flow angle (0°-60°):  65.62
# Non-optimal difussion factor (DF=w1/w2, 0.70-0.95):  1.34

# %%
HPC3.compDictionary()
# Out:
# RADIAL COMPRESSOR FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 14.3052,
#  'Compressor type': 'Radial compressor',
#  'Rotational speed [RPM]': 16920,
#  'Number of stages': 4,
#  'Max. tip velocity [m/s]': 600,
#  'Inlet pressure [bar]': 18.73,
#  'Inlet temperature [C]': 25.0,
#  'Inlet volumetric [m3/h]': 34180.74,
#  'Delta enthalpy [kJ/kg]': 745.54,
#  'Compression ratio': 1.59,
#  'Compressor power [kW]': 10665.04,
#  'Comp. Isentropic eff. [%]': 83.03,
#  'Comp. Polytropic eff. [%]': 84.1}
