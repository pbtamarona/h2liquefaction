# %%
from hydrogen_liquefaction import turbine

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

T_in    = 33.2000000000000  #K
P_in    = 29.3911300000000 #bar
P_out   = 3.50000000000000  #bar

m       = 2315.23292650504/3600 #kg/s

Turbine6= turbine.Turbine(fluid, T_in, P_in, P_out, m)

# %%
Turbine6.initialSpec()
# Out:
# TURBO-EXPANDER INITIAL SPECIFICATION INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 0.6431
#
# Inlet Condition
# P [bar]     =  29.391
# T [Kelvin]  =  33.2
# H [kJ/kg]   =  186.1
# S [kJ/kg.K] =  5.305
#
#
# Isentropic Outlet Condition
# P [bar]     =  3.5
# T [Kelvin]  =  25.41
# H [kJ/kg]   =  132.428
# S [kJ/kg.K] =  5.305
#
#
# Δh_is [kJ/kg]  =  53.672
# Power_is [kW]  = 34.517

# %%
#design constraint
u1_max  = 500 #m/s

Turbine6.noOfStages(u1_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  255.102
# Min. number of stage =  1
# Max. number of stage =  3

# %%
Turbine6.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  54887.24
# Max. RPM =  142960.751

# %%
Turbine6.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-0.8

# %%
Turbine6.stagesCalculation(86500, 1, True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:47.95
# Expansion ratio:8.4
# Power [kW]:30.84
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 40.65,
#  'Stator outlet pressure [bar]': 12.9,
#  'Stator outlet temperature [℃]': -241.98,
#  'Rotor outlet pressure [bar]': 3.5,
#  'Rotor outlet temperature [℃]': -247.74,
#  'Total-to-static efficiency [%]': 86.55,
#  'Isentropic efficiency [%]': 89.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.645,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 5.94,
#  'Rotor inlet diameter [cm]': 4.61,
#  'Rotor outlet diameter [cm]': 2.97,
#  'Blade height at rotor inlet  [cm]': 0.14,
#  'Blade height at rotor outlet  [cm]': 1.06}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 57.8,
#                       'Absolute tangential rotor inlet': 229.5,
#                       'Absolute rotor inlet': 236.6,
#                       'Absolute tangential rotor outlet': 0.0,
# ...

# %%
Turbine6.turbDictionary()
# Out:
# RADIAL INFLOW TURBINE FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 0.6431202573625111,
#  'Turbine type': 'Radial inflow turbine',
#  'Rotational speed [RPM]': 86500,
#  'Number of stages': 1,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 29.39,
#  'Inlet temperature [C]': -239.95,
#  'Inlet volumetric [m3/h]': 40.65,
#  'Delta enthalpy [kJ/kg]': 47.95,
#  'Expansion ratio': 0.12,
#  'Turbine power [kW]': 30.84,
#  'Turb. Isentropic eff. [%]': 89.34,
#  'Turb. Polytropic eff. [%]': 87.04}
