# %%
from hydrogen_liquefaction import turbine

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

T_in    = 47.3593615947418 #K
P_in    = 29.3199500000000 #bar
P_out   = 7.89500000000000 #bar

m       = 16662.0861432084/3600 #kg/s

Turbine2 = turbine.Turbine(fluid, T_in, P_in, P_out, m)

# %%
Turbine2.initialSpec()
# Out:
# TURBO-EXPANDER INITIAL SPECIFICATION INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 4.6284
#
# Inlet Condition
# P [bar]     =  29.32
# T [Kelvin]  =  47.36
# H [kJ/kg]   =  560.065
# S [kJ/kg.K] =  14.662
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.895
# T [Kelvin]  =  29.88
# H [kJ/kg]   =  426.803
# S [kJ/kg.K] =  14.662
#
#
# Δh_is [kJ/kg]  =  133.262
# Power_is [kW]  = 616.785

# %%
#design constraint
u1_max  = 500 #m/s

Turbine2.noOfStages(u1_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  255.102
# Min. number of stage =  1
# Max. number of stage =  3

# %%
Turbine2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  22909.545
# Max. RPM =  80828.159

# %%
Turbine2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-0.8

# %%
Turbine2.stagesCalculation(48000, 1, True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:119.3
# Expansion ratio:3.71
# Power [kW]:552.18
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 803.49,
#  'Stator outlet pressure [bar]': 15.86,
#  'Stator outlet temperature [℃]': -234.89,
#  'Rotor outlet pressure [bar]': 7.89,
#  'Rotor outlet temperature [℃]': -243.27,
#  'Total-to-static efficiency [%]': 86.42,
#  'Isentropic efficiency [%]': 89.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.616,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 17.3,
#  'Rotor inlet diameter [cm]': 13.05,
#  'Rotor outlet diameter [cm]': 8.04,
#  'Blade height at rotor inlet  [cm]': 0.82,
#  'Blade height at rotor outlet  [cm]': 2.81}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 90.7,
#                       'Absolute tangential rotor inlet': 363.8,
#                       'Absolute rotor inlet': 374.9,
#                       'Absolute tangential rotor outlet': 0.0,
#                       'Absolute meridional rotor outlet': 97.9,
#                       'Absolute rotor outlet': 97.9,
#                       'Absolute stator inlet': 97.9,
#                       'Relative tangential rotor inlet': 35.9,
#                       'Relative rotor inlet': 97.6,
#                       'Relative tangential rotor outlet': 201.9,
#                       'Relative rotor outlet': 224.4,
#                       'Blade speed rotor inlet': 327.9,
#                       'Blade speed rotor outlet': 201.9},
#  'Mach Numbers': {'Ma at stator inlet': 0.171,
#                   'Ma at stator outlet': 0.808,
#                   'Ma at rotor inlet': 0.21,
#                   'Ma at rotor outlet': -0.0},
#  'Non-dimensional': {'Specific speed': 0.475,
#                      'Flow coefficient': 0.298,
#                      'Work coefficient': 1.11,
#                      'Isentropic velocity ratio': 0.671,
#                      'Isentropic work coefficient': 1.24,
#                      'Rotor meridional velocity ratio': 0.927,
#                      'Degree of reaction': 0.451},
#  'Flow angles [°]': {'Absolute rotor inlet': 76.0,
#                      'Absolute rotor outlet': 0,
#                      'Relative rotor inlet': 21.6,
#                      'Relative rotor outlet': 64.14}}
# Warnings:
# Non-optimal work coefficient (0.8-1.0):  1.11
# Non-optimal rotor hub/tip ratio (>0.4):  0.3

# %%
Turbine2.turbDictionary()
# Out:
# RADIAL INFLOW TURBINE FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 4.628357262002333,
#  'Turbine type': 'Radial inflow turbine',
#  'Rotational speed [RPM]': 48000,
#  'Number of stages': 1,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 29.32,
#  'Inlet temperature [C]': -225.79,
#  'Inlet volumetric [m3/h]': 803.49,
#  'Delta enthalpy [kJ/kg]': 119.3,
#  'Expansion ratio': 0.27,
#  'Turbine power [kW]': 552.18,
#  'Turb. Isentropic eff. [%]': 89.53,
#  'Turb. Polytropic eff. [%]': 85.11}
