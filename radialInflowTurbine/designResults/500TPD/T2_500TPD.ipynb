# %%
import sys
import os

current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

import turbine

nTurbine = 2 #Number of turbines in parallel

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

T_in    = 47.3593098311159 #K
P_in    = 29.2800000000000 #bar
P_out   = 7.89480000000000 #bar

m       = 66659.8967837593/(3600*nTurbine) #kg/s

Turbine2 = turbine.Turbine(fluid, T_in, P_in, P_out, m)

# %%
Turbine2.initialSpec()
# Out:
# TURBO-EXPANDER INITIAL SPECIFICATION INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 9.2583
#
# Inlet Condition
# P [bar]     =  29.28
# T [Kelvin]  =  47.36
# H [kJ/kg]   =  560.338
# S [kJ/kg.K] =  14.672
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.895
# T [Kelvin]  =  29.88
# H [kJ/kg]   =  427.095
# S [kJ/kg.K] =  14.672
#
#
# Δh_is [kJ/kg]  =  133.243
# Power_is [kW]  = 1233.605

# %%
#design constraint
u1_max  = 500 #m/s

Turbine2.noOfStages(u1_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  255.102
# Min. number of stage =  1
# Max. number of stage =  3

# %%
Turbine2.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  16181.841
# Max. RPM =  57119.003

# %%
Turbine2.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-0.8

# %%
Turbine2.stagesCalculation(34000, 1, True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:119.32
# Expansion ratio:3.71
# Power [kW]:1104.7
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 1610.1,
#  'Stator outlet pressure [bar]': 15.86,
#  'Stator outlet temperature [℃]': -234.87,
#  'Rotor outlet pressure [bar]': 7.89,
#  'Rotor outlet temperature [℃]': -243.27,
#  'Total-to-static efficiency [%]': 86.44,
#  'Isentropic efficiency [%]': 89.6}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.617,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 24.43,
#  'Rotor inlet diameter [cm]': 18.42,
#  'Rotor outlet diameter [cm]': 11.36,
#  'Blade height at rotor inlet  [cm]': 1.16,
#  'Blade height at rotor outlet  [cm]': 3.98}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 90.8,
#                       'Absolute tangential rotor inlet': 363.6,
#                       'Absolute rotor inlet': 374.7,
#                       'Absolute tangential rotor outlet': 0.0,
#                       'Absolute meridional rotor outlet': 98.0,
#                       'Absolute rotor outlet': 98.0,
#                       'Absolute stator inlet': 98.0,
#                       'Relative tangential rotor inlet': 35.6,
#                       'Relative rotor inlet': 97.5,
#                       'Relative tangential rotor outlet': 202.2,
#                       'Relative rotor outlet': 224.7,
#                       'Blade speed rotor inlet': 328.0,
#                       'Blade speed rotor outlet': 202.2},
#  'Mach Numbers': {'Ma at stator inlet': 0.171,
#                   'Ma at stator outlet': 0.807,
#                   'Ma at rotor inlet': 0.21,
#                   'Ma at rotor outlet': -0.0},
#  'Non-dimensional': {'Specific speed': 0.476,
#                      'Flow coefficient': 0.299,
#                      'Work coefficient': 1.109,
#                      'Isentropic velocity ratio': 0.672,
#                      'Isentropic work coefficient': 1.239,
#                      'Rotor meridional velocity ratio': 0.927,
#                      'Degree of reaction': 0.451},
#  'Flow angles [°]': {'Absolute rotor inlet': 75.98,
#                      'Absolute rotor outlet': 0,
#                      'Relative rotor inlet': 21.41,
#                      'Relative rotor outlet': 64.15}}
# Warnings:
# Non-optimal work coefficient (0.8-1.0):  1.109
# Non-optimal rotor hub/tip ratio (>0.4):  0.3

# %%
Turbine2.turbDictionary()
# Out:
# RADIAL INFLOW TURBINE FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 9.258318997744347,
#  'Turbine type': 'Radial inflow turbine',
#  'Rotational speed [RPM]': 34000,
#  'Number of stages': 1,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 29.28,
#  'Inlet temperature [C]': -225.79,
#  'Inlet volumetric [m3/h]': 1610.1,
#  'Delta enthalpy [kJ/kg]': 119.32,
#  'Expansion ratio': 0.27,
#  'Turbine power [kW]': 1104.7,
#  'Turb. Isentropic eff. [%]': 89.55,
#  'Turb. Polytropic eff. [%]': 85.14}
