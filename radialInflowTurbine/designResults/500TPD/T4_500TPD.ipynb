# %%
from hydrogen_liquefaction import turbine

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

T_in    = 33.2000000000000  #K
P_in    = 29.3500000000000 #bar
P_out   = 3.50000000000000  #bar

m       = 9262.53691072737/3600 #kg/s

Turbine4= turbine.Turbine(fluid, T_in, P_in, P_out, m)

# %%
Turbine4.initialSpec()
# Out:
# TURBO-EXPANDER INITIAL SPECIFICATION INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 2.5729
#
# Inlet Condition
# P [bar]     =  29.35
# T [Kelvin]  =  33.2
# H [kJ/kg]   =  186.115
# S [kJ/kg.K] =  5.308
#
#
# Isentropic Outlet Condition
# P [bar]     =  3.5
# T [Kelvin]  =  25.41
# H [kJ/kg]   =  132.495
# S [kJ/kg.K] =  5.308
#
#
# Δh_is [kJ/kg]  =  53.62
# Power_is [kW]  = 137.961

# %%
#design constraint
u1_max  = 500 #m/s

Turbine4.noOfStages(u1_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  255.102
# Min. number of stage =  1
# Max. number of stage =  3

# %%
Turbine4.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  27417.579
# Max. RPM =  71398.909

# %%
Turbine4.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-0.8

# %%
Turbine4.stagesCalculation(43400, 1, True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:47.93
# Expansion ratio:8.39
# Power [kW]:123.31
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 162.65,
#  'Stator outlet pressure [bar]': 12.91,
#  'Stator outlet temperature [℃]': -241.98,
#  'Rotor outlet pressure [bar]': 3.5,
#  'Rotor outlet temperature [℃]': -247.74,
#  'Total-to-static efficiency [%]': 86.58,
#  'Isentropic efficiency [%]': 89.4}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.646,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 11.84,
#  'Rotor inlet diameter [cm]': 9.19,
#  'Rotor outlet diameter [cm]': 5.94,
#  'Blade height at rotor inlet  [cm]': 0.29,
#  'Blade height at rotor outlet  [cm]': 2.12}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 57.8,
#                       'Absolute tangential rotor inlet': 229.2,
#                       'Absolute rotor inlet': 236.3,
#                       'Absolute tangential rotor outlet': 0.0,
# ...

# %%
Turbine4.turbDictionary()
# Out:
# RADIAL INFLOW TURBINE FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 2.5729269196464912,
#  'Turbine type': 'Radial inflow turbine',
#  'Rotational speed [RPM]': 43400,
#  'Number of stages': 1,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 29.35,
#  'Inlet temperature [C]': -239.95,
#  'Inlet volumetric [m3/h]': 162.65,
#  'Delta enthalpy [kJ/kg]': 47.93,
#  'Expansion ratio': 0.12,
#  'Turbine power [kW]': 123.31,
#  'Turb. Isentropic eff. [%]': 89.38,
#  'Turb. Polytropic eff. [%]': 87.08}
