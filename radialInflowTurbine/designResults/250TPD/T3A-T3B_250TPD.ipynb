# %%
import sys
import os

current_dir = os.path.dirname(os.path.abspath(''))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

import turbine

nTurbine = 2 #Number of turbines in parallel

class Format:
    end = '\033[0m'
    underline = '\033[4m'

fluid   = "REFPROP::HYDROGEN"

T_in    = 111.990433826541 #K
P_in    = 29.4865300000000 #bar
P_out   = 7.69764000000000 #bar

m       = 33985.0036716544/(3600*nTurbine) #kg/s

Turbine3AB = turbine.Turbine(fluid, T_in, P_in, P_out, m)

# %%
Turbine3AB.initialSpec()
# Out:
# TURBO-EXPANDER INITIAL SPECIFICATION INITIAL SPECIFICATION
# Fluid: HYDROGEN
# Mass flow [kg/s] : 4.7201
#
# Inlet Condition
# P [bar]     =  29.487
# T [Kelvin]  =  111.99
# H [kJ/kg]   =  1410.725
# S [kJ/kg.K] =  26.299
#
#
# Isentropic Outlet Condition
# P [bar]     =  7.698
# T [Kelvin]  =  67.11
# H [kJ/kg]   =  927.281
# S [kJ/kg.K] =  26.299
#
#
# Δh_is [kJ/kg]  =  483.444
# Power_is [kW]  = 2281.921

# %%
#design constraint
u1_max  = 500 #m/s

Turbine3AB.noOfStages(u1_max)
# Out:
# Mininum and Maximum Number of Stage
# Wheel Tip Velocity [m/s]  =  500
# Δh_max/stage [kJ/kg] =  255.102
# Min. number of stage =  2
# Max. number of stage =  4

# %%
Turbine3AB.rotationalSpeedRange()
# Out:
# Minimum & Maximum Rotational Speed
# Min. RPM =  26407.98
# Max. RPM =  64644.223

# %%
Turbine3AB.nzSelectionPlot()
# Out:
# Rotational Speed Selection Plot
#
# Specific speed range for radial compressor is between 0.4-0.8

# %%
Turbine3AB.stagesCalculation(41500, 2, True)
# Out:
# Stage 1
# Delta enthalpy [kJ/kg]:212.27
# Expansion ratio:1.79
# Power [kW]:1001.93
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 2682.56,
#  'Stator outlet pressure [bar]': 21.45,
#  'Stator outlet temperature [℃]': -171.97,
#  'Rotor outlet pressure [bar]': 16.48,
#  'Rotor outlet temperature [℃]': -180.33,
#  'Total-to-static efficiency [%]': 85.04,
#  'Isentropic efficiency [%]': 87.9}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.564,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 26.12,
#  'Rotor inlet diameter [cm]': 19.73,
#  'Rotor outlet diameter [cm]': 11.12,
#  'Blade height at rotor inlet  [cm]': 1.28,
#  'Blade height at rotor outlet  [cm]': 3.73}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 116.0,
#                       'Absolute tangential rotor inlet': 495.0,
#                       'Absolute rotor inlet': 508.5,
#                       'Absolute tangential rotor outlet': 0.0,
#                       'Absolute meridional rotor outlet': 125.7,
#                       'Absolute rotor outlet': 125.7,
#                       'Absolute stator inlet': 125.7,
#                       'Relative tangential rotor inlet': 66.3,
#                       'Relative rotor inlet': 133.6,
#                       'Relative tangential rotor outlet': 241.6,
#                       'Relative rotor outlet': 272.3,
#                       'Blade speed rotor inlet': 428.7,
#                       'Blade speed rotor outlet': 241.6},
#  'Mach Numbers': {'Ma at stator inlet': 0.143,
#                   'Ma at stator outlet': 0.611,
#                   'Ma at rotor inlet': 0.161,
#                   'Ma at rotor outlet': 0.342},
#  'Non-dimensional': {'Specific speed': 0.41,
#                      'Flow coefficient': 0.293,
#                      'Work coefficient': 1.155,
#                      'Isentropic velocity ratio': 0.658,
#                      'Isentropic work coefficient': 1.315,
#                      'Rotor meridional velocity ratio': 0.923,
#                      'Degree of reaction': 0.428},
#  'Flow angles [°]': {'Absolute rotor inlet': 76.81,
#                      'Absolute rotor outlet': 0,
#                      'Relative rotor inlet': 29.77,
#                      'Relative rotor outlet': 62.52}}
# Warnings:
# Non-optimal work coefficient (0.8-1.0):  1.155
# Non-optimal degree of reaction (0.45-0.65):  0.428
# Non-optimal rotor hub/tip ratio (>0.4):  0.328
# Stage 2
# Delta enthalpy [kJ/kg]:225.42
# Expansion ratio:2.14
# Power [kW]:1064.0
# Thermodynamic Parameters:
# {'Stage inlet volumetric [m3/h]': 3920.1,
#  'Stator outlet pressure [bar]': 11.42,
#  'Stator outlet temperature [℃]': -191.33,
#  'Rotor outlet pressure [bar]': 7.7,
#  'Rotor outlet temperature [℃]': -201.9,
#  'Total-to-static efficiency [%]': 86.86,
#  'Isentropic efficiency [%]': 90.5}
# Geometric Parameters:
# {'Rotor tip diameter ratio': 0.635,
#  'Rotor hub diameter ratio': 0.185,
#  'Stator inlet diameter [cm]': 27.91,
#  'Rotor inlet diameter [cm]': 20.64,
#  'Rotor outlet diameter [cm]': 13.12,
#  'Blade height at rotor inlet  [cm]': 1.68,
#  'Blade height at rotor outlet  [cm]': 4.65}
# Kinematic Parameters:
# {'Velocities [m/s]': {'Absolute meridional rotor inlet': 126.4,
#                       'Absolute tangential rotor inlet': 487.2,
#                       'Absolute rotor inlet': 503.3,
#                       'Absolute tangential rotor outlet': 0.0,
#                       'Absolute meridional rotor outlet': 143.2,
#                       'Absolute rotor outlet': 143.2,
#                       'Absolute stator inlet': 143.2,
#                       'Relative tangential rotor inlet': 38.7,
#                       'Relative rotor inlet': 132.2,
#                       'Relative tangential rotor outlet': 285.0,
#                       'Relative rotor outlet': 319.0,
#                       'Blade speed rotor inlet': 448.5,
#                       'Blade speed rotor outlet': 285.0},
#  'Mach Numbers': {'Ma at stator inlet': 0.18,
#                   'Ma at stator outlet': 0.673,
#                   'Ma at rotor inlet': 0.177,
#                   'Ma at rotor outlet': 0.457},
#  'Non-dimensional': {'Specific speed': 0.514,
#                      'Flow coefficient': 0.319,
#                      'Work coefficient': 1.086,
#                      'Isentropic velocity ratio': 0.678,
#                      'Isentropic work coefficient': 1.202,
#                      'Rotor meridional velocity ratio': 0.883,
#                      'Degree of reaction': 0.467},
#  'Flow angles [°]': {'Absolute rotor inlet': 75.45,
#                      'Absolute rotor outlet': 0,
#                      'Relative rotor inlet': 17.03,
#                      'Relative rotor outlet': 63.33}}
# Warnings:
# Non-optimal flow coefficient (0.2-0.3):  0.319
# Non-optimal work coefficient (0.8-1.0):  1.086
# Non-optimal rotor hub/tip ratio (>0.4):  0.291
# Non-optimal rotor inlet relative flow angle (20°-40°):  17.03

# %%
Turbine3AB.turbDictionary()
# Out:
# RADIAL INFLOW TURBINE FINAL SPECIFICATION
# {'Fluid': 'HYDROGEN',
#  'Mass flow [kg/s]': 4.720139398840889,
#  'Turbine type': 'Radial inflow turbine',
#  'Rotational speed [RPM]': 41500,
#  'Number of stages': 2,
#  'Max. tip velocity [m/s]': 500,
#  'Inlet pressure [bar]': 29.49,
#  'Inlet temperature [C]': -161.16,
#  'Inlet volumetric [m3/h]': 2682.56,
#  'Delta enthalpy [kJ/kg]': 437.68,
#  'Expansion ratio': 0.26,
#  'Turbine power [kW]': 2065.92,
#  'Turb. Isentropic eff. [%]': 90.53,
#  'Turb. Polytropic eff. [%]': 87.69}
